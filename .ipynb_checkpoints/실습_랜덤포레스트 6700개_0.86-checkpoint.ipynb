# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('./data/result_review.csv')
data.drop('review_idx', axis = 1, inplace = True)
data.columns = ['제품명', '닉네임', '평점', '리뷰내용']
data
# Out:
#                  제품명       닉네임  평점  \
# 0     원더 세라마이드 모찌 토너      두치봉구   5
# 1     원더 세라마이드 모찌 토너   리뷰쓰는핑핑이   5
# 2     원더 세라마이드 모찌 토너    베리베리피치   5
# 3     원더 세라마이드 모찌 토너       냐람지   5
# 4     원더 세라마이드 모찌 토너      헤헤헷잉   5
# ...              ...       ...  ..
# 6695          순행클렌징폼      코비짱짱   5
# 6696          순행클렌징폼     고요한시간   4
# 6697          순행클렌징폼       꼬꼬우   4
# 6698          순행클렌징폼  aangmu__   5
# 6699          순행클렌징폼     졸리면커피   4
#
#                                                    리뷰내용
# 0     완전 가성비 최고 대용량 토너예요! 가격도 엄청 저렴한데 용량이 어마무시해서 스킨팩...
# 1     예전에 패드 너어어어무 만족해하며 썼던 기억이 떠올라서 구매해 본 토너입니다!! 아...
# 2     이것민 바르고 화장한다는데 좋네요. 기존 토너보단 에멀젼 느낌이라 지성분들 이것만 ...
# 3     벌써 n병째 재구매하는, 이제는 없어서는 안 될 필수템  지성인 나에게는 4계절 모...
# 4     열분 이거 가성비 갑입니다 양만 믾은 것도 아니고 제품력도 좋습니다  여러번 챱챱 ...
# ...                                                 ...
# 6695  선물 받아서 사용했는데 너무 순해요 잘못쓰면 따갑고 트러블도 많이 올라오는데 이제품...
# 6696  순행클렌징 폼 내용물의 색깔은 노란끼가 아주 약하게 있는 투명한 색이에요 거의 투명...
# 6697                             순하구 촉촉해서 만족스러운 제품입니다.
# 6698  좋아서 2통째 쓰는중이에요 ㅎㅎ 순한게 느껴져서 놀러온 친구들도 맘 편히 쓰더라구요...
# 6699  주르륵 흐를 정도의 수분감있는 젤타입 클렌징 폼입니다. 양도 넉넉하고 살짝 갈색빛이...
#
# [6700 rows x 4 columns]

# %%
fi_review = data["리뷰내용"]
fi_review
# Out:
# 0       웰라쥬 앰플이 유명해서 앰플 사용하다가 토너도 같이 사용해봤는데 역시나 너무 좋았습...
# 1       여름철만 되면 붉게 달아오르는 피부에 어떻게하면 속건조도 잡고 붉은끼도 진정시킬수있...
# 2       되게 촉촉하고 수분감이 장난 아닙니다 그래서 화장할 때 잘 쓰고 있어요 그리고 바르...
# 3       라이트한 사용감이지만 보습력이 있어서 여름에 건조한 피부가 쓰기 좋고 부담감이 없어...
# 4       수분이 꽉 꽉 채워지는 느낌!! 다들 쓰세여 겨울에 무조건!!! 건조한 피부는 무조...
#                               ...
# 1888    가볍다는 평이 많네요! 저는 너무 무거워서 깜짝 놀랐어요!! 흡수가 안되는건 아닌데...
# 1889    수분 부족형 지성, 얼굴에 열감이 잘 올라오는 피부입니다!  일단 속건조는 잘 잡아...
# 1890    스킨만 써보다 클레어스 올만이네요! 분사력 좋아요!!! 골고루 퍼지고 양도 적당히 ...
# 1891    의외로 촉촉했어요 세안직후 뿌려주고있는데 앰플미스트라그런지 흡수하고나서도 건조하진 ...
# 1892    좋았던점2가지 전성분이 확인했는데  성분이 좋은편이더라구요  그래서 믿고뿌려봤고 저...
# Name: 리뷰내용, Length: 1893, dtype: object

# %%
# 평점 기준
# 긍정 : 5, 4
# 중립 : 3
# 부정 : 2, 1

data['평점']

# 평점 기준
def rating_replace(rating):
    if rating in [5, 4]:  # 긍정은 2로 변경
        return 2
    elif rating == 3:  # 중립은 1로 변경
        return 1
    else:  # 부정은 0으로 변경
        return 0

data['감성분석 결과'] = data['평점'].apply(rating_replace)
data
# Out:
#                  제품명       닉네임  평점  \
# 0     원더 세라마이드 모찌 토너      두치봉구   5
# 1     원더 세라마이드 모찌 토너   리뷰쓰는핑핑이   5
# 2     원더 세라마이드 모찌 토너    베리베리피치   5
# 3     원더 세라마이드 모찌 토너       냐람지   5
# 4     원더 세라마이드 모찌 토너      헤헤헷잉   5
# ...              ...       ...  ..
# 6695          순행클렌징폼      코비짱짱   5
# 6696          순행클렌징폼     고요한시간   4
# 6697          순행클렌징폼       꼬꼬우   4
# 6698          순행클렌징폼  aangmu__   5
# 6699          순행클렌징폼     졸리면커피   4
#
#                                                    리뷰내용  감성분석 결과
# 0     완전 가성비 최고 대용량 토너예요! 가격도 엄청 저렴한데 용량이 어마무시해서 스킨팩...        2
# 1     예전에 패드 너어어어무 만족해하며 썼던 기억이 떠올라서 구매해 본 토너입니다!! 아...        2
# 2     이것민 바르고 화장한다는데 좋네요. 기존 토너보단 에멀젼 느낌이라 지성분들 이것만 ...        2
# 3     벌써 n병째 재구매하는, 이제는 없어서는 안 될 필수템  지성인 나에게는 4계절 모...        2
# 4     열분 이거 가성비 갑입니다 양만 믾은 것도 아니고 제품력도 좋습니다  여러번 챱챱 ...        2
# ...                                                 ...      ...
# 6695  선물 받아서 사용했는데 너무 순해요 잘못쓰면 따갑고 트러블도 많이 올라오는데 이제품...        2
# 6696  순행클렌징 폼 내용물의 색깔은 노란끼가 아주 약하게 있는 투명한 색이에요 거의 투명...        2
# 6697                             순하구 촉촉해서 만족스러운 제품입니다.         2
# 6698  좋아서 2통째 쓰는중이에요 ㅎㅎ 순한게 느껴져서 놀러온 친구들도 맘 편히 쓰더라구요...        2
# 6699  주르륵 흐를 정도의 수분감있는 젤타입 클렌징 폼입니다. 양도 넉넉하고 살짝 갈색빛이...        2
#
# [6700 rows x 5 columns]

# %%
data[data['감성분석 결과']==2].count()
# Out:
# 제품명        5776
# 닉네임        5776
# 평점         5776
# 리뷰내용       5776
# 감성분석 결과    5776
# dtype: int64

# %%
# 리뷰 내용 전처리
X = data['리뷰내용']
y = data['감성분석 결과']

# %%
# 라이브러리 불러오기
from konlpy.tag import Okt
okt = Okt()

# %%
okt.tagset
# Out:
# {'Adjective': '형용사',
#  'Adverb': '부사',
#  'Alpha': '알파벳',
#  'Conjunction': '접속사',
#  'Determiner': '관형사',
#  'Eomi': '어미',
#  'Exclamation': '감탄사',
#  'Foreign': '외국어, 한자 및 기타기호',
#  'Hashtag': '트위터 해쉬태그',
#  'Josa': '조사',
#  'KoreanParticle': '(ex: ㅋㅋ)',
#  'Noun': '명사',
#  'Number': '숫자',
#  'PreEomi': '선어말어미',
#  'Punctuation': '구두점',
#  'ScreenName': '트위터 아이디',
#  'Suffix': '접미사',
#  'Unknown': '미등록어',
#  'Verb': '동사'}

# %%
list_ = []

for i in X:
  list_.append(okt.pos(i, join=True))

list_
# Out:
# [['완전/Noun',
#   '가성/Noun',
#   '비/Noun',
#   '최고/Noun',
#   '대/Modifier',
#   '용량/Noun',
#   '토너/Noun',
#   '예요/Josa',
#   '!/Punctuation',
#   '가격/Noun',
#   '도/Josa',
#   '엄청/Adverb',
#   '저렴한데/Adjective',
#   '용량/Noun',
#   '이/Josa',
#   '어마/Noun',
#   '무시/Noun',
#   '해서/Verb',
#   '스킨/Noun',
#   '팩/Noun',
#   '으로/Josa',
#   '아낌없이/Adverb',
#   '쓰기/Noun',
#   '에/Josa',
#   '너무/Adverb',
#   '좋아요/Adjective',
#   '성분/Noun',
#   '도/Josa',
#   '크게/Noun',
#   '나쁜건/Adjective',
#   '없는/Adjective',
#   '것/Noun',
#   '같고/Adjective',
#   '모찌/Noun',
#   '토너/Noun',
#   '이름답게/Verb',
#   '워터/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '이지만/Josa',
#   '아주/Noun',
#   '수분/Noun',
#   '감/Noun',
#   '이/Josa',
#   '없지는/Adjective',
#   '않고/Verb',
#   '촉촉한/Adjective',
#   '편이/Noun',
#   '예요/Josa',
#   '좀/Noun',
#   '가격/Noun',
#   '대/Suffix',
#   '있는/Adjective',
#   '워터/Noun',
#   '토너/Noun',
#   '들/Suffix',
#   '은/Josa',
#   '스킨/Noun',
#   '팩/Noun',
#   '으로/Josa',
#   '막/Noun',
#   '쓰기/Noun',
#   '엔/Josa',
#   '아까웠는데/Adjective',
#   '이/Noun',
#   '제품/Noun',
#   '은/Josa',
#   '가격/Noun',
#   '이/Josa',
#   '너무/Adverb',
#   '훌륭해서/Adjective',
#   '신경/Noun',
#   '쓰지/Verb',
#   '않고/Verb',
#   '막/Noun',
#   '써도/Verb',
#   '좋아요/Adjective'],
#  ['예전/Noun',
#   '에/Josa',
#   '패드/Noun',
#   '너/Modifier',
#   '어어/Noun',
#   '어/Suffix',
#   '무/Noun',
#   '만족해하며/Adjective',
#   '썼던/Verb',
#   '기억/Noun',
#   '이/Josa',
#   '떠올라서/Verb',
#   '구매/Noun',
#   '해/Verb',
#   '본/Verb',
#   '토너/Noun',
#   '입니다/Adjective',
#   '!!/Punctuation',
#   '아니/Adjective',
#   '근데/Adverb',
#   '가격/Noun',
#   '실화/Noun',
#   '?!/Punctuation',
#   '넘/Verb',
#   '저렴해서/Adjective',
#   '좋았고/Adjective',
#   '용량/Noun',
#   '도/Josa',
#   '큰데/Verb',
#   '작은/Adjective',
#   '용량/Noun',
#   '도/Josa',
#   '증정/Noun',
#   '하더라구요/Verb',
#   '?/Punctuation',
#   '심지어/Noun',
#   '완전/Noun',
#   '샘플/Noun',
#   '사이즈/Noun',
#   '도/Josa',
#   '아니고/Adjective',
#   '넉넉한/Adjective',
#   '통/Noun',
#   '../Punctuation',
#   '오/Modifier',
#   '와우/Noun',
#   '👍👍/Foreign',
#   '게다가/Noun',
#   '물/Noun',
#   '토너/Noun',
#   '만/Josa',
#   '쓰다가/Verb',
#   '얘/Noun',
#   '쓰니까/Verb',
#   '영양/Noun',
#   '공급/Noun',
#   '도/Josa',
#   '제대로/Noun',
#   '되는/Verb',
#   '느낌/Noun',
#   '들어요/Verb',
#   '〰️/Foreign',
#   '넘나리/Verb',
#   '만족해하면서/Adjective',
#   '쓰고/Verb',
#   '있습니다/Adjective',
#   '굳/Adjective',
#   '굳/Adjective',
#   '굳/Adjective',
#   '그리/Verb',
#   '겨/Noun',
#   '에센스/Noun',
#   '따로/Adverb',
#   '안/Noun',
#   '발라/Noun',
#   '도/Josa',
#   '될/Verb',
#   '것/Noun',
#   '같은/Adjective',
#   '느낌/Noun',
#   '이라/Josa',
#   'ㅋㅋㅋ/KoreanParticle',
#   '체력/Noun',
#   '적/Suffix',
#   '정신/Noun',
#   '적/Suffix',
#   '여유/Noun',
#   '가/Josa',
#   '되면/Verb',
#   '두/Noun',
#   '번/Noun',
#   '발라주고/Verb',
#   '크림/Noun',
#   '발라주고/Verb',
#   '마무리/Noun',
#   '하고/Josa',
#   '있습니다/Adjective',
#   'ㅎㅎ/KoreanParticle',
#   '기초/Noun',
#   '화장품/Noun',
#   '줄/Noun',
#   '이고/Josa',
#   '싶다면/Verb',
#   '이/Noun',
#   '토너/Noun',
#   '강력/Noun',
#   '추천/Noun',
#   '!!/Punctuation',
#   '합니다/Verb',
#   '😆💗/Foreign'],
#  ['이/Determiner',
#   '것민/Noun',
#   '바르고/Verb',
#   '화장/Noun',
#   '한다는데/Verb',
#   '좋네요/Adjective',
#   './Punctuation',
#   '기존/Noun',
#   '토너/Noun',
#   '보단/Josa',
#   '에멀젼/Noun',
#   '느낌/Noun',
#   '이라/Josa',
#   '지성/Noun',
#   '분들/Suffix',
#   '이/Determiner',
#   '것/Noun',
#   '만/Josa',
#   '바르고/Verb',
#   '여름/Noun',
#   '에/Josa',
#   '화장/Noun',
#   '하시면/Verb',
#   '좋을/Adjective',
#   '것/Noun',
#   '같아요/Adjective',
#   '향/Noun',
#   '은/Josa',
#   '여자/Noun',
#   '화장품/Noun',
#   '향료/Noun',
#   '냄새/Noun',
#   '가/Josa',
#   '획/Noun',
#   '닙니디/Noun'],
#  ['벌써/Noun',
#   'n/Alpha',
#   '병/Noun',
#   '째/Suffix',
#   '재구/Verb',
#   '매하/Noun',
#   '는/Josa',
#   ',/Punctuation',
#   '이제/Noun',
#   '는/Josa',
#   '없어서는/Adjective',
#   '안/Noun',
#   '될/Verb',
#   '필수/Noun',
#   '템/Noun',
#   '지성인/Noun',
#   '나/Noun',
#   '에게는/Josa',
#   '4/Number',
#   '계절/Noun',
#   '모두/Noun',
#   '사용/Noun',
#   '가능하고/Adjective',
#   ',/Punctuation',
#   '여러/Modifier',
#   '번/Noun',
#   '레이어/Noun',
#   '링/Noun',
#   '할수록/Verb',
#   '피부/Noun',
#   '에/Josa',
#   '수분/Noun',
#   '감/Noun',
#   '이/Josa',
#   '차는/Verb',
#   '게/Noun',
#   '느껴져서/Verb',
#   '7/Number',
#   '스킨/Noun',
#   '이나/Josa',
#   '스킨/Noun',
#   '팩용/Noun',
#   '으로/Josa',
#   '정말/Noun',
#   '애용/Noun',
#   '하고/Josa',
#   '있다/Adjective',
#   '💖/Foreign',
#   '공병/Noun',
#   '에/Josa',
#   '담으면/Verb',
#   '여행가/Noun',
#   '서/Josa',
#   '이/Determiner',
#   '거/Noun',
#   '하나로/Noun',
#   '도/Josa',
#   '어떻/Modifier',
#   '게/Noun',
#   '든/Josa',
#   '전/Noun',
#   '단계/Noun',
#   '활용/Noun',
#   '가능할/Adjective',
#   '정도/Noun',
#   '데/Noun',
#   '일리/Noun',
#   '로/Josa',
#   '아낌없이/Adverb',
#   '사용/Noun',
#   '중/Suffix',
#   '이고/Josa',
#   ',/Punctuation',
#   '용량/Noun',
#   '이/Josa',
#   '거대한데다/Adjective',
#   '제품/Noun',
#   '을/Josa',
#   '바닥/Noun',
#   '까지/Josa',
#   '긁어/Verb',
#   '쓰기/Noun',
#   '좋은/Adjective',
#   '병/Noun',
#   '타입/Noun',
#   '이라/Josa',
#   '가성/Noun',
#   '비도/Noun',
#   '최고/Noun',
#   '향/Noun',
#   '은/Josa',
#   '은은한/Adjective',
#   '플/Exclamation',
#   '로럴/Noun',
#   '향/Noun',
#   '이/Josa',
#   '느껴지는데/Verb',
#   ',/Punctuation',
#   '쓰다/Verb',
#   '보면/Verb',
#   '무향/Noun',
#   '인/Josa',
#   '제품/Noun',
#   '이/Josa',
#   '아쉬울/Adjective',
#   '정도/Noun',
#   '로/Josa',
#   '향/Noun',
#   '이/Josa',
#   '좋아진다/Verb',
#   '!/Punctuation',
#   '끈/Noun',
#   '적임/Noun',
#   '없이/Adverb',
#   '쫀/Noun',
#   '~/Punctuation',
#   '득/Noun',
#   '한/Josa',
#   '마무리/Noun',
#   '감/Noun',
#   '💦/Foreign',
#   '⚠️/Foreign',
#   '하지만/Conjunction',
#   '건성/Noun',
#   '인/Josa',
#   '분/Noun',
#   '들/Suffix',
#   '은/Josa',
#   '토너/Noun',
#   '로/Josa',
#   '몇/Noun',
#   '번/Noun',
#   '레이어/Noun',
#   '링/Noun',
#   '후/Noun',
#   '에/Josa',
#   '보습/Noun',
#   '장벽/Noun',
#   '크림/Noun',
#   '을/Josa',
#   '덧/Noun',
#   '발라주고/Verb',
#   '마무리/Noun',
#   '하면/Verb',
#   '좋을/Adjective',
#   '것/Noun',
#   '같고/Adjective',
#   ',/Punctuation',
#   '트러블/Noun',
#   '성/Suffix',
#   '피부/Noun',
#   '인/Josa',
#   '분들/Suffix',
#   '중/Noun',
#   '닦/Verb',
#   '토/Noun',
#   '를/Josa',
#   '즐겨하는/Verb',
#   '분/Noun',
#   '들이라면/Verb',
#   '다소/Noun',
#   '수분/Noun',
#   '감/Noun',
#   '이/Josa',
#   '오버/Noun',
#   '하/Suffix',
#   '거나/Noun',
#   '각질/Noun',
#   '이/Josa',
#   '덜/Noun',
#   '닦인/Verb',
#   '느낌/Noun',
#   '이/Josa',
#   '들/Verb',
#   '수도/Noun',
#   '있겠다/Adjective'],
#  ['열/Modifier',
#   '분/Noun',
#   '이/Determiner',
#   '거/Noun',
#   '가성/Noun',
#   '비/Noun',
#   '갑/Noun',
#   '입니다/Adjective',
#   '양/Noun',
#   '만/Josa',
#   '믾/Noun',
#   '은/Josa',
#   '것/Noun',
#   '도/Josa',
#   '아니고/Adjective',
#   '제품/Noun',
#   '력/Suffix',
#   '도/Josa',
#   '좋습니다/Adjective',
#   '여러/Modifier',
#   '번/Noun',
#   '챱챱/Noun',
#   '흡수/Noun',
#   '하면/Verb',
#   '보습/Noun',
#   '력/Suffix',
#   '와/Verb',
#   '따에요/Verb',
#   '👍🏻/Foreign',
#   '전/Noun',
#   '향/Noun',
#   '도/Josa',
#   '좋더라구요/Adjective',
#   '../Punctuation',
#   '토너/Noun',
#   '팩/Noun',
#   '하/Suffix',
#   '기도/Noun',
#   '좋고/Adjective',
#   '대/Modifier',
#   '용량/Noun',
#   '이지만/Josa',
#   '이미/Adverb',
#   '몇/Modifier',
#   '통/Noun',
#   '비웠어요/Verb'],
#  ['정말/Noun',
#   '놀라운/Adjective',
#   '제품/Noun',
#   '입니다/Adjective',
#   './Punctuation',
#   '작년/Noun',
#   '부터/Josa',
#   '사용/Noun',
#   '해/Verb',
#   '왔습니다/Verb',
#   './Punctuation',
#   '정말/Noun',
#   '촉촉하고/Adjective',
#   '건조하지/Adjective',
#   '않은/Verb',
#   '피부/Noun',
#   '로/Josa',
#   '만들어주는/Verb',
#   '제품/Noun',
#   '이에요/Josa'],
#  ['유튜버/Noun',
#   '가/Josa',
#   '좋다고/Adjective',
#   '좋다고/Adjective',
#   '극찬/Noun',
#   '을/Josa',
#   '해서/Verb',
#   '속/Noun',
#   '는셈/Verb',
#   '치고/Josa',
#   '구매/Noun',
#   '해봤음/Verb',
#   './Punctuation',
#   '근데/Adverb',
#   '이/Determiner',
#   '거/Noun',
#   '..../Punctuation',
#   '요물/Noun',
#   '이네/Josa',
#   '?/Punctuation',
#   '가격/Noun',
#   '대비/Noun',
#   '짱/Noun',
#   '좋음/Adjective',
#   './Punctuation',
#   '얇게/Adjective',
#   '여러/Modifier',
#   '번/Noun',
#   '레이어/Noun',
#   '드/Noun',
#   '해서/Verb',
#   '발라주면/Verb',
#   '속/Modifier',
#   '건조/Noun',
#   '를/Josa',
#   '꽤/Noun',
#   '잘/Verb',
#   '잡아/Verb',
#   '준다/Verb',
#   '세안/Noun',
#   '후/Noun',
#   '첫/Noun',
#   '단계/Noun',
#   '에서/Josa',
#   '사용/Noun',
#   '하는데/Verb',
#   '에센스/Noun',
#   '같은/Adjective',
#   '점성/Noun',
#   '이/Josa',
#   '있는/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '이라/Josa',
#   '닦/Verb',
#   '토로/Noun',
#   '사용/Noun',
#   '하는/Verb',
#   '대신/Noun',
#   ',/Punctuation',
#   '여러/Modifier',
#   '번/Noun',
#   '레이어/Noun',
#   '드/Noun',
#   '해서/Verb',
#   '바르는게/Verb',
#   '더/Noun',
#   '좋음/Adjective',
#   './Punctuation',
#   '얘/Noun',
#   '하나로/Noun',
#   '도/Josa',
#   '속/Modifier',
#   '건조/Noun',
#   '를/Josa',
#   '잘/Verb',
#   '잡아줘서/Verb',
#   '이/Determiner',
#   '거/Noun',
#   '다음/Noun',
#   '기능/Noun',
#   '성/Suffix',
#   '제품/Noun',
#   '인/Josa',
#   '레티놀/Noun',
#   '순서/Noun',
#   '로/Josa',
#   '발라줘도/Verb',
#   '피부/Noun',
#   '가/Josa',
#   '마르는/Adjective',
#   '느낌/Noun',
#   '이/Josa',
#   '적다/Verb',
#   './Punctuation',
#   '그래서/Adverb',
#   '자주/Noun',
#   '손/Noun',
#   '이/Josa',
#   '가는듯/Verb',
#   './Punctuation',
#   '재구매/Verb',
#   '의사/Noun',
#   '있음/Adjective',
#   './Punctuation',
#   '짐승/Noun',
#   '용량/Noun',
#   '에/Josa',
#   '이정/Noun',
#   '도/Josa',
#   '기능/Noun',
#   '성/Suffix',
#   '이/Determiner',
#   '라면/Noun',
#   '구매/Noun',
#   '안/Noun',
#   '하는게/Verb',
#   '더/Noun',
#   '손해/Noun',
#   './Punctuation'],
#  ['가성/Noun',
#   '비/Noun',
#   '좋아요/Adjective',
#   'ㅋㅋ/KoreanParticle',
#   '무난/Noun',
#   '무난/Noun',
#   '해/Noun',
#   '요/Josa',
#   '저/Determiner',
#   '한텐/Noun',
#   '살짝/Noun',
#   '따가운데/Adjective',
#   '붉어지거나/Adjective',
#   '트러블/Noun',
#   '생기진/Verb',
#   '않았어요/Verb',
#   '촉촉하니/Adjective',
#   '좋아요/Adjective',
#   '여름/Noun',
#   '에는/Josa',
#   '이/Determiner',
#   '것/Noun',
#   '만/Josa',
#   '발라/Noun',
#   '도/Josa',
#   '굿/Noun'],
#  ['피부/Noun',
#   '타입/Noun',
#   ':/Punctuation',
#   '지성/Noun',
#   '//Punctuation',
#   '민감/Noun',
#   '성/Suffix',
#   '결론/Noun',
#   ':/Punctuation',
#   '가성/Noun',
#   '비/Noun',
#   '최고/Noun',
#   '…/Punctuation',
#   '물/Noun',
#   '토너/Noun',
#   '와/Josa',
#   '콧물토너/Noun',
#   '의/Josa',
#   '중간/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '이라고/Josa',
#   '보시/Noun',
#   '면/Josa',
#   '돼요/Verb',
#   '!/Punctuation',
#   '그래서/Adverb',
#   '너무/Adverb',
#   '건조하지도/Adjective',
#   ',/Punctuation',
#   '너무/Adverb',
#   '답답하지도/Adjective',
#   '않게/Verb',
#   '사용/Noun',
#   '할/Verb',
#   '수/Noun',
#   '있었어요/Adjective',
#   '지성/Noun',
#   '이라/Josa',
#   '콧물/Noun',
#   '토너/Noun',
#   '는/Josa',
#   '답답해서/Adjective',
#   '물/Noun',
#   '토너/Noun',
#   '를/Josa',
#   '사용/Noun',
#   '했는데/Verb',
#   '금새/Modifier',
#   '줄어들고/Verb',
#   '금방/Noun',
#   '건조해져서/Adjective',
#   '레이어/Noun',
#   '링/Noun',
#   '하기/Verb',
#   '가끔/Noun',
#   '귀찮을/Adjective',
#   '때/Noun',
#   '가/Josa',
#   '있더라구요/Adjective',
#   '그래서/Adverb',
#   '구매/Noun',
#   '하게/Verb',
#   '되었는데/Verb',
#   '용량/Noun',
#   '깡패/Noun',
#   '../Punctuation',
#   '가성/Noun',
#   '비/Noun',
#   '최고/Noun',
#   '인/Josa',
#   '것/Noun',
#   '같아요/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '은/Josa',
#   '살짝/Noun',
#   '유/Noun',
#   '분/Suffix',
#   '기있어서/Verb',
#   '한번/Noun',
#   '흡수/Noun',
#   '시켜주니/Verb',
#   '지/Modifier',
#   '성/Modifier',
#   '피부/Noun',
#   '인/Josa',
#   '저/Noun',
#   '에겐/Josa',
#   '촉촉하게/Adjective',
#   '잘/Verb',
#   '유지/Noun',
#   '되었어요/Verb',
#   '솜/Noun',
#   '에/Josa',
#   '넉넉하게/Adjective',
#   '적셔/Verb',
#   '스킨/Noun',
#   '팩/Noun',
#   '으로도/Josa',
#   '사용/Noun',
#   '할/Verb',
#   '수/Noun',
#   '있는데/Adjective',
#   '피부/Noun',
#   '상태/Noun',
#   '에/Josa',
#   '따라/Verb',
#   '처음/Noun',
#   '에는/Josa',
#   '짧게/Adjective',
#   '하는/Verb',
#   '것/Noun',
#   '추천/Noun',
#   '드려요/Verb',
#   '!/Punctuation',
#   '저/Noun',
#   '는/Josa',
#   '길게하면/Adjective',
#   '뾰루지/Noun',
#   '가/Josa',
#   '나서/Verb',
#   '잠깐/Noun',
#   '붙이/Noun',
#   '고/Josa',
#   '닦아/Verb',
#   '준답니다/Verb',
#   '영양/Noun',
#   '이/Josa',
#   '필요한/Adjective',
#   '날/Noun',
#   '에/Josa',
#   '하면/Verb',
#   '좋아요/Adjective'],
#  ['세/Modifier',
#   '라마/Noun',
#   '이드/Noun',
#   '성분/Noun',
#   '이/Josa',
#   '보습/Noun',
#   '과/Josa',
#   '영양/Noun',
#   '을/Josa',
#   '도와주고/Verb',
#   '히알루론산/Noun',
#   '&/Punctuation',
#   '판테/Verb',
#   '놀/Noun',
#   '함유/Noun',
#   '로/Josa',
#   '쫀쫀/Noun',
#   '한/Josa',
#   '피부/Noun',
#   '케어/Noun',
#   '를/Josa',
#   '도와주고/Verb',
#   '병풀/Noun',
#   '추출/Noun',
#   '물이/Noun',
#   '민감/Noun',
#   '피부/Noun',
#   '진정/Noun',
#   '케어/Noun',
#   '를/Josa',
#   '도와줘요/Verb',
#   '화장/Noun',
#   '솜/Noun',
#   '에/Josa',
#   '토너/Noun',
#   '를/Josa',
#   '듬뿍/Noun',
#   '적셔/Verb',
#   '민감하거나/Adjective',
#   '달아오른/Verb',
#   '피부/Noun',
#   '에/Josa',
#   '스킨/Noun',
#   '팩/Noun',
#   '으로/Josa',
#   '사용/Noun',
#   '해도/Verb',
#   '좋아요/Adjective'],
#  ['학생/Noun',
#   '때/Noun',
#   '많이/Adverb',
#   '썼던/Verb',
#   '토너/Noun',
#   '임/Noun',
#   '진짜/Noun',
#   '말/Noun',
#   '그래도/Adverb',
#   '모찌/Noun',
#   '같은/Adjective',
#   '제/Modifier',
#   '형임/Noun',
#   '콧물/Noun',
#   '?/Punctuation',
#   '같이/Adverb',
#   '흐르는/Verb',
#   '제/Modifier',
#   '형/Noun',
#   '에서/Josa',
#   '조금/Noun',
#   '더/Noun',
#   '모찌/Noun',
#   '같은/Adjective',
#   '?/Punctuation',
#   '로션/Noun',
#   '같이/Josa',
#   '쓰기/Noun',
#   '부담스러울/Adjective',
#   '때/Noun',
#   '이/Determiner',
#   '거/Noun',
#   '하나/Noun',
#   '에/Josa',
#   '선크림/Noun',
#   '에센스/Noun',
#   '같은/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '이랑/Josa',
#   '같이/Adverb',
#   '쓰면/Verb',
#   '피부/Noun',
#   '표현/Noun',
#   '잘/VerbPrefix',
#   '되고/Verb',
#   '너무/Adverb',
#   '좋았음/Adjective',
#   '트러블/Noun',
#   '효과/Noun',
#   '는/Josa',
#   '잘/Verb',
#   '못/VerbPrefix',
#   '본거/Verb',
#   '같지만/Adjective',
#   '피부/Noun',
#   '하나/Noun',
#   '는/Josa',
#   '모찌/Noun',
#   '같아/Adjective',
#   '짐/Noun'],
#  ['모찌/Noun',
#   '토너/Noun',
#   '가성/Noun',
#   '비/Noun',
#   '갑이죠/Verb',
#   'ㅎㅎ/KoreanParticle',
#   '저/Noun',
#   '는/Josa',
#   '닦/Verb',
#   '토/Noun',
#   '안/VerbPrefix',
#   '하지만/Verb',
#   '닦/Verb',
#   '토/Noun',
#   '하시는/Verb',
#   '분/Noun',
#   '들/Suffix',
#   '이나/Josa',
#   '스킨/Noun',
#   '팩/Noun',
#   '하는/Verb',
#   '분/Noun',
#   '들/Suffix',
#   '은/Josa',
#   '꼭/Noun',
#   '구입/Noun',
#   '하셔요/Verb',
#   '양/Noun',
#   '이/Josa',
#   '많아/Adjective',
#   '3월/Number',
#   '에/Foreign',
#   '샀는데/Verb',
#   '아직도/Adverb',
#   '쓰는게/Verb',
#   '단점/Noun',
#   '..../Punctuation',
#   '이지만/Josa',
#   '이/Noun',
#   '가격/Noun',
#   '에/Josa',
#   '이/Noun',
#   '용량/Noun',
#   '은/Josa',
#   '진짜/Noun',
#   '혜자/Noun',
#   '입니다/Adjective',
#   '😁😁😁😁/Foreign',
#   '제품/Noun',
#   '이/Josa',
#   '확/Noun',
#   '좋다거나/Adjective',
#   '그런건/Adjective',
#   '아닌데/Adjective',
#   '그래도/Adverb',
#   '무난/Noun',
#   '하게/Verb',
#   '잘/Verb',
#   '사용/Noun',
#   '하고/Josa',
#   '있어요/Adjective',
#   '물/Noun',
#   '토너/Noun',
#   '치곤/Verb',
#   '점성/Noun',
#   '있어서/Adjective',
#   '지성인/Noun',
#   '분들/Suffix',
#   '겨울/Noun',
#   '에/Josa',
#   '쓰셔도/Verb',
#   '좋아요/Adjective',
#   'ㅋㅋ/KoreanParticle',
#   '추천/Noun',
#   '합니다/Verb'],
#  ['휘뚜루마뚜루/Adverb',
#   '막/Noun',
#   '바르기/Verb',
#   '좋은/Adjective',
#   '토너/Noun',
#   '자극/Noun',
#   '도/Josa',
#   '없어서/Adjective',
#   '좋아요/Adjective',
#   '~/Punctuation',
#   '특별하지/Adjective',
#   '않은게/Verb',
#   '장점/Noun',
#   '이자/Noun',
#   '단점/Noun',
#   '임/Noun',
#   'ㅋ/KoreanParticle',
#   '그래도/Adverb',
#   '가성/Noun',
#   '비/Noun',
#   '면/Noun',
#   '에선/Josa',
#   '대/Modifier',
#   '혜자/Noun'],
#  ['양/Noun',
#   '많고/Adjective',
#   '순하고/Adjective',
#   '가격/Noun',
#   '착하고/Adjective',
#   '엄청/Adverb',
#   '효과/Noun',
#   '가/Josa',
#   '있다/Adjective',
#   '이건/Noun',
#   '아니지만/Adjective',
#   '단점/Noun',
#   '이/Josa',
#   '없고/Adjective',
#   '무난/Noun',
#   '해서/Verb',
#   '5/Number',
#   '통째/Noun',
#   '쓰고있어용/Verb'],
#  ['솜/Noun',
#   '에/Josa',
#   '묻혀서/Verb',
#   '쓰면/Verb',
#   '더/Noun',
#   '좋을/Adjective',
#   '듯/Noun',
#   '한/Josa',
#   '토너/Noun',
#   '에요/Josa',
#   './Punctuation',
#   '귀찮아서/Adjective',
#   '수분/Noun',
#   '보충/Noun',
#   '용/Noun',
#   '으로/Josa',
#   '손/Noun',
#   '에/Josa',
#   '덜어/Verb',
#   '쓰고/Verb',
#   '있긴/Adjective',
#   '하지만/Conjunction',
#   '스킨/Noun',
#   '팩/Noun',
#   '하/Suffix',
#   '듯/Noun',
#   '솜/Noun',
#   '에/Josa',
#   '묻혀/Verb',
#   '사용/Noun',
#   '하면/Verb',
#   '수분/Noun',
#   '감/Noun',
#   '이/Josa',
#   '더/Noun',
#   '채워질/Verb',
#   '듯/Noun',
#   '합니다/Verb',
#   './Punctuation',
#   '엄청/Adverb',
#   '순위/Noun',
#   '가/Josa',
#   '높은/Adjective',
#   '제품/Noun',
#   '인데/Josa',
#   '왜/Noun',
#   '그런지/Adjective',
#   '이해/Noun',
#   '가/Josa',
#   '갈/Verb',
#   '정도/Noun',
#   '예요/Josa',
#   './Punctuation',
#   '부담/Noun',
#   '스럽지/Josa',
#   '않은/Verb',
#   '제/Modifier',
#   '형/Noun',
#   '인데/Josa',
#   '히알루론산/Noun',
#   '때문/Noun',
#   '에/Josa',
#   '촉촉함이/Adjective',
#   '오래/Adverb',
#   '가요/Noun',
#   './Punctuation',
#   '향/Noun',
#   '은/Josa',
#   '산뜻하고/Adjective',
#   '강하지/Adjective',
#   '않아서/Verb',
#   '호불호/Noun',
#   '는/Josa',
#   '크지/Verb',
#   '않을거라/Verb',
#   '생각/Noun',
#   '됩니다/Verb',
#   './Punctuation',
#   '양/Noun',
#   '이/Josa',
#   '정말/Noun',
#   '많아서/Adjective',
#   '오래/Adverb',
#   '쓸/Verb',
#   '수/Noun',
#   '있는데/Adjective',
#   '가격/Noun',
#   '도/Josa',
#   '비싸지/Adjective',
#   '않아/Verb',
#   '가성/Noun',
#   '비/Noun',
#   '갑인/Noun',
#   '제품/Noun',
#   '이/Suffix',
#   '예요/Josa',
#   './Punctuation'],
#  ['살짝/Noun',
#   '꾸/Verb',
#   '덕/Noun',
#   '한/Josa',
#   '제/Modifier',
#   '형/Noun',
#   '에/Josa',
#   '수분/Noun',
#   '감/Noun',
#   '가득한/Adjective',
#   '토너/Noun',
#   '네/Suffix',
#   '요/Josa',
#   '!/Punctuation',
#   '그렇다고/Conjunction',
#   '끈/Noun',
#   '적/Suffix',
#   '이/Determiner',
#   '거나/Noun',
#   '하진/Noun',
#   '않고/Verb',
#   '화장/Noun',
#   '솜/Noun',
#   '에/Josa',
#   '넉넉히/Adjective',
#   '적신/Noun',
#   '다음/Noun',
#   '가볍게/Adjective',
#   '닦아내주듯/Verb',
#   '결정/Noun',
#   '돈/Noun',
#   '후/Noun',
#   '에/Josa',
#   '다시/Noun',
#   '한번/Noun',
#   '레이어/Noun',
#   '링/Noun',
#   '하는데요/Verb',
#   '~/Punctuation',
#   '그러고/Adjective',
#   '나면/Verb',
#   '피부/Noun',
#   '가/Josa',
#   '진찌/Noun',
#   '쫀득쫀득/Noun',
#   '수분/Noun',
#   '머/Noun',
#   '금은/Noun',
#   '느낌/Noun',
#   '이/Josa',
#   '들어요/Verb',
#   '~/Punctuation',
#   '무엇/Noun',
#   '보다/Josa',
#   '넉넉한/Adjective',
#   '량/Noun',
#   '과/Josa',
#   '가격/Noun',
#   '이/Josa',
#   '너무/Adverb',
#   '맘/Noun',
#   '에/Josa',
#   '듭니/Noun',
#   '다/Josa',
#   '!!!/Punctuation'],
#  ['워낙/Noun',
#   '대/Modifier',
#   '용량/Noun',
#   '이다/Josa',
#   '보니/Verb',
#   '스킨/Noun',
#   '팩/Noun',
#   '주/Modifier',
#   '구/Modifier',
#   '장창/Noun',
#   '해주고/Verb',
#   '치덕치덕/Noun',
#   '발라줘도/Verb',
#   '한가득/Adverb',
#   '남아있는/Verb',
#   '마법/Noun',
#   '대/Modifier',
#   '용량/Noun',
#   '임/Noun',
#   '에도/Josa',
#   '가격/Noun',
#   '이/Josa',
#   '너무/Adverb',
#   '저렴해서/Adjective',
#   '별/Noun',
#   '기대/Noun',
#   '안/VerbPrefix',
#   '했는데/Verb',
#   '뭔가/Noun',
#   '막/Noun',
#   '엄청/Adverb',
#   '좋다/Adjective',
#   '!!!!/Punctuation',
#   '이런건/Adjective',
#   '아니지만/Adjective',
#   '되게/Adverb',
#   '순하고/Adjective',
#   '촉촉해져서/Adjective',
#   '무난/Noun',
#   '하게/Verb',
#   '잘/Verb',
#   '사용/Noun',
#   '중/Suffix',
#   '인/Josa',
#   '토너/Noun',
#   '에요/Josa',
#   '!/Punctuation',
#   '나름/Noun',
#   '보습/Noun',
#   '력/Suffix',
#   '좋아서/Adjective',
#   '피부/Noun',
#   '쫀쫀/Noun',
#   '해지는게/Verb',
#   '느껴져요/Verb'],
#  ['대/Modifier',
#   '용량/Noun',
#   '이라/Josa',
#   '너무/Adverb',
#   '좋아요/Adjective',
#   '흰색/Noun',
#   '색상/Noun',
#   '에/Josa',
#   '약간/Noun',
#   '의/Josa',
#   '점성/Noun',
#   '이/Josa',
#   '있는데/Adjective',
#   '보통/Noun',
#   '점성/Noun',
#   '있는/Adjective',
#   '제품/Noun',
#   '은/Josa',
#   '피부/Noun',
#   '에/Josa',
#   '스며드는게/Verb',
#   '더딘/Verb',
#   '편/Noun',
#   '인데/Josa',
#   '토니모리/Noun',
#   '원더/Noun',
#   '세/Modifier',
#   '라마/Noun',
#   '이드/Noun',
#   '모찌/Noun',
#   '토너/Noun',
#   '는/Josa',
#   '피부/Noun',
#   '에/Josa',
#   '부드럽게/Adjective',
#   '빠르게/Adjective',
#   '흡수/Noun',
#   '되요/Verb',
#   '대/Modifier',
#   '용량/Noun',
#   '이랑/Josa',
#   '파팍/Noun',
#   '쓰기/Noun',
#   '에/Josa',
#   '부담/Noun',
#   '이/Josa',
#   '없어요/Adjective'],
#  ['일단/Noun',
#   '양/Noun',
#   '이/Josa',
#   '엄청/Adverb',
#   '많아서/Adjective',
#   '오래/Adverb',
#   '두고/Verb',
#   '사용/Noun',
#   '이/Josa',
#   '가능하고/Adjective',
#   ',/Punctuation',
#   '써도/Verb',
#   '써도/Verb',
#   '안/Noun',
#   '줄어드는/Verb',
#   '것/Noun',
#   '같은/Adjective',
#   '느낌/Noun',
#   '이라/Josa',
#   '듬뿍듬뿍/Adverb',
#   '바를/Verb',
#   '수/Noun',
#   '있어서/Adjective',
#   '좋아요/Adjective',
#   './Punctuation',
#   '가격/Noun',
#   '대도/Noun',
#   '엄청/Adverb',
#   '착해서/Adjective',
#   '가성/Noun',
#   '비/Noun',
#   '토너/Noun',
#   '로/Josa',
#   '아주/Noun',
#   '좋아요/Adjective',
#   './Punctuation',
#   '우유/Noun',
#   '같은/Adjective',
#   '색/Noun',
#   '이고/Josa',
#   '묽다기/Adjective',
#   '보다는/Josa',
#   '살짝/Noun',
#   '점도/Noun',
#   '가/Josa',
#   '있는/Adjective',
#   '편이/Noun',
#   '에요/Josa',
#   './Punctuation'],
#  ['가격/Noun',
#   '이/Josa',
#   '싸서/Verb',
#   '사실/Noun',
#   '기대/Noun',
#   '를/Josa',
#   '안/Noun',
#   '했었다/Verb',
#   './Punctuation',
#   '근데/Adverb',
#   '막상/Noun',
#   '써/Verb',
#   '보니/Verb',
#   '너무/Adverb',
#   '좋음/Adjective',
#   './Punctuation',
#   '아니/Adjective',
#   ',/Punctuation',
#   '내/Noun',
#   '가/Josa',
#   '써/Verb',
#   '본/Verb',
#   '토너/Noun',
#   '중/Noun',
#   '최고/Noun',
#   '임/Noun',
#   './Punctuation',
#   '이/Noun',
#   '토너/Noun',
#   '만큼/Josa',
#   '촉촉하고/Adjective',
#   '보습/Noun',
#   '꽉/Noun',
#   '채워주는/Verb',
#   '토너/Noun',
#   '를/Josa',
#   '본/Verb',
#   '적/Noun',
#   '이/Josa',
#   '없다/Adjective',
#   './Punctuation',
#   '다른/Noun',
#   '토너/Noun',
#   '들/Suffix',
#   '은/Josa',
#   '바르면/Verb',
#   '금방/Noun',
#   '날아가는데/Verb',
#   ',/Punctuation',
#   '얘/Noun',
#   '는/Josa',
#   '그런/Adjective',
#   '게/Noun',
#   '없다/Adjective',
#   './Punctuation',
#   '물/Noun',
#   '토너/Noun',
#   '와/Josa',
#   '달리/Noun',
#   '약간/Noun',
#   '점성/Noun',
#   '이/Josa',
#   '있어서/Adjective',
#   '바를/Verb',
#   '때/Noun',
#   '도/Josa',
#   '편하다/Adjective',
#   './Punctuation',
#   '(/Punctuation',
#   '일반/Noun',
#   '물/Noun',
#   '토너/Noun',
#   '는/Josa',
#   '손틈/Noun',
#   '사이/Noun',
#   '로/Josa',
#   '빠져나가서/Verb',
#   '바닥/Noun',
#   '난리/Noun',
#   '남/Noun',
#   'ㅋㅋ/KoreanParticle',
#   ')/Punctuation',
#   '가격/Noun',
#   '대비/Noun',
#   '용량/Noun',
#   '도/Josa',
#   '혜자/Noun',
#   '라서/Josa',
#   '다/Adverb',
#   '쓰면/Verb',
#   '재구매/Verb',
#   '할/Verb',
#   '거/Noun',
#   '다/Josa',
#   './Punctuation',
#   '진짜/Noun',
#   '안/Noun',
#   '살/Noun',
#   '이유/Noun',
#   '가/Josa',
#   '없는데/Adjective',
#   '?/Punctuation',
#   '학생/Noun',
#   '분들/Suffix',
#   '토너/Noun',
#   '이/Determiner',
#   '거/Noun',
#   '쓰세요/Verb',
#   './Punctuation'],
#  ['저렴한/Adjective',
#   '가격/Noun',
#   '인데/Josa',
#   '웬만한/Adjective',
#   '토너/Noun',
#   '못/Noun',
#   '지/Josa',
#   '않게/Verb',
#   '좋습니다/Adjective',
#   './Punctuation',
#   '닥토/Noun',
#   '하기에/Verb',
#   '더/Noun',
#   '좋고/Adjective',
#   '화장/Noun',
#   '솜/Noun',
#   '에/Josa',
#   '듬/Noun',
#   '~/Punctuation',
#   '뿍/Noun',
#   '묻혀서/Verb',
#   '팩/Noun',
#   '하면/Verb',
#   '다음/Noun',
#   '날/Noun',
#   '피부/Noun',
#   '가/Josa',
#   '쫀득/Noun',
#   '해/Verb',
#   '집니다/Verb',
#   './Punctuation',
#   '이름/Noun',
#   '처럼/Josa',
#   '모찌/Noun',
#   '피부/Noun',
#   '가/Josa',
#   '되는/Verb',
#   '것/Noun',
#   '같아요/Adjective',
#   './Punctuation',
#   '저렴한/Adjective',
#   '가격/Noun',
#   '에/Josa',
#   '막/Noun',
#   '쓰고/Verb',
#   '싶은/Verb',
#   '토너/Noun',
#   '로/Josa',
#   '추천/Noun',
#   '합니다/Verb',
#   './Punctuation'],
#  ['저렴해서/Adjective',
#   '좋아요/Adjective',
#   '지성/Noun',
#   '에/Josa',
#   '가까운/Adjective',
#   '복합/Noun',
#   '성/Suffix',
#   '에게는/Josa',
#   '특별히/Adjective',
#   '좋다고/Adjective',
#   '느껴지진/Verb',
#   '않네요/Verb',
#   '환절기/Noun',
#   '에/Josa',
#   '써/Verb',
#   '보겠습니다/Verb'],
#  ['더/Noun',
#   '모/Modifier',
#   '테라/Noun',
#   '피/Noun',
#   '토너/Noun',
#   '알기/Verb',
#   '전/Noun',
#   '까지/Josa',
#   '꾸준히/Adjective',
#   '썼던/Verb',
#   '제품/Noun',
#   '이에요/Josa',
#   '!/Punctuation',
#   '화장/Noun',
#   '솜/Noun',
#   '에/Josa',
#   '듬뿍/Noun',
#   '묻혀서/Verb',
#   '닦아내도/Verb',
#   '좋고/Adjective',
#   '손바닥/Noun',
#   '에/Josa',
#   '덜어서/Verb',
#   '그냥/Noun',
#   '얼굴/Noun',
#   '에/Josa',
#   '막/Noun',
#   '흡수/Noun',
#   '시켜줘도/Verb',
#   '괜찮았어요/Adjective',
#   './Punctuation',
#   '번/Noun',
#   '들거/Verb',
#   '림/Noun',
#   '없이/Adverb',
#   '피부/Noun',
#   '속/Modifier',
#   '건조/Noun',
#   '를/Josa',
#   '잡아주는/Verb',
#   '느낌/Noun',
#   '이라/Josa',
#   '화장/Noun',
#   '전/Noun',
#   '에/Josa',
#   '써도/Verb',
#   '괜찮고/Adjective',
#   '몸/Noun',
#   '에/Josa',
#   '막/Noun',
#   '퍼붓/Verb',
#   '기도/Noun',
#   '좋아서/Adjective',
#   '쭉/Noun',
#   '애용/Noun',
#   '했습니다/Verb',
#   './Punctuation',
#   '더/Noun',
#   '모/Modifier',
#   '테라/Noun',
#   '피/Noun',
#   '토너/Noun',
#   '보다는/Josa',
#   '살짝/Noun',
#   '더/Noun',
#   '쫀쫀/Noun',
#   '하고/Josa',
#   '보습/Noun',
#   '감/Noun',
#   '이/Josa',
#   '느껴지는/Verb',
#   '제/Modifier',
#   '형/Noun',
#   '이에요/Josa',
#   './Punctuation',
#   '지금/Noun',
#   '은/Josa',
#   '더/Noun',
#   '모/Modifier',
#   '테라/Noun',
#   '피/Noun',
#   '에/Josa',
#   '정착/Noun',
#   '해서/Verb',
#   '다시/Noun',
#   '돌아갈/Verb',
#   '일/Noun',
#   '은/Josa',
#   '없지만/Adjective',
#   '.../Punctuation',
#   '가격/Noun',
#   '대비/Noun',
#   '제품/Noun',
#   '력/Suffix',
#   '이/Josa',
#   '월등히/Adjective',
#   '좋기/Adjective',
#   '때문/Noun',
#   '에/Josa',
#   '저렴하게/Adjective',
#   '막/Noun',
#   '쓸/Verb',
#   '토너/Noun',
#   '찾는/Verb',
#   '분/Noun',
#   '들/Suffix',
#   '께/Josa',
#   '추천/Noun',
#   '합니당/Verb',
#   '!/Punctuation'],
#  ['닦/Verb',
#   '토/Noun',
#   '에/Josa',
#   '짱/Noun',
#   ',,/Punctuation',
#   '건조하지도/Adjective',
#   '않고/Verb',
#   '가격/Noun',
#   '도/Josa',
#   '저렴해서/Adjective',
#   '부담/Noun',
#   '없이/Adverb',
#   '팩/Noun',
#   '으로도/Josa',
#   '사용/Noun',
#   '중/Suffix',
#   '입니다/Adjective'],
#  ['가성/Noun',
#   '비/Noun',
#   '좋은/Adjective',
#   '토너/Noun',
#   '예요/Josa',
#   '할인/Noun',
#   '할/Verb',
#   '때/Noun',
#   '쟁/Noun',
#   '여/Josa',
#   '두/Determiner',
#   '고/Modifier',
#   '쓰기/Noun',
#   '너무/Adverb',
#   '좋아요/Adjective',
#   '건성/Noun',
#   '이라/Josa',
#   '일반/Noun',
#   '물/Noun',
#   '토너/Noun',
#   '들/Suffix',
#   '보다/Josa',
#   '좋더라구요/Adjective',
#   '가성/Noun',
#   '비/Noun',
#   '좋으니/Adjective',
#   '그냥/Noun',
#   '막/Noun',
#   '쓰기/Noun',
#   '도/Josa',
#   '좋고/Adjective',
#   '꾸준히/Adjective',
#   '인기/Noun',
#   '있는/Adjective',
#   '이유/Noun',
#   '가/Josa',
#   '있지요/Adjective'],
#  ['가성/Noun',
#   '비/Noun',
#   '좋고/Adjective',
#   '촉촉해서/Adjective',
#   '5/Number',
#   '통정/Noun',
#   '도/Josa',
#   '사용/Noun',
#   '한/Josa',
#   '거/Noun',
#   '같아요/Adjective',
#   '!/Punctuation',
#   '토니모리/Noun',
#   '도/Josa',
#   '기초/Noun',
#   '를/Josa',
#   '잘/VerbPrefix',
#   '한다고/Verb',
#   '느꼈던/Verb',
#   '화장품/Noun',
#   '!/Punctuation'],
#  ['정말/Noun',
#   '20/Number',
#   '대/Verb',
#   '피부/Noun',
#   '건강/Noun',
#   '힐/Noun',
#   '때/Noun',
#   '잘/Verb',
#   '쓴/Verb',
#   '템/Noun',
#   '무난/Noun',
#   '한/Determiner',
#   '데/Noun',
#   '크리미/Noun',
#   '해서/Verb',
#   '겨울/Noun',
#   '에/Josa',
#   '퍽퍽/Noun',
#   '발라/Noun',
#   '2/Number',
#   '중/Noun',
#   '레이어/Noun',
#   '해주면/Verb',
#   '기초/Noun',
#   '크게/Noun',
#   '안해/Noun',
#   '도/Josa',
#   '잘/Verb',
#   '먹/Verb',
#   '템/Noun',
#   '이/Josa',
#   '였음/Verb',
#   '화장/Noun',
#   '솜/Noun',
#   '보다/Josa',
#   '손/Noun',
#   '과/Josa',
#   '궁합/Noun',
#   '이/Josa',
#   '좋고/Adjective',
#   '한번/Noun',
#   '보다/Josa',
#   '두/Determiner',
#   '번/Noun',
#   '세번/Noun',
#   '올리는게/Verb',
#   '이/Noun',
#   '스킨/Noun',
#   '을/Josa',
#   '극대/Noun',
#   '화할/Adjective',
#   '수/Noun',
#   '있음/Adjective'],
#  ['촉촉해요/Adjective',
#   '🤍/Foreign',
#   '보습/Noun',
#   '감/Noun',
#   '이/Josa',
#   '느껴지는/Verb',
#   '토너/Noun',
#   '같긴/Adjective',
#   '한데/Eomi',
#   '워터/Noun',
#   '리/Noun',
#   '한/Josa',
#   '텍스처/Noun',
#   '라서/Josa',
#   '완전/Noun',
#   '산뜻하고/Adjective',
#   '가벼웠어요/Adjective',
#   '전/Noun',
#   '닦/Verb',
#   '토/Noun',
#   '랑/Josa',
#   '스킨/Noun',
#   '팩/Noun',
#   '등/Noun',
#   '으로/Josa',
#   '사용/Noun',
#   '했는데/Verb',
#   '속/Modifier',
#   '건조/Noun',
#   '잡/Noun',
#   '히/Noun',
#   '고/Josa',
#   '그래서/Adverb',
#   '좋았/Adjective',
#   '습/Noun',
#   '니당/Verb',
#   'ㅋㅋㅋ/KoreanParticle'],
#  ['정/Noun',
#   '~~~/Punctuation',
#   '말/Noun',
#   '무난/Noun',
#   '그/Noun',
#   '자체/Noun',
#   '예요/Josa',
#   '가성/Noun',
#   '비/Noun',
#   '훌륭하고요/Adjective',
#   '닦/Verb',
#   '토용/Noun',
#   '으로/Josa',
#   '샀는데/Verb',
#   '닦/Verb',
#   '토/Noun',
#   '는/Josa',
#   '물/Noun',
#   '토너/Noun',
#   '가/Josa',
#   '좋은/Adjective',
#   '듯/Noun',
#   '해서/Verb',
#   '잘/Verb',
#   '맞진/Verb',
#   '않았고/Verb',
#   '건조해서/Adjective',
#   '스킨/Noun',
#   '잔뜩/Noun',
#   '머/Noun',
#   '금고/Noun',
#   '싶을/Verb',
#   '때/Noun',
#   '몸/Noun',
#   '에도/Josa',
#   '무겁지/Adjective',
#   '않게/Verb',
#   '처벅처벅/Adverb',
#   '다/Adverb',
#   '발라/Noun',
#   '버리고/Verb',
#   '싶을/Verb',
#   '때/Noun',
#   '좋습니다/Adjective'],
#  ['완전/Noun',
#   '물/Noun',
#   '같은/Adjective',
#   '제/Modifier',
#   '형도/Noun',
#   '아니고/Adjective',
#   '콧물제형/Noun',
#   '이라/Josa',
#   '금방/Noun',
#   '안/VerbPrefix',
#   '날라가고/Verb',
#   '좋아요/Adjective',
#   '진짜/Noun',
#   '피부/Noun',
#   '쫀쫀/Noun',
#   '해져요/Verb'],
#  ['무난/Noun',
#   '하게/Verb',
#   '쓰기/Noun',
#   '좋은/Adjective',
#   '거/Noun',
#   '같다/Adjective',
#   '이런/Modifier',
#   '말/Noun',
#   '은/Josa',
#   '뭣하/Noun',
#   '지만/Josa',
#   '약간/Noun',
#   '흐르는/Verb',
#   '콧물제/Noun',
#   '형/Suffix',
#   '같다고나/Adjective',
#   '할까/Verb',
#   '유/Noun',
#   '분기도/Noun',
#   '많지/Adjective',
#   '않은거/Verb',
#   '같아서/Adjective',
#   '지성/Noun',
#   '도/Josa',
#   '괜찮을듯/Adjective',
#   '하지만/Conjunction',
#   '건성/Noun',
#   '에/Josa',
#   '가장/Noun',
#   '좋을거/Adjective',
#   '같은/Adjective',
#   '스킨/Noun',
#   '인거/Josa',
#   '같다/Adjective',
#   '향/Noun',
#   '도/Josa',
#   '별/Modifier',
#   '달리/Noun',
#   '없는거/Adjective',
#   '같아서/Adjective',
#   '향/Noun',
#   '에/Josa',
#   '예민한/Adjective',
#   '나/Noun',
#   '는/Josa',
#   '좋은/Adjective',
#   '거/Noun',
#   '같다/Adjective'],
#  ['저렴한/Adjective',
#   '가격/Noun',
#   '에/Josa',
#   '보습/Noun',
#   '력/Suffix',
#   '도/Josa',
#   '좋고/Adjective',
#   '가볍지/Adjective',
#   '않은/Verb',
#   '콧물제형/Noun',
#   '의/Josa',
#   '토너/Noun',
#   '에요/Josa',
#   '!!/Punctuation',
#   '자기/Noun',
#   '전/Noun',
#   '에/Josa',
#   '바르는/Verb',
#   '토너/Noun',
#   '로/Josa',
#   '좋고/Adjective',
#   '수분/Noun',
#   '충전/Noun',
#   '하기에/Verb',
#   '좋은/Adjective',
#   '토너/Noun',
#   '에요/Josa',
#   '뭔가/Noun',
#   '기름/Noun',
#   '이/Josa',
#   '많이/Adverb',
#   '올라오거나/Verb',
#   '너무/Adverb',
#   '더운/Adjective',
#   '날/Noun',
#   '엔/Josa',
#   '쓰기/Noun',
#   '에/Josa',
#   '무겁고/Adjective',
#   '겨울/Noun',
#   '이나/Josa',
#   '건조할/Adjective',
#   '때/Noun',
#   '쓰기/Noun',
#   '더/Noun',
#   '좋은/Adjective',
#   '거/Noun',
#   '같아요/Adjective',
#   '!/Punctuation'],
#  ['가격/Noun',
#   '이/Josa',
#   '저렴하고/Adjective',
#   '수분/Noun',
#   '감/Noun',
#   '과/Josa',
#   '유/Noun',
#   '분/Suffix',
#   '이/Josa',
#   '아주/Noun',
#   '살짝/Noun',
#   '함유/Noun',
#   '된/Verb',
#   '느낌/Noun',
#   '스킨/Noun',
#   '팩/Noun',
#   '하기/Verb',
#   '좋아요/Adjective',
#   './Punctuation'],
#  ['얼굴/Noun',
#   '에/Josa',
#   '열/Modifier',
#   '감/Noun',
#   '도/Josa',
#   '낮춰주고/Verb',
#   '토너/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '이/Josa',
#   '약간/Noun',
#   '쫀쫀/Noun',
#   '한/Josa',
#   '느낌/Noun',
#   '이/Josa',
#   '있어서/Adjective',
#   '얼굴/Noun',
#   '에/Josa',
#   '탄력/Noun',
#   '을/Josa',
#   '탱탱하게/Adjective',
#   '넣어/Verb',
#   '준/Noun',
#   '느낌/Noun',
#   '이/Josa',
#   '듭니/Noun',
#   '다/Josa',
#   '그리고/Conjunction',
#   '유/Noun',
#   '분/Suffix',
#   '감/Noun',
#   '이/Josa',
#   '적당해서/Adjective',
#   '기름/Noun',
#   '지지/Noun',
#   '않고/Verb',
#   '산뜻하게/Adjective',
#   '마무리/Noun',
#   '돼서/Verb',
#   '데/Noun',
#   '일리/Noun',
#   '하게/Verb',
#   '쓰기/Noun',
#   '추천/Noun',
#   '드립니다/Verb'],
#  ['패드/Noun',
#   '로/Josa',
#   '화장/Noun',
#   '전/Noun',
#   '간단하게/Adjective',
#   '팩/Noun',
#   '하는/Verb',
#   '용도/Noun',
#   '로/Josa',
#   '사용/Noun',
#   '하는/Verb',
#   '제품/Noun',
#   '입니다/Adjective',
#   '콧물제형/Noun',
#   '이지만/Josa',
#   '크게/Noun',
#   '끈/Noun',
#   '적/Suffix',
#   '거리/Noun',
#   '진/Noun',
#   '않아서/Verb',
#   '항상/Noun',
#   '사용/Noun',
#   '하고/Josa',
#   '있습니다/Adjective',
#   'ㅎㅎ/KoreanParticle'],
#  ['토니모리/Noun',
#   '인/Josa',
#   '줄/Noun',
#   '모르고/Verb',
#   '올리브영/Noun',
#   '샀는데/Verb',
#   '완전/Noun',
#   '만족해요/Adjective',
#   '촉촉하고/Adjective',
#   '진짜/Noun',
#   '모찌/Noun',
#   '해요/Verb',
#   '건성/Noun',
#   '추천/Noun',
#   '템/Noun',
#   '입니다/Adjective'],
#  ['어린/Verb',
#   '친구/Noun',
#   '들/Suffix',
#   '이/Josa',
#   '사용/Noun',
#   '하기/Verb',
#   '좋은/Adjective',
#   '가성/Noun',
#   '비/Noun',
#   '잡은/Verb',
#   '템/Noun',
#   './Punctuation',
#   '드라마틱한/Adjective',
#   '효과/Noun',
#   '는/Josa',
#   '없지만/Adjective',
#   '촉촉하긴/Adjective',
#   '해/Noun',
#   '요/Josa',
#   './Punctuation',
#   '크림/Noun',
#   '스킨/Noun',
#   '가성/Noun',
#   '비템/Noun',
#   '처럼/Josa',
#   '나온/Verb',
#   '느낌/Noun',
#   '?/Punctuation',
#   '스킨/Noun',
#   '토너/Noun',
#   '화장품/Noun',
#   '효과/Noun',
#   '에/Josa',
#   '큰/Verb',
#   '욕심/Noun',
#   '이/Josa',
#   '없다면/Adjective',
#   '또/Noun',
#   '구매/Noun',
#   '해도/Verb',
#   '좋아요/Adjective',
#   './Punctuation',
#   '양/Noun',
#   '이/Josa',
#   '진짜/Noun',
#   '많아서/Adjective',
#   '낭비하며/Adjective',
#   '써도/Verb',
#   '될/Verb',
#   '정도/Noun',
#   '입니다/Adjective',
#   'ㅋㅋ/KoreanParticle'],
#  ['바르고/Verb',
#   '따가웠어요/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '이/Josa',
#   '약간/Noun',
#   '미끌미끌해서/Adjective',
#   '보습/Noun',
#   '에는/Josa',
#   '좋을듯/Adjective',
#   '합니다/Verb',
#   '바르고나서/Verb',
#   '건조하게/Adjective',
#   '당기는/Verb',
#   '느낌/Noun',
#   '이/Josa',
#   '없어요/Adjective'],
#  ['건성/Noun',
#   '피부/Noun',
#   '에/Josa',
#   '구/Modifier',
#   '원/Modifier',
#   '템/Noun',
#   '입니다/Adjective',
#   'ㅜ/KoreanParticle',
#   'ㅜ/KoreanParticle',
#   'ㅜ/KoreanParticle',
#   '피부관리/Noun',
#   '가/Josa',
#   '너무/Adverb',
#   '귀찮은/Adjective',
#   '프로/Noun',
#   '귀찮러/Adjective',
#   '지만/Josa',
#   '겨울/Noun',
#   '만/Josa',
#   '되면/Verb',
#   '속/Modifier',
#   '건조/Noun',
#   '가/Josa',
#   '미쳐서/Adjective',
#   '피부/Noun',
#   '가/Josa',
#   '진짜/Noun',
#   '쩍쩍/Noun',
#   '갈라진다는/Verb',
#   '느낌/Noun',
#   '을/Josa',
#   '24시간/Number',
#   '내내/Noun',
#   '느끼며/Verb',
#   '../Punctuation',
#   '밖에/Josa',
#   '나가서/Verb',
#   '조금/Noun',
#   '이라도/Josa',
#   '히터/Noun',
#   '바람/Noun',
#   '이/Josa',
#   '얼굴/Noun',
#   '을/Josa',
#   '후려친다/Verb',
#   '?/Punctuation',
#   '그러면/Adverb',
#   '바로/Noun',
#   '사막/Noun',
#   '매/Noun',
#   '마른/Adjective',
#   '땅/Noun',
#   '이/Determiner',
#   '걸/Noun',
#   '랑/Josa',
#   '요/Noun',
#   ';;/Punctuation',
#   '근데/Adverb',
#   '그/Noun',
#   '때/Noun',
#   '나타난/Verb',
#   '구원/Noun',
#   '템/Noun',
#   '../Punctuation',
#   '제/Noun',
#   '가/Josa',
#   '크림/Noun',
#   '이랑/Josa',
#   '크림/Noun',
#   '다/Adverb',
#   '발라/Noun',
#   '봤는데/Verb',
#   '속/Modifier',
#   '건조/Noun',
#   '에는/Josa',
#   '토너/Noun',
#   '더/Noun',
#   '라/Josa',
#   '구/Noun',
#   '여/Josa',
#   '크림/Noun',
#   '아무리/Adverb',
#   '발라/Noun',
#   '봤자/Verb',
#   '속/Noun',
#   '까지/Josa',
#   '침투/Noun',
#   '안되는/Adjective',
#   '느낌/Noun',
#   '아시져/Verb',
#   '그런/Adjective',
#   '사람/Noun',
#   '들/Suffix',
#   '다/Adverb',
#   '들/Verb',
#   '주목/Noun',
#   '../Punctuation',
#   '씻고/Verb',
#   '나오자마자/Verb',
#   '닦/Verb',
#   '토/Noun',
#   '한/Verb',
#   '번/Noun',
#   '하고/Verb',
#   '원하는/Adjective',
#   '촉촉함이/Adjective',
#   '될/Verb',
#   '때/Noun',
#   '까지/Josa',
#   '흡/Exclamation',
#   '토/Noun',
#   '갈겨/Adverb',
#   '주세요/Verb',
#   '!(/Punctuation',
#   '전/Noun',
#   '심할/Adjective',
#   '땐/Noun',
#   '5/Number',
#   '번/Noun',
#   '넘게도/Verb',
#   '합니다/Verb',
#   '..)/Punctuation',
#   '대신/Noun',
#   '완벽하게/Adjective',
#   '흡수/Noun',
#   '될/Verb',
#   '때/Noun',
#   '까지/Josa',
#   '!/Punctuation',
#   '끝나면/Verb',
#   '위/Noun',
#   '에/Josa',
#   '크림/Noun',
#   '덧/Noun',
#   '바르고/Verb',
#   '오일/Noun',
#   '까지/Josa',
#   '하면/Verb',
#   '피부/Noun',
#   '장벽/Noun',
#   '튼/Verb',
#   '튼/Verb',
#   '완벽/Noun',
#   '입니다/Adjective',
#   '심지어/Noun',
#   '대/Modifier',
#   '용량/Noun',
#   '에/Josa',
#   '싸다/Verb',
#   '?/Punctuation',
#   '미치죠/Adjective',
#   '평생/Noun',
#   '팔아주세요/Verb'],
#  ['예전/Noun',
#   '에/Josa',
#   '잘/Verb',
#   '썼던/Verb',
#   '앰플/Noun',
#   '토너/Noun',
#   '가/Josa',
#   '생각나서/Verb',
#   '샀는데/Verb',
#   '확실히/Adjective',
#   '좋/Adjective',
#   '네/Determiner',
#   '용/Noun',
#   '이름/Noun',
#   '을/Josa',
#   '정말/Noun',
#   '잘/Verb',
#   '붙인/Verb',
#   '게/Noun',
#   '첫/Modifier',
#   '단계/Noun',
#   '부터/Josa',
#   '보습/Noun',
#   '이/Josa',
#   '되서/Verb',
#   '피붓결/Noun',
#   '이/Josa',
#   '모찌/Noun',
#   '처럼/Josa',
#   '촵챱/Noun',
#   '부드러워져요/Adjective',
#   '피부/Noun',
#   '결/Noun',
#   '정리/Noun',
#   '되는/Verb',
#   '게/Noun',
#   '제일/Noun',
#   '좋았던/Adjective',
#   '점/Noun',
#   '인/Josa',
#   '거/Noun',
#   '같아요/Adjective',
#   '다만/Noun',
#   '겨울/Noun',
#   '이/Josa',
#   '지나서/Verb',
#   '그런지/Adjective',
#   '좀/Noun',
#   '더/Noun',
#   '유/Noun',
#   '분기/Noun',
#   '가/Josa',
#   '올라오는/Verb',
#   '느낌/Noun',
#   'ㅠ/KoreanParticle',
#   '이/Noun',
#   '없지/Adjective',
#   '않아/Verb',
#   '있어서/Adjective',
#   '요즘/Noun',
#   '은/Josa',
#   '손/Noun',
#   '이/Josa',
#   '잘/Verb',
#   '안/VerbPrefix',
#   '가네용/Verb',
#   ',,/Punctuation',
#   '겨울/Noun',
#   '에/Josa',
#   '춥고/Verb',
#   '건조하고/Adjective',
#   '히터/Noun',
#   '틀어서/Verb',
#   '피부/Noun',
#   '가/Josa',
#   '자꾸/Noun',
#   '텃/Noun',
#   '을/Josa',
#   '때/Noun',
#   '는/Josa',
#   '기초/Noun',
#   '부터/Josa',
#   '촉촉하게/Adjective',
#   '잡아줘서/Verb',
#   '너무/Adverb',
#   '잘/Verb',
#   '썼긴/Verb',
#   '합니당/Verb',
#   '건조해서/Adjective',
#   '피부/Noun',
#   '가/Josa',
#   '예민해져있을/Adjective',
#   '때/Noun',
#   '는/Josa',
#   '진정/Noun',
#   '효과/Noun',
#   '도/Josa',
#   '봤어요/Verb',
#   '제/Modifier',
#   '형/Noun',
#   '은/Josa',
#   '물/Noun',
#   '토너/Noun',
#   '보다는/Josa',
#   '좀/Noun',
#   '더/Noun',
#   '점성/Noun',
#   '이/Josa',
#   '있는/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '인데/Josa',
#   '또/Noun',
#   '발릴/Verb',
#   '때/Noun',
#   '는/Josa',
#   '물/Noun',
#   '처럼/Josa',
#   '발려요/Verb',
#   '전/Noun',
#   '향/Noun',
#   '이/Josa',
#   '되게/Adverb',
#   '좋았는데/Adjective',
#   '뭔가/Noun',
#   '새/Modifier',
#   '콤/Noun',
#   '한/Josa',
#   '?/Punctuation',
#   '화장품/Noun',
#   '향/Noun',
#   '이/Josa',
#   '납니다/Verb',
#   '근데/Adverb',
#   '전혀/Noun',
#   '거부/Noun',
#   '감/Noun',
#   '들만/Verb',
#   '한/Determiner',
#   '향/Noun',
#   '이/Josa',
#   '아니라서/Adjective',
#   '오히려/Noun',
#   '좋았어요/Adjective',
#   '제/Noun',
#   '가/Josa',
#   '수/Modifier',
#   '부지/Noun',
#   '라/Josa',
#   '그런지/Adjective',
#   '날씨/Noun',
#   '가/Josa',
#   '더워지니까/Verb',
#   '좀/Noun',
#   '기름기/Noun',
#   '가/Josa',
#   '올라오는/Verb',
#   '거/Noun',
#   '같아/Adjective',
#   '요즘/Noun',
#   '은/Josa',
#   '안/Noun',
#   '사용/Noun',
#   '하/Suffix',
#   '지만/Josa',
#   '겨울/Noun',
#   '에는/Josa',
#   '잘/Verb',
#   '썼던/Verb',
#   '제품/Noun',
#   '이에요/Josa',
#   '건성/Noun',
#   '분/Noun',
#   '들/Suffix',
#   '은/Josa',
#   '사계절/Noun',
#   '내내/Noun',
#   '잘/Verb',
#   '쓰실/Verb',
#   '것/Noun',
#   '같다고/Adjective',
#   '느꼈/Verb',
#   '습/Noun',
#   '니당/Verb',
#   '흡/Exclamation',
#   '토/Noun',
#   '나/Josa',
#   '팩토/Noun',
#   '추천/Noun',
#   '해요/Verb',
#   '!!/Punctuation'],
#  ['✔️/Foreign',
#   '피부/Noun',
#   '타입/Noun',
#   ':/Punctuation',
#   '중건/Noun',
#   '성/Suffix',
#   '//Punctuation',
#   '속/Modifier',
#   '건조/Noun',
#   '//Punctuation',
#   '민감/Noun',
#   '성/Suffix',
#   '피부/Noun',
#   '✔️/Foreign',
#   '제/Modifier',
#   '형/Noun',
#   ':/Punctuation',
#   '물/Noun',
#   '스킨/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '✔️/Foreign',
#   '발림/Noun',
#   '성/Suffix',
#   ':/Punctuation',
#   '촉촉하게/Adjective',
#   '잘/Verb',
#   '발려요/Verb',
#   './Punctuation',
#   '✔️/Foreign',
#   '제품/Noun',
#   '설명/Noun',
#   ':/Punctuation',
#   '-/Punctuation',
#   '세/Modifier',
#   '라마/Noun',
#   '이드/Noun',
#   '5,000/Number',
#   'ppb/Alpha',
#   '함유/Noun',
#   '-/Punctuation',
#   '보습/Noun',
#   '+/Punctuation',
#   '영양/Noun',
#   '+/Punctuation',
#   '진정/Noun',
#   '(/Punctuation',
#   '히알루론산/Noun',
#   '&/Punctuation',
#   '판테/Verb',
#   '놀/Noun',
#   '&/Punctuation',
#   '병풀/Noun',
#   '추출/Noun',
#   '물/Noun',
#   ')/Punctuation',
#   '-/Punctuation',
#   '민감/Noun',
#   '성/Suffix',
#   '피부/Noun',
#   '자극/Noun',
#   '테스트/Noun',
#   '완료/Noun',
#   '-/Punctuation',
#   '인공/Noun',
#   '향료/Noun',
#   '//Punctuation',
#   '인공/Noun',
#   '색소/Noun',
#   '//Punctuation',
#   '동물성/Noun',
#   '원료/Noun',
#   '//Punctuation',
#   'PEG/Alpha',
#   '계면활성제/Noun',
#   'X/Alpha',
#   '-/Punctuation',
#   '화해/Noun',
#   '2년/Number',
#   '연속/Noun',
#   '위너/Noun',
#   ',/Punctuation',
#   '글/Noun',
#   '로우/Noun',
#   '픽/Noun',
#   '위너/Noun',
#   '선정/Noun',
#   ',/Punctuation',
#   '올리브영/Noun',
#   '실시간/Noun',
#   '랭킹/Noun',
#   '1/Number',
#   '위/Noun',
#   '달성/Noun',
#   '✔️/Foreign',
#   '사/Modifier',
#   '용감/Noun',
#   ':/Punctuation',
#   '모찌/Noun',
#   '비건/Noun',
#   '토너/Noun',
#   '를/Josa',
#   '잘/Verb',
#   '사용/Noun',
#   '했는데/Verb',
#   ',/Punctuation',
#   '오/Modifier',
#   '리지/Noun',
#   '널/Noun',
#   '세/Modifier',
#   '라마/Noun',
#   '이드/Noun',
#   '비건/Noun',
#   '토너/Noun',
#   '도/Josa',
#   '사용/Noun',
#   '해보았어요/Verb',
#   '!/Punctuation',
#   '두/Noun',
#   '제품/Noun',
#   '을/Josa',
#   '비교/Noun',
#   '했을/Verb',
#   '때/Noun',
#   '모찌/Noun',
#   '비건/Noun',
#   '토너/Noun',
#   '는/Josa',
#   '점성/Noun',
#   '있는/Adjective',
#   '콧물/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '이/Determiner',
#   '라면/Noun',
#   ',/Punctuation',
#   '오/Modifier',
#   '리지/Noun',
#   '널/Noun',
#   '세/Modifier',
#   '라마/Noun',
#   '이드/Noun',
#   '비건/Noun',
#   '토너/Noun',
#   '는/Josa',
#   '좀/Noun',
#   '더/Noun',
#   '묽은/Adjective',
#   '물/Noun',
#   '스킨/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '이라서/Josa',
#   '닦/Verb',
#   '토/Noun',
#   '나/Josa',
#   '7/Number',
#   '스킨/Noun',
#   '법/Noun',
#   '활용/Noun',
#   '도/Josa',
#   '가능해요/Adjective',
#   '~/Punctuation',
#   '모찌/Noun',
#   '비건/Noun',
#   '토너/Noun',
#   '가/Josa',
#   '영/Modifier',
#   '양감/Noun',
#   '이/Josa',
#   '더/Noun',
#   '느껴지는/Verb',
#   '겨울/Noun',
#   '용이/Noun',
#   '라면/Noun',
#   ',/Punctuation',
#   '세/Modifier',
#   '라마/Noun',
#   '이드/Noun',
#   '모찌/Noun',
#   '토너/Noun',
#   '는/Josa',
#   '사계절/Noun',
#   '사용/Noun',
#   '하기/Verb',
#   '좋을/Adjective',
#   '것/Noun',
#   '같아요/Adjective',
#   '!/Punctuation',
#   '끈/Noun',
#   '적/Suffix',
#   '이지/Josa',
#   '않고/Verb',
#   '금세/Noun',
#   '흡수/Noun',
#   '되면서/Verb',
#   '촉촉함이/Adjective',
#   '느껴져요/Verb',
#   './Punctuation',
#   '자극/Noun',
#   '없이/Adverb',
#   '순하고/Adjective',
#   ',/Punctuation',
#   '피부/Noun',
#   '가/Josa',
#   '진정/Noun',
#   '되는/Verb',
#   '느낌/Noun',
#   '이에요/Josa',
#   '~/Punctuation',
#   '대/Modifier',
#   '용량/Noun',
#   '토너/Noun',
#   '라/Josa',
#   '부담/Noun',
#   '없이/Adverb',
#   '듬뿍/Noun',
#   '바를/Verb',
#   '수/Noun',
#   '있어/Adjective',
#   '좋아요/Adjective',
#   '!/Punctuation',
#   '닦/Verb',
#   '토/Noun',
#   '//Punctuation',
#   '7/Number',
#   '스킨/Noun',
#   '법/Noun',
#   '//Punctuation',
#   '스킨/Noun',
#   '팩/Noun',
#   '//Punctuation',
#   '미스트/Noun',
#   '로/Josa',
#   '활용/Noun',
#   '가능해요/Adjective',
#   './Punctuation',
#   '✔/Foreign',
#   '성분/Noun',
#   '//Punctuation',
#   '트러블/Noun',
#   '유무/Noun',
#   ':/Punctuation',
#   '모공/Noun',
#   '막는/Verb',
#   '성분/Noun',
#   '이나/Josa',
#   '티/Noun',
#   '트리/Noun',
#   '성분/Noun',
#   '에/Josa',
#   '민감한/Adjective',
#   '피부/Noun',
#   '이고/Josa',
#   ',/Punctuation',
#   '안/VerbPrefix',
#   '맞으면/Verb',
#   '바로/Noun',
#   '알러지/Noun',
#   '가/Josa',
#   '나/Noun',
#   '는/Josa',
#   '예민한/Adjective',
#   '피부/Noun',
#   '에요/Josa',
#   '~/Punctuation',
#   '민감/Noun',
#   '성/Suffix',
#   '피부/Noun',
#   '자극/Noun',
#   '테스트/Noun',
#   '를/Josa',
#   '완료/Noun',
#   '한/Josa',
#   '제품/Noun',
#   '답/Noun',
#   '게/Josa',
#   '트러블/Noun',
#   '이/Josa',
#   '없었고/Adjective',
#   '순하게/Adjective',
#   '느껴졌어요/Verb',
#   './Punctuation'],
#  ['저렴하고/Adjective',
#   '양/Noun',
#   '많고/Adjective',
#   '가성/Noun',
#   '비/Noun',
#   '좋아요/Adjective',
#   './Punctuation',
#   '흡수/Noun',
#   '잘/VerbPrefix',
#   '되고/Verb',
#   '스킨/Noun',
#   '레이어/Noun',
#   '링/Noun',
#   '하/Suffix',
#   '면/Josa',
#   '쫀득/Noun',
#   '한/Josa',
#   '피부/Noun',
#   '되어요/Verb',
#   './Punctuation',
#   '대학생/Noun',
#   '때/Noun',
#   '인터넷/Noun',
#   '으로/Josa',
#   '대/Modifier',
#   '용량/Noun',
#   '으로/Josa',
#   '많이/Adverb',
#   '샀던/Verb',
#   '기억/Noun',
#   '이/Josa',
#   '있어요/Adjective',
#   '!/Punctuation'],
#  ['대/Modifier',
#   '용량/Noun',
#   '에/Josa',
#   '쫀득/Noun',
#   '한/Josa',
#   '제/Modifier',
#   '형/Noun',
#   ',/Punctuation',
#   '그리고/Conjunction',
#   '합리/Noun',
#   '적/Suffix',
#   '인/Josa',
#   '가격/Noun',
#   '까지/Josa',
#   '특별히/Adjective',
#   '부족함/Noun',
#   '없는/Adjective',
#   '제품/Noun',
#   '입니다/Adjective',
#   './Punctuation',
#   '베스트셀러/Noun',
#   '인데/Josa',
#   '는/Verb',
#   '다/Adverb',
#   '이유/Noun',
#   '가/Josa',
#   '있는거/Adjective',
#   '같아요/Adjective',
#   '!/Punctuation',
#   '꾸/Verb',
#   '덕/Noun',
#   '하/Suffix',
#   '지도/Noun',
#   '너무/Adverb',
#   '묽지도/Adjective',
#   '않아/Verb',
#   '넘/Verb',
#   '만족합니다/Adjective',
#   '!/Punctuation'],
#  ['진짜/Noun',
#   '저렴한/Adjective',
#   '가격/Noun',
#   '에/Josa',
#   '잘/Verb',
#   '쓰고/Verb',
#   '있어요/Adjective',
#   './Punctuation',
#   '토너/Noun',
#   '는/Josa',
#   '성분/Noun',
#   '이/Josa',
#   '다/Adverb',
#   '비슷하다고/Adjective',
#   '하서/Noun',
#   '가격/Noun',
#   '저렴한/Adjective',
#   '것/Noun',
#   '으로/Josa',
#   '골랐어요/Verb',
#   './Punctuation'],
#  ['샵/Noun',
#   '에서/Josa',
#   '쓰는/Verb',
#   '템/Noun',
#   '이라길래/Verb',
#   '정말/Noun',
#   '믿고/Verb',
#   '쓰는/Verb',
#   '템/Noun',
#   '일단/Noun',
#   '가성/Noun',
#   '비/Noun',
#   '가/Josa',
#   '좋은/Adjective',
#   '게/Noun',
#   '최대/Noun',
#   '장점/Noun',
#   '!!!/Punctuation',
#   '수분/Noun',
#   '감/Noun',
#   '많아서/Adjective',
#   '좋고/Adjective',
#   '팩토/Noun',
#   '하/Suffix',
#   '자마자/Noun',
#   '얼굴/Noun',
#   '이/Josa',
#   '시원해지는게/Adjective',
#   '정말/Noun',
#   '얼굴/Noun',
#   '로/Josa',
#   '느껴짐/Verb',
#   '!!!!/Punctuation',
#   '그래서/Adverb',
#   '정말/Noun',
#   '잘/Verb',
#   '사용/Noun',
#   '합니다/Verb',
#   '…../Punctuation',
#   '❤️/Foreign',
#   '토니모리/Noun',
#   '사랑/Noun',
#   '합니다/Verb',
#   '……/Punctuation',
#   '정말루/Noun',
#   '…./Punctuation'],
#  ['가격/Noun',
#   '대비/Noun',
#   '대/Modifier',
#   '용량/Noun',
#   '으로/Josa',
#   '너무/Adverb',
#   '대/Modifier',
#   '만족/Noun',
#   '이에요/Josa',
#   '화장/Noun',
#   '수/Noun',
#   '에/Josa',
#   '듬뿍/Noun',
#   '적셔서/Verb',
#   '올려/Verb',
#   '두면/Verb',
#   '팩/Noun',
#   '대용/Noun',
#   '으로도/Josa',
#   '좋고/Adjective',
#   '화장/Noun',
#   '정말/Noun',
#   '잘/Verb',
#   '먹습니다/Verb',
#   '!/Punctuation'],
#  ['초대/Noun',
#   '용량/Noun',
#   '인데/Josa',
#   '가격/Noun',
#   '도/Josa',
#   '저렴해서/Adjective',
#   '정말/Noun',
#   '가성/Noun',
#   '비/Noun',
#   '갑/Noun',
#   '이에요/Josa',
#   '!/Punctuation',
#   '조금/Noun',
#   '아쉬운/Adjective',
#   '점/Noun',
#   '은/Josa',
#   '주로/Noun',
#   '토너/Noun',
#   '팩/Noun',
#   '을/Josa',
#   '하려고/Verb',
#   '구매/Noun',
#   '했는데/Verb',
#   ',/Punctuation',
#   '이/Noun',
#   '토너/Noun',
#   '로/Josa',
#   '팩/Noun',
#   '을/Josa',
#   '하고/Verb',
#   '나면/Verb',
#   '수분/Noun',
#   '공급/Noun',
#   '은/Josa',
#   '되지만/Verb',
#   '겉도/Noun',
#   '는/Josa',
#   '유/Noun',
#   '분/Suffix',
#   '이/Josa',
#   '좀/Noun',
#   '많아서/Adjective',
#   '화장/Noun',
#   '전/Noun',
#   '에/Josa',
#   '하기는/Adverb',
#   '어려워요/Adjective',
#   'ㅠ/KoreanParticle',
#   '그렇지만/Conjunction',
#   '대/Modifier',
#   '용량/Noun',
#   ',/Punctuation',
#   '수분/Noun',
#   '공급/Noun',
#   ',/Punctuation',
#   '피부/Noun',
#   '를/Josa',
#   '쫀쫀하/Noun',
#   '게/Josa',
#   '만/Noun',
#   '들어준다는/Verb',
#   '점/Noun',
#   '이/Josa',
#   '만족스럽기에/Adjective',
#   '4/Number',
#   '점/Noun',
#   '을/Josa',
#   '드립니다/Verb',
#   '!/Punctuation'],
#  ['일단/Noun',
#   '대/Modifier',
#   '용량/Noun',
#   '에/Josa',
#   '합리/Noun',
#   '적/Suffix',
#   '인/Josa',
#   '가격/Noun',
#   '으로/Josa',
#   '부담/Noun',
#   '이/Josa',
#   '없어서/Adjective',
#   '좋았어요/Adjective',
#   './Punctuation',
#   '스킨/Noun',
#   '팩/Noun',
#   '할/Verb',
#   '때/Noun',
#   '용량/Noun',
#   '적고/Verb',
#   '비싼/Adjective',
#   '토너/Noun',
#   '는/Josa',
#   '쓰기/Noun',
#   '아까운데/Adjective',
#   '이/Noun',
#   '제품/Noun',
#   '은/Josa',
#   '대/Modifier',
#   '용량/Noun',
#   '이라/Josa',
#   '팍팍/Adverb',
#   '써도/Verb',
#   '안/Noun',
#   '아깝고/Adjective',
#   '스킨/Noun',
#   '팩/Noun',
#   '해주고/Verb',
#   '나면/Verb',
#   '피부/Noun',
#   '가/Josa',
#   '시원해지고/Adjective',
#   '촉촉해져요/Adjective',
#   './Punctuation',
#   '평소/Noun',
#   '에/Josa',
#   '기초/Noun',
#   '케어/Noun',
#   '할/Verb',
#   '때/Noun',
#   '도/Josa',
#   '두/Determiner',
#   '세번/Noun',
#   '정도/Noun',
#   '흡수/Noun',
#   '시켜주면/Verb',
#   '이/Noun',
#   '제품/Noun',
#   '이랑/Josa',
#   '크림/Noun',
#   '만/Josa',
#   '발라/Noun',
#   '도/Josa',
#   '피부/Noun',
#   '가/Josa',
#   '건조하지/Adjective',
#   '않았어요/Verb',
#   './Punctuation',
#   '앰플/Noun',
#   '까지/Josa',
#   '써주면/Verb',
#   '말/Noun',
#   '그대로/Noun',
#   '모찌/Noun',
#   '모찌/Noun',
#   '한/Josa',
#   '피부/Noun',
#   '완성/Noun',
#   'ㅎㅎ/KoreanParticle',
#   '미스트/Noun',
#   '공병/Noun',
#   '에/Josa',
#   '담아서/Verb',
#   '틈틈이/Noun',
#   '뿌려줘도/Verb',
#   '좋아요/Adjective',
#   './Punctuation',
#   '화장/Noun',
#   '한/Josa',
#   '후/Noun',
#   '에는/Josa',
#   '뿌리/Noun',
#   '면/Josa',
#   '무너질/Verb',
#   '수/Noun',
#   '있으니/Adjective',
#   '저/Noun',
#   '는/Josa',
#   '집/Noun',
#   '에서/Josa',
#   '생각날/Verb',
#   '때/Noun',
#   '마다/Josa',
#   '미스트/Noun',
#   '처럼/Josa',
#   '뿌리는데/Verb',
#   '이렇게/Adverb',
#   '매주/Adverb',
#   '하다/Verb',
#   '보면/Verb',
#   '피부/Noun',
#   '가/Josa',
#   '촉촉하고/Adjective',
#   '부드러워져요/Adjective',
#   './Punctuation',
#   '그런데/Conjunction',
#   '이렇게/Adverb',
#   '마구/Noun',
#   '팩/Noun',
#   '하고/Josa',
#   '바르고/Verb',
#   '뿌려도/Verb',
#   '용량/Noun',
#   '이/Josa',
#   '많아서/Adjective',
#   '오래오래/Noun',
#   '쓸/Verb',
#   '수/Noun',
#   '있다는/Adjective',
#   '점/Noun',
#   '.../Punctuation',
#   '기/Modifier',
#   '본/Modifier',
#   '템/Noun',
#   '처럼/Josa',
#   '계속/Noun',
#   '재구매/Verb',
#   '하면서/Verb',
#   '쓰게/Verb',
#   '되는/Verb',
#   '제품/Noun',
#   '이에요/Josa'],
#  ['기대/Noun',
#   '안/VerbPrefix',
#   '했는데/Verb',
#   '생각/Noun',
#   '보다/Josa',
#   '속/Modifier',
#   '건조/Noun',
#   '를/Josa',
#   '잘/Verb',
#   '잡아줘서/Verb',
#   '환절기/Noun',
#   '에/Josa',
#   '쓰기/Noun',
#   '좋은/Adjective',
#   '제품/Noun',
#   '이었습니다/Verb',
#   '끈/Noun',
#   '적거/Verb',
#   '림/Noun',
#   '도/Josa',
#   '없어서/Adjective',
#   '닦/Verb',
#   '토/Noun',
#   '해도/Noun',
#   '괜찮았어요/Adjective',
#   '촉촉한/Adjective',
#   '토너/Noun',
#   '찾으시는/Verb',
#   '분/Noun',
#   '들/Suffix',
#   '한테/Josa',
#   '추천/Noun',
#   '해요/Verb'],
#  ['☁/Foreign',
#   '피부/Noun',
#   '가/Josa',
#   '살짝/Noun',
#   '민감한/Adjective',
#   '편/Noun',
#   '인데/Josa',
#   '가렵거/Noun',
#   '나/Josa',
#   '피부/Noun',
#   '에/Josa',
#   '뭐/Noun',
#   '가/Josa',
#   '올라오지/Verb',
#   '않았어요/Verb',
#   '!/Punctuation',
#   '☁/Foreign',
#   '쫀존/Noun',
#   '한/Josa',
#   '하고/Verb',
#   '피부/Noun',
#   '를/Josa',
#   '촉촉하게/Adjective',
#   '유지/Noun',
#   '시켜줘요/Verb',
#   './Punctuation',
#   '☁/Foreign',
#   '물/Noun',
#   '같은/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '토너/Noun',
#   '를/Josa',
#   '선호/Noun',
#   '하는데/Verb',
#   '제/Modifier',
#   '형도/Noun',
#   '만족했어요/Adjective',
#   '☁/Foreign',
#   '가격/Noun',
#   '도/Josa',
#   '저렴하고/Adjective',
#   '양도/Noun',
#   '많아서/Adjective',
#   '팍팍/Adverb',
#   '쓰기/Noun',
#   '넘/Verb',
#   '좋았어용/Adjective',
#   '¨̮/Foreign'],
#  ['이/Determiner',
#   '토너/Noun',
#   '만/Josa',
#   '쓰면/Verb',
#   '톤/Noun',
#   '업되/Verb',
#   '고/Noun',
#   '맑아져요/Adjective',
#   '평생/Noun',
#   '쓰/Verb',
#   '고픈/Adjective',
#   '토너/Noun',
#   '입니당/Adjective',
#   '추천/Noun',
#   '해요/Verb'],
#  ['수/Modifier',
#   '부지/Noun',
#   '라/Josa',
#   '수분/Noun',
#   '토너/Noun',
#   '가/Josa',
#   '필수/Noun',
#   '인데/Josa',
#   '독도/Noun',
#   '토너/Noun',
#   '로/Josa',
#   '챱챱/Noun',
#   '발라/Noun',
#   '주기도/Noun',
#   '하고/Verb',
#   '스킨/Noun',
#   '팩/Noun',
#   '하/Suffix',
#   '기도/Noun',
#   '좋고/Adjective',
#   '활용/Noun',
#   '성/Suffix',
#   '이/Josa',
#   '좋은/Adjective',
#   '스킨/Noun',
#   '입니다/Adjective',
#   './Punctuation'],
#  ['For/Alpha',
#   'me/Alpha',
#   'it/Alpha',
#   '’/Punctuation',
#   's/Alpha',
#   'just/Alpha',
#   'a/Alpha',
#   'toner/Alpha',
#   './Punctuation',
#   'I/Alpha',
#   'haven/Alpha',
#   '’/Punctuation',
#   't/Alpha',
#   'noticed/Alpha',
#   'any/Alpha',
#   'skin/Alpha',
#   'changes/Alpha',
#   'or/Alpha',
#   'improvements/Alpha',
#   './Punctuation',
#   'I/Alpha',
#   'was/Alpha',
#   'using/Alpha',
#   'it/Alpha',
#   'just/Alpha',
#   'a/Alpha',
#   'step/Alpha',
#   'of/Alpha',
#   'a/Alpha',
#   'skin/Alpha',
#   'care/Alpha',
#   './Punctuation',
#   'I/Alpha',
#   'cannot/Alpha',
#   'say/Alpha',
#   'I/Alpha',
#   'would/Alpha',
#   'buy/Alpha',
#   'it/Alpha',
#   'again/Alpha',
#   './Punctuation',
#   'But/Alpha',
#   'it/Alpha',
#   'was/Alpha',
#   'just/Alpha',
#   'fine/Alpha',
#   'to/Alpha',
#   'use/Alpha',
#   'it/Alpha',
#   'once/Alpha',
#   './Punctuation'],
#  ['독도/Noun',
#   '토너/Noun',
#   '유명해서/Adjective',
#   '한번/Noun',
#   '구매/Noun',
#   '해봤어요/Verb',
#   '!!!!/Punctuation',
#   '속/Modifier',
#   '건조/Noun',
#   '잡아주고/Verb',
#   '촉촉하니/Adjective',
#   '좋아용/Adjective',
#   '왜/Noun',
#   '유명한지/Adjective',
#   '알/Noun',
#   '것/Noun',
#   '같은/Adjective',
#   '..../Punctuation',
#   '!!!!!/Punctuation',
#   '라운드/Noun',
#   '랩/Noun',
#   '토너/Noun',
#   '짱/VerbPrefix',
#   '입니당/Adjective',
#   '❤️❤️❤️❤️/Foreign'],
#  ['아이/Noun',
#   '가/Josa',
#   '독도/Noun',
#   '토너/Noun',
#   '가/Josa',
#   '여름/Noun',
#   '에/Josa',
#   '좋다고/Adjective',
#   '사/Modifier',
#   '달래/Noun',
#   '서/Josa',
#   '사용/Noun',
#   '중/Suffix',
#   '인데/Josa',
#   '벌써/Noun',
#   '4/Number',
#   '통째/Noun',
#   '사용/Noun',
#   '중/Suffix',
#   '이에요/Josa',
#   '!/Punctuation',
#   '아주/Noun',
#   '순하고/Adjective',
#   '저/Determiner',
#   '자극/Noun',
#   '이라/Josa',
#   '사춘기/Noun',
#   '아이/Noun',
#   '들/Suffix',
#   '사용/Noun',
#   '하기/Verb',
#   '좋네요/Adjective',
#   '!/Punctuation'],
#  ['매우/Noun',
#   '묽은/Adjective',
#   '토너/Noun',
#   '인데/Josa',
#   '피부/Noun',
#   '에/Josa',
#   '쫙/Noun',
#   '흡수/Noun',
#   '되는/Verb',
#   '느낌/Noun',
#   '이라/Josa',
#   '여러/Modifier',
#   '겹/Noun',
#   '발라/Noun',
#   '주기도/Noun',
#   '좋고/Adjective',
#   '피부/Noun',
#   '속/Noun',
#   '까지/Josa',
#   '보습/Noun',
#   '을/Josa',
#   '해주는/Verb',
#   '느낌/Noun',
#   '이라서/Josa',
#   '속/Modifier',
#   '건조/Noun',
#   '에/Josa',
#   '효과/Noun',
#   '적/Suffix',
#   '인/Josa',
#   '제품/Noun',
#   '인/Josa',
#   '것/Noun',
#   '같아요/Adjective',
#   './Punctuation',
#   '솜/Noun',
#   '에/Josa',
#   '뿌려서/Verb',
#   '팩/Noun',
#   '처럼/Josa',
#   '해주기도/Verb',
#   '좋아요/Adjective',
#   '용량/Noun',
#   '이/Josa',
#   '커서/Noun',
#   '더/Noun',
#   '좋아요/Adjective'],
#  ['완전/Noun',
#   '물/Noun',
#   '같은/Adjective',
#   '토너/Noun',
#   '입니다/Adjective',
#   '끈/Noun',
#   '적/Suffix',
#   '이지/Josa',
#   '않는/Verb',
#   '산뜻한/Adjective',
#   '사/Modifier',
#   '용감/Noun',
#   '이고/Josa',
#   '토너/Noun',
#   '가/Josa',
#   '촉촉하고/Adjective',
#   '피부/Noun',
#   '에/Josa',
#   '흡수/Noun',
#   '가/Josa',
#   '잘/Verb',
# ...
#   '피부/Noun',
#   '가/Josa',
#   '촉촉해져서/Adjective',
#   '겨울/Noun',
#   '나이트/Noun',
#   '케어/Noun',
#   '로/Josa',
#   '딱인것/Adjective',
#   '같아요/Adjective',
#   '가벼운/Adjective',
#   '사/Modifier',
#   '용감/Noun',
#   '좋아하시거나/Adjective',
#   '메이크업/Noun',
#   '전/Noun',
#   '에/Josa',
#   '바르/Verb',
#   '기/Noun',
#   '에는/Josa',
#   '조금/Noun',
#   '리치/Noun',
#   '한/Josa',
#   '느낌/Noun',
#   '이고/Josa',
#   '산뜻한/Adjective',
#   '마무리/Noun',
#   '감은/Verb',
#   '아니라서/Adjective',
#   '취향/Noun',
#   '탈것/Noun',
#   '같은데/Adjective',
#   '저/Noun',
#   '는/Josa',
#   '워낙/Noun',
#   '건조/Noun',
#   '한편/Noun',
#   '이라/Josa',
#   '너무/Adverb',
#   '만족하면서/Adjective',
#   '사용/Noun',
#   '중이/Noun',
#   '예요/Josa',
#   '!!/Punctuation',
#   'ㅎㅎ/KoreanParticle',
#   '지성/Noun',
#   '분들/Suffix',
#   '보다는/Josa',
#   '건성/Noun',
#   '분들/Suffix',
#   '에게/Josa',
#   '추천/Noun',
#   '합니다/Verb'],
#  ['진짜/Noun',
#   '너무/Adverb',
#   '아쉬운/Adjective',
#   '게/Noun',
#   '제품/Noun',
#   '은/Josa',
#   '너무/Adverb',
#   '좋은데/Adjective',
#   '제/Noun',
#   '피부/Noun',
#   '랑/Josa',
#   '안/Noun',
#   '맞는/Verb',
#   '성분/Noun',
#   '이/Josa',
#   '있는지/Adjective',
#   '이/Determiner',
#   '것/Noun',
#   '만/Josa',
#   '바르면/Verb',
#   '뭐/Noun',
#   '가/Josa',
#   '나/Noun',
#   '는/Josa',
#   '것/Noun',
#   '같아요/Adjective',
#   '.../Punctuation',
#   'ㅠ/KoreanParticle',
#   '엄청/Adverb',
#   '쫀쫀해/Noun',
#   '서/Josa',
#   '속/Modifier',
#   '건조/Noun',
#   '다/Adverb',
#   '잡아주고/Verb',
#   '흡수/Noun',
#   '되면/Verb',
#   '피부/Noun',
#   '에서/Josa',
#   '광/Noun',
#   '이/Josa',
#   '나요/Eomi',
#   './Punctuation',
#   '진짜/Noun',
#   '촉촉해요/Adjective',
#   './Punctuation',
#   '뭘/Noun',
#   '발라/Noun',
#   '도/Josa',
#   '건조한/Adjective',
#   '날/Noun',
#   '이/Determiner',
#   '거/Noun',
#   '하나로/Noun',
#   '해결/Noun',
#   '됩니다/Verb',
#   './Punctuation',
#   '성분/Noun',
#   '잘/Verb',
#   '맞는/Verb',
#   '분/Noun',
#   '들께는/Verb',
#   '겨울철/Noun',
#   '인생/Noun',
#   '템일/Noun',
#   '듯/Noun',
#   '.(/Punctuation',
#   '부럽습니다/Adjective',
#   'ㅜㅜ/KoreanParticle',
#   ')/Punctuation'],
#  ['굉장히/Adjective',
#   '찐/Verb',
#   '덕/Noun',
#   '거리/Noun',
#   '는/Josa',
#   '제/Modifier',
#   '형/Noun',
#   '이라/Josa',
#   '보습/Noun',
#   '감/Noun',
#   '에는/Josa',
#   '좋을/Adjective',
#   '듯/Noun',
#   '하나/Noun',
#   '마무리/Noun',
#   '감/Noun',
#   '이/Josa',
#   '개인/Noun',
#   '적/Suffix',
#   '인/Josa',
#   '취향/Noun',
#   '이/Josa',
#   '아니라/Adjective',
#   '잘/Verb',
#   '사용/Noun',
#   '하지/Verb',
#   '않았다/Verb',
#   './Punctuation',
#   '겨울/Noun',
#   '에/Josa',
#   '얼굴/Noun',
#   '이/Josa',
#   '너무/Adverb',
#   '건조하고/Adjective',
#   '따가워서/Adjective',
#   '저녁/Noun',
#   '에/Josa',
#   '이/Noun',
#   '제품/Noun',
#   '을/Josa',
#   '듬뿍/Noun',
#   '바르고/Verb',
#   '잤는데/Verb',
#   '../Punctuation',
#   '다음/Noun',
#   '날/Noun',
#   '세상/Noun',
#   '촉촉하고/Adjective',
#   '맨/Noun',
#   '들/Suffix',
#   '맨/Noun',
#   '들/Suffix',
#   '한/Josa',
#   '피부/Noun',
#   '가/Josa',
#   '되어/Verb',
#   '놀랐다/Verb',
#   './Punctuation',
#   '보습/Noun',
#   '력/Suffix',
#   '이/Josa',
#   '굉장히/Adjective',
#   '좋고/Adjective',
#   '대/Modifier',
#   '용량/Noun',
#   '으로도/Josa',
#   '팔고/Noun',
#   '있어/Adjective',
#   '매우/Noun',
#   '매우/Noun',
#   '잘/Verb',
#   '사용/Noun',
#   '중/Suffix',
#   '이다/Josa',
#   './Punctuation'],
#  ['촉촉해요/Adjective',
#   '얼굴/Noun',
#   '에서/Josa',
#   '광/Noun',
#   '이나/Josa',
#   '는것/Verb',
#   '같고/Adjective',
#   '걸쭉하면서/Adjective',
#   '늘어나는/Verb',
#   '제/Modifier',
#   '형/Noun',
#   '이에요/Josa',
#   '밤/Noun',
#   '에/Josa',
#   '바르고/Verb',
#   '자기/Noun',
#   '좋고/Adjective',
#   '보습/Noun',
#   '에/Josa',
#   '관여/Noun',
#   '하는/Verb',
#   '여러가지/Noun',
#   '성분/Noun',
#   '이/Josa',
#   '들어있어서/Verb',
#   '겨울/Noun',
#   '에/Josa',
#   '쓰기/Noun',
#   '좋은/Adjective',
#   '에센스/Noun',
#   '라는/Josa',
#   '말/Noun',
#   '이/Josa',
#   '잘/VerbPrefix',
#   '어울려요/Verb',
#   '건성/Noun',
#   ',/Punctuation',
#   '복합/Noun',
#   '성/Suffix',
#   '에게/Josa',
#   '추천/Noun',
#   '합니다/Verb',
#   '향/Noun',
#   '은/Josa',
#   '상큼/Noun',
#   '한/Determiner',
#   '향/Noun',
#   '이나/Josa',
#   '요/Noun'],
#  ['쿠팡/Noun',
#   '에서/Josa',
#   '저렴한/Adjective',
#   '가격/Noun',
#   '으로/Josa',
#   '구매/Noun',
#   '했는데/Verb',
#   '진짜/Noun',
#   '가성/Noun',
#   '비/Noun',
#   '갑/Noun',
#   '이에요/Josa',
#   '.../Punctuation',
#   '막/Noun',
#   '쓸려고/Verb',
#   '샀는데/Verb',
#   '찐득한/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '이긴/Verb',
#   '하지만/Conjunction',
#   '건조할/Adjective',
#   '때/Noun',
#   '바르면/Verb',
#   '보습/Noun',
#   '장난/Noun',
#   '아니에요/Adjective',
#   '막/Noun',
#   '쓰기/Noun',
#   '좋음/Adjective',
#   '레알/Noun',
#   '가성/Noun',
#   '비템임/Noun'],
#  ['기초/Noun',
#   '사용/Noun',
#   '하면서/Verb',
#   '그렇게/Adverb',
#   '까지/Josa',
#   '좋다고/Adjective',
#   '생각/Noun',
#   '해본/Verb',
#   '적/Noun',
#   '없는데/Adjective',
#   ',/Punctuation',
#   '이건/Noun',
#   '좋았다/Adjective',
#   './Punctuation',
#   '사용/Noun',
#   '하기/Verb',
#   '전/Noun',
#   '에/Josa',
#   '가끔/Noun',
#   '느끼던/Verb',
#   '속/Modifier',
#   '건조/Noun',
#   '를/Josa',
#   '비폴렌/Noun',
#   '사용/Noun',
#   '하고부터/Verb',
#   '한/Verb',
#   '번/Noun',
#   '도/Josa',
#   '못/Noun',
#   '느꼈다/Verb',
#   './Punctuation',
#   '사실/Noun',
#   '꽃가루/Noun',
#   '알러지/Noun',
#   '있으면/Adjective',
#   '안/VerbPrefix',
#   '맞을/Verb',
#   '수/Noun',
#   '있다고/Adjective',
#   '해서/Verb',
#   '고민/Noun',
#   '했는데/Verb',
#   ',/Punctuation',
#   '아토피/Noun',
#   '때문/Noun',
#   '에/Josa',
#   '뒤집어진/Verb',
#   '적은/Verb',
#   '있어도/Adjective',
#   '화장품/Noun',
#   '때문/Noun',
#   '에/Josa',
#   '뒤집어진/Verb',
#   '적은/Verb',
#   '없어서/Adjective',
#   '그냥/Noun',
#   '구매/Noun',
#   './Punctuation',
#   '제/Modifier',
#   '형/Noun',
#   '자체/Noun',
#   '가/Josa',
#   '찐득한/Adjective',
#   '느낌/Noun',
#   '?/Punctuation',
#   '막/Noun',
#   '사용/Noun',
#   '하/Suffix',
#   '니까/Josa',
#   '입구/Noun',
#   '더러워져서/Verb',
#   '닦아/Verb',
#   '줬다/Verb',
#   './Punctuation',
#   '그렇다고/Conjunction',
#   '흡수/Noun',
#   '가/Josa',
#   '너무/Adverb',
#   '안되는/Adjective',
#   '것/Noun',
#   '도/Josa',
#   '아니라/Adjective',
#   '너무/Adverb',
#   '좋다/Adjective',
#   './Punctuation',
#   '앰플/Noun',
#   '까지/Josa',
#   '바르고/Verb',
#   '선풍기/Noun',
#   '로/Josa',
#   '머리/Noun',
#   '말려도/Verb',
#   '얼굴/Noun',
#   '이/Josa',
#   '촉촉하다/Adjective',
#   './Punctuation',
#   '머리/Noun',
#   '말리/Noun',
#   '고/Josa',
#   '크림/Noun',
#   '발라/Noun',
#   '도/Josa',
#   '문제/Noun',
#   '없었다/Adjective',
#   './Punctuation',
#   '원래/Noun',
#   '펌핑/Noun',
#   '한/Verb',
#   '번/Noun',
#   '으로/Josa',
#   '사용/Noun',
#   '했는데/Verb',
#   ',/Punctuation',
#   '최근/Noun',
#   '에/Josa',
#   '다이소/Noun',
#   '리들샷/Noun',
#   '이랑/Josa',
#   '레티놀/Noun',
#   '이랑/Josa',
#   '사용/Noun',
#   '하면서/Verb',
#   '건조해져서/Adjective',
#   '더/Noun',
#   '팍팍/Adverb',
#   '사용/Noun',
#   '하고/Josa',
#   '있다/Adjective',
#   './Punctuation',
#   '리들샷/Noun',
#   '은/Josa',
#   '괜찮은데/Adjective',
#   ',/Punctuation',
#   '레티놀/Noun',
#   '사용/Noun',
#   '하고/Josa',
#   '앰플/Noun',
#   '바르니까/Verb',
#   '앰플/Noun',
#   '이/Josa',
#   '금방/Noun',
#   '흡수/Noun',
#   '되고/Verb',
#   '없어지는/Verb',
#   '신기한/Adjective',
#   '경험/Noun',
#   '을/Josa',
#   '할/Verb',
#   '수/Noun',
#   '있었다/Adjective',
#   './Punctuation',
#   '향/Noun',
#   '은/Josa',
#   '모르겠고/Verb',
#   ',/Punctuation',
#   '아침/Noun',
#   '에도/Josa',
#   '사용/Noun',
#   '하고/Josa',
#   '밤/Noun',
#   '에도/Josa',
#   '사용/Noun',
#   '한/Josa',
#   '다/Adverb',
#   './Punctuation',
#   '최근/Noun',
#   '에/Josa',
#   '유난히/Adverb',
#   '화장/Noun',
#   '이/Josa',
#   '더/Noun',
#   '잘/Verb',
#   '먹는/Verb',
#   '느낌/Noun',
#   '인데/Josa',
#   '../Punctuation',
#   '이/Determiner',
#   '것/Noun',
#   '도/Josa',
#   '앰플/Noun',
#   '때문/Noun',
#   '인가/Josa',
#   '싶다/Verb',
#   './Punctuation',
#   '비폴렌/Noun',
#   '사용/Noun',
#   '하고부터/Verb',
#   '기/Modifier',
#   '초단/Noun',
#   '계/Suffix',
#   '에서/Josa',
#   '속/Modifier',
#   '당/Modifier',
#   '김/Noun',
#   '이/Josa',
#   '전혀/Noun',
#   '안/Noun',
#   '느껴진다/Verb',
#   './Punctuation',
#   '유/Noun',
#   '분/Suffix',
#   '이/Josa',
#   '너무/Adverb',
#   '많으면/Adjective',
#   '얼굴/Noun',
#   '에/Josa',
#   '잔잔하게/Adjective',
#   '뾰루지/Noun',
#   '가/Josa',
#   '올라오는데/Verb',
#   '그런/Adjective',
#   '것/Noun',
#   '도/Josa',
#   '없었고/Adjective',
#   './Punctuation',
#   '다행히/Adjective',
#   '알러지/Noun',
#   '반응/Noun',
#   '도/Josa',
#   '없었고/Adjective',
#   ',/Punctuation',
#   '너무/Adverb',
#   '좋다/Adjective',
#   './Punctuation'],
#  ['무지/Noun',
#   '쫜득/Noun',
#   '한/Josa',
#   '앰플/Noun',
#   '겨울/Noun',
#   '에/Josa',
#   '속/Modifier',
#   '건조/Noun',
#   '가/Josa',
#   '심해서/Adjective',
#   '자기/Noun',
#   '전/Noun',
#   '에/Josa',
#   '뭘/Noun',
#   '발라/Noun',
#   '도/Josa',
#   '다음/Noun',
#   '날/Noun',
#   '피부/Noun',
#   '가/Josa',
#   '당겼는데/Verb',
#   '이/Noun',
#   '제품/Noun',
#   '바르고/Verb',
#   '해결/Noun',
#   '됨/Verb',
#   '가을/Noun',
#   '겨울/Noun',
#   '봄/Noun',
#   '사용/Noun',
#   '하고/Josa',
#   '여름/Noun',
#   '에만/Josa',
#   '다른/Noun',
#   '제품/Noun',
#   '쓰면/Verb',
#   '될/Verb',
#   '듯/Noun'],
#  ['💜/Foreign',
#   '저녁/Noun',
#   '에/Josa',
#   '바르면/Verb',
#   '최고/Noun',
#   '❤️/Foreign',
#   '진짜/Noun',
#   '진해/Noun',
#   '요/Josa',
#   '미샤/Noun',
#   '가/Josa',
#   '리뉴얼/Noun',
#   '되면서/Verb',
#   '가격/Noun',
#   '들/Suffix',
#   '이/Josa',
#   '전반/Noun',
#   '적/Suffix',
#   '으로/Josa',
#   '다/Adverb',
#   '올랐는데/Verb',
#   '그만큼/Adverb',
#   '성분/Noun',
#   '이/Josa',
#   '좋아진거/Verb',
#   '같/Adjective',
#   '애/Noun',
#   '요/Josa',
#   './Punctuation',
#   '바르고/Verb',
#   '나면/Verb',
#   '쫀쫀/Noun',
#   '하고/Josa',
#   '저녁/Noun',
#   '에/Josa',
#   '바르면/Verb',
#   '다음/Noun',
#   '날/Noun',
#   '피부/Noun',
#   '상태/Noun',
#   '최고/Noun',
#   '입니다/Adjective',
#   './Punctuation',
#   '가격/Noun',
#   '...../Punctuation',
#   '할인/Noun',
#   '할/Verb',
#   '때/Noun',
#   '사지/Noun',
#   '않으면/Verb',
#   '엄두/Noun',
#   '가/Josa',
#   '나지/Verb',
#   '않는/Verb',
#   '가격/Noun',
#   '이/Josa',
#   '되었어요/Verb',
#   './Punctuation',
#   '내/Noun',
#   '가/Josa',
#   '어릴/Verb',
#   '때/Noun',
#   '알던/Verb',
#   '미샤/Noun',
#   '가/Josa',
#   '맞는지/Verb',
#   '모르/Verb',
#   '겠네용/Verb'],
#  ['개인/Noun',
#   '적/Suffix',
#   '으로/Josa',
#   '미샤/Noun',
#   '앰/Noun',
#   '플/Exclamation',
#   '라인/Noun',
#   '중/Suffix',
#   '에/Josa',
#   '제일/Noun',
#   '만족/Noun',
#   '스럽게/Josa',
#   '잘쓰고/Verb',
#   '있는/Adjective',
#   '제품/Noun',
#   '이/Suffix',
#   '에/Josa',
#   '용/Noun',
#   '👍/Foreign',
#   '쫀쫀/Noun',
#   '한/Josa',
#   '광/Noun',
#   '+/Punctuation',
#   '속/Modifier',
#   '건조/Noun',
#   '쏵/Noun',
#   '잡아주는/Verb',
#   '느낌/Noun',
#   '으로/Josa',
#   '건성/Noun',
#   '에서/Josa',
#   '초초/Noun',
#   '추천/Noun',
#   '입니당/Adjective'],
#  ['건성/Noun',
#   '겨울/Noun',
#   '필수/Noun',
#   '템/Noun',
#   '물광/Noun',
#   '피부/Noun',
#   '만들고/Verb',
#   '싶을/Verb',
#   '때/Noun',
#   '꼭/Noun',
#   '필요한/Adjective',
#   '제품/Noun',
#   '이에요/Josa',
#   '!!!/Punctuation',
#   '건성/Noun',
#   '중/Suffix',
#   '에서도/Josa',
#   '악/Noun',
#   '건성/Noun',
#   '이라/Josa',
#   '가을/Noun',
#   '겨울/Noun',
#   '에/Josa',
#   '피부/Noun',
#   '가/Josa',
#   '찢어질듯/Verb',
#   '아프고/Adjective',
#   '항상/Noun',
#   '보습/Noun',
#   '에/Josa',
#   '집착/Noun',
#   '하는데/Verb',
#   '너무/Adverb',
#   '꿀템/Noun',
#   '이에요/Josa',
#   './Punctuation',
#   '토너/Noun',
#   '찹/Verb',
#   '찹/Verb',
#   '바르고/Verb',
#   '이/Determiner',
#   '거/Noun',
#   '듬뿍/Noun',
#   '바르고/Verb',
#   '피지오/Verb',
#   '겔/Noun',
#   '로션/Noun',
#   '바르면/Verb',
#   '보습/Noun',
#   '끝/Noun',
#   '!/Punctuation',
#   '저/Noun',
#   '는/Josa',
#   '파데에도/Verb',
#   '살짝/Noun',
#   '섞어/Verb',
#   '바르는데/Verb',
#   '그럼/Adjective',
#   '꿀광/Noun',
#   '피부/Noun',
#   '완성/Noun',
#   '이에요/Josa',
#   './Punctuation',
#   '친구/Noun',
#   '들/Suffix',
#   '이/Josa',
#   '맨날/Adverb',
#   '뭐/Noun',
#   '발랐냐고/Verb',
#   '물어봐요/Verb',
#   'ㅎㅎ/KoreanParticle',
#   '단종/Noun',
#   '되면/Verb',
#   '시위/Noun',
#   '할거에요/Verb'],
#  ['전/Noun',
#   '부터/Josa',
#   '궁금했던/Adjective',
#   '제품/Noun',
#   '입니다/Adjective',
#   '이/Noun',
#   '제품/Noun',
#   '좋다는/Adjective',
#   '이야기/Noun',
#   '는/Josa',
#   '워낙/Noun',
#   '들어와서/Verb',
#   '알/Noun',
#   '고/Josa',
#   '있었지만/Adjective',
#   '매번/Noun',
#   '살/Noun',
#   '까말까/Adjective',
#   '고민/Noun',
#   '만/Josa',
#   '했었거든요/Verb',
#   '그러다/Adjective',
#   '요즘/Noun',
#   '피부/Noun',
#   '컨디션/Noun',
#   '이/Josa',
#   '좀/Noun',
#   '별로/Noun',
#   '인거/Josa',
#   '같아/Adjective',
#   '곧/Noun',
#   '겨울/Noun',
#   '이/Josa',
#   '다가오기도/Verb',
#   '하고/Verb',
#   '미리/Noun',
#   '구매/Noun',
#   '해봤어요/Verb',
#   '근데/Adverb',
#   '이/Determiner',
#   '거/Noun',
#   '진짜/Noun',
#   '너무/Adverb',
#   '좋네요/Adjective',
#   '왜/Noun',
#   '좋다한/Adjective',
#   '건지/Verb',
#   '이해/Noun',
#   '돼요/Verb',
#   'ㅠㅠ/KoreanParticle',
#   '아니면/Adjective',
#   '제/Noun',
#   '가/Josa',
#   '미샤/Noun',
#   '랑/Josa',
#   '잘/Verb',
#   '맞는/Verb',
#   '건지/Verb',
#   'ㅋㅋㅋ/KoreanParticle',
#   '미샤/Noun',
#   '는/Josa',
#   '쓰는거마다/Verb',
#   '다/Adverb',
#   '좋거든요/Adjective',
#   '미샤/Noun',
#   '최고/Noun',
#   '…/Punctuation',
#   '❤️/Foreign',
#   '메이크업/Noun',
#   '전/Noun',
#   '에/Josa',
#   '쓰는/Verb',
#   '용도/Noun',
#   '보다는/Josa',
#   '나이트/Noun',
#   '용/Noun',
#   '으로만/Josa',
#   '사용/Noun',
#   '중/Suffix',
#   '인데/Josa',
#   '요/Noun',
#   '가끔/Noun',
#   '귀찮을/Adjective',
#   '때/Noun',
#   '토너/Noun',
#   '만/Josa',
#   '챱챱/Noun',
#   '바르고/Verb',
#   '이/Determiner',
#   '거/Noun',
#   '하나/Noun',
#   '만/Josa',
#   '발라줘도/Verb',
#   '촉촉하더라구요/Adjective',
#   '겉/Noun',
#   '만/Josa',
#   '채워주는게/Verb',
#   '아니라/Adjective',
#   '속/Noun',
#   '까지/Josa',
#   '보습/Noun',
#   '을/Josa',
#   '채워주는거/Verb',
#   '같아요/Adjective',
#   '아/Exclamation',
#   '참고/Noun',
#   '로/Josa',
#   '보라색/Noun',
#   '병/Noun',
#   '도/Josa',
#   '제/Noun',
#   '미샤/Noun',
#   '최애/Noun',
#   '템/Noun',
#   '중/Noun',
#   '에/Josa',
#   '하나/Noun',
#   '인데/Josa',
#   '보습/Noun',
#   '감은/Verb',
#   '이/Noun',
#   '게/Josa',
#   '더/Noun',
#   '좋은/Adjective',
#   '거/Noun',
#   '같아요/Adjective',
#   '!/Punctuation',
#   '그나마/Adverb',
#   '단점/Noun',
#   '을/Josa',
#   '찾자면/Verb',
#   '스포이드/Noun',
#   '형태/Noun',
#   '라/Josa',
#   '끝/Noun',
#   '까지/Josa',
#   '사용/Noun',
#   '하기가/Verb',
#   '힘들다는건데/Adjective',
#   '그래도/Adverb',
#   '위생/Noun',
#   '적/Suffix',
#   '으로/Josa',
#   '사용/Noun',
#   '할/Verb',
#   '수/Noun',
#   '있어/Adjective',
#   '만족합니다/Adjective'],
#  ['효과/Noun',
#   '가/Josa',
#   '꽤/Noun',
#   '좋습니다/Adjective',
#   '~/Punctuation',
#   '민감/Noun',
#   '성/Suffix',
#   '피부/Noun',
#   '인데/Josa',
#   '도/Noun',
#   ',/Punctuation',
#   '트러블/Noun',
#   '도/Josa',
#   '올라오지/Verb',
#   '않고요/Verb',
#   '~/Punctuation',
#   '피부/Noun',
#   '에/Josa',
#   '적당한/Adjective',
#   '영/Modifier',
#   '양감/Noun',
#   '을/Josa',
#   '주어/Noun',
#   '서/Josa',
#   ',/Punctuation',
#   '피부/Noun',
#   '컨디션/Noun',
#   '이/Josa',
#   '좋아져요/Verb',
#   '~~~^^/Punctuation'],
#  ['겨울/Noun',
#   '에/Josa',
#   '쓰기/Noun',
#   '에도/Josa',
#   '너무/Adverb',
#   '좋아요/Adjective',
#   '예전/Noun',
#   '에/Josa',
#   '한창/Noun',
#   '쓰다가/Verb',
#   '안/VerbPrefix',
#   '썼었는데/Verb',
#   '건조해진/Adjective',
#   '요즘/Noun',
#   '다시/Noun',
#   '발라/Noun',
#   '보니/Verb',
#   '역시/Noun',
#   '보습/Noun',
#   '진정/Noun',
#   '굿/Noun',
#   '이네/Josa',
#   '요/Noun'],
#  ['잘맞는/Adjective',
#   '사람/Noun',
#   '들/Suffix',
#   '에겐/Josa',
#   '고가/Noun',
#   '화장품/Noun',
#   '보다/Josa',
#   '좋은/Adjective',
#   '거/Noun',
#   '같아요/Adjective',
#   './Punctuation',
#   '여름/Noun',
#   '에/Josa',
#   '쓰긴/Verb',
#   '무거운/Adjective',
#   '편/Noun',
#   '인데/Josa',
#   '그/Noun',
#   '외/Noun',
#   '계절/Noun',
#   './Punctuation',
#   '특히/Adverb',
#   '겨울/Noun',
#   '에/Josa',
#   '진짜/Noun',
#   '잘/Verb',
#   '쓰고/Verb',
#   '있어요/Adjective',
#   './Punctuation',
#   'nn/Alpha',
#   '병/Noun',
#   '째/Suffix',
#   '쓰고/Verb',
#   '있는/Adjective',
#   '인생/Noun',
#   '템/Noun',
#   '이며/Josa',
#   '주변/Noun',
#   '에도/Josa',
#   '강/Noun',
#   '추하고/Adjective',
#   '있습니다/Adjective',
#   './Punctuation'],
#  ['건성/Noun',
#   '타입/Noun',
#   '촉촉함/Adjective',
#   '보습/Noun',
#   '력/Suffix',
#   '이/Josa',
#   '최상인/Noun',
#   '앰플/Noun',
#   '이에요/Josa',
#   '!/Punctuation',
#   '정말/Noun',
#   '한겨울/Noun',
#   '에/Josa',
#   '정말/Noun',
#   '잘써서/Verb',
#   '매년/Noun',
#   '겨울/Noun',
#   '마다/Josa',
#   '찾게/Verb',
#   '되는거/Verb',
#   '같아요/Adjective',
#   './Punctuation',
#   '대신/Noun',
#   '겨울/Noun',
#   '말고/Josa',
#   '다른/Modifier',
#   '계절/Noun',
#   '에는/Josa',
#   '과/Noun',
#   '하고/Josa',
#   '겨울/Noun',
#   '엔/Josa',
#   '건성/Noun',
#   '에겐/Josa',
#   '최고/Noun',
#   '입니다/Adjective',
#   '(/Punctuation',
#   '쏘귿/Noun',
#   '👍/Foreign',
#   ')/Punctuation'],
#  ['건성/Noun',
#   '분들/Suffix',
#   '한테/Josa',
#   '매우/Noun',
#   '추천/Noun',
#   '벗/Noun',
#   '뜨/Verb',
#   '나머지/Noun',
#   '는/Josa',
#   '../Punctuation',
#   '제/Noun',
#   '가/Josa',
#   '끈/Noun',
#   '적/Suffix',
#   '이/Determiner',
#   '는걸/Noun',
#   '너무/Adverb',
#   '싫어해서/Adjective',
#   'ㅠㅠ/KoreanParticle',
#   '이건/Noun',
#   '바르고/Verb',
#   '난뒤/Noun',
#   '잔/Noun',
#   '여/Josa',
#   '감/Noun',
#   '이/Josa',
#   '남아있구/Verb',
#   '넘/Verb',
#   '답답해서/Adjective',
#   '손/Noun',
#   '이/Josa',
#   '잘/VerbPrefix',
#   '안/VerbPrefix',
#   '갔어요/Verb',
#   '꾸역꾸역/Adverb',
#   '썼는데/Verb',
#   '결국/Adverb',
#   '공병/Noun',
#   '볼려다가/Verb',
#   '포기/Noun',
#   '../Punctuation',
#   'ㅠㅠ/KoreanParticle',
#   '타/Noun',
#   '나이트/Noun',
#   '앰플/Noun',
#   '은/Josa',
#   '영/Modifier',
#   '양감/Noun',
#   '가득한/Adjective',
#   '거/Noun',
#   '였는데/Verb',
#   '끈/Noun',
#   '적/Suffix',
#   '이는거/Verb',
#   '없이/Adverb',
#   '잘썻거든/Noun',
#   '요/Josa',
#   '그래두/Adjective',
#   '트러블/Noun',
#   '이나/Josa',
#   '이런/Modifier',
#   '거/Noun',
#   '는/Josa',
#   '안/VerbPrefix',
#   '났고/Verb',
#   '사용/Noun',
#   '할/Verb',
#   '때/Noun',
#   '답답한/Adjective',
#   '느낌/Noun',
#   '말고/Josa',
#   '보습/Noun',
#   '이라/Josa',
#   '던지/Verb',
#   '이런건/Adjective',
#   '문제/Noun',
#   '가/Josa',
#   '없었기에/Adjective',
#   '쏘/Verb',
#   '쏘/Verb',
#   '드립니다/Verb'],
#  ['스킨푸드/Noun',
#   '프로폴리스/Noun',
#   '없이/Adverb',
#   '못/Noun',
#   '살았는데/Verb',
#   '요즘/Noun',
#   '슼푸/Noun',
#   '매장/Noun',
#   '을/Josa',
#   '찾을/Verb',
#   '수가/Noun',
#   '없어서/Adjective',
#   '갈아탔어요/Verb',
#   'ㅠ/KoreanParticle',
#   '결론/Noun',
#   '은/Josa',
#   '너무/Adverb',
#   '너무/Adverb',
#   '좋아요/Adjective',
#   '한펌핑/Noun',
#   '은/Josa',
#   '살짝/Noun',
#   '부족한가/Adjective',
#   '싶었는데/Verb',
#   '한/Verb',
#   '펌핑/Noun',
#   '으로도/Josa',
#   '보습/Noun',
#   '은/Josa',
#   '잘/Verb',
#   '되네요/Verb',
#   '밤낮/Noun',
#   '으로/Josa',
#   '너무/Adverb',
#   '잘/Verb',
#   '쓰고/Verb',
#   '있는/Adjective',
#   '제품/Noun',
#   '이에요/Josa'],
#  ...]

# %%
# tagging = []
# morph = []
# tag = []

# for j in range(len(list_)):
#   for i in list_[j] :
#     morph.append(i.split('/')[0])
#     tag.append(i.split('/')[1])
#   tagging.append([morph, tag])

# pd.DataFrame(tagging, columns =['morph', 'tag'])
# Out:
#                                                   morph  \
# 0     [완전, 가성, 비, 최고, 대, 용량, 토너, 예요, !, 가격, 도, 엄청, 저...
# 1     [완전, 가성, 비, 최고, 대, 용량, 토너, 예요, !, 가격, 도, 엄청, 저...
# 2     [완전, 가성, 비, 최고, 대, 용량, 토너, 예요, !, 가격, 도, 엄청, 저...
# 3     [완전, 가성, 비, 최고, 대, 용량, 토너, 예요, !, 가격, 도, 엄청, 저...
# 4     [완전, 가성, 비, 최고, 대, 용량, 토너, 예요, !, 가격, 도, 엄청, 저...
# ...                                                 ...
# 6695  [완전, 가성, 비, 최고, 대, 용량, 토너, 예요, !, 가격, 도, 엄청, 저...
# 6696  [완전, 가성, 비, 최고, 대, 용량, 토너, 예요, !, 가격, 도, 엄청, 저...
# 6697  [완전, 가성, 비, 최고, 대, 용량, 토너, 예요, !, 가격, 도, 엄청, 저...
# 6698  [완전, 가성, 비, 최고, 대, 용량, 토너, 예요, !, 가격, 도, 엄청, 저...
# 6699  [완전, 가성, 비, 최고, 대, 용량, 토너, 예요, !, 가격, 도, 엄청, 저...
#
#                                                     tag
# 0     [Noun, Noun, Noun, Noun, Modifier, Noun, Noun,...
# 1     [Noun, Noun, Noun, Noun, Modifier, Noun, Noun,...
# 2     [Noun, Noun, Noun, Noun, Modifier, Noun, Noun,...
# 3     [Noun, Noun, Noun, Noun, Modifier, Noun, Noun,...
# 4     [Noun, Noun, Noun, Noun, Modifier, Noun, Noun,...
# ...                                                 ...
# 6695  [Noun, Noun, Noun, Noun, Modifier, Noun, Noun,...
# 6696  [Noun, Noun, Noun, Noun, Modifier, Noun, Noun,...
# 6697  [Noun, Noun, Noun, Noun, Modifier, Noun, Noun,...
# 6698  [Noun, Noun, Noun, Noun, Modifier, Noun, Noun,...
# 6699  [Noun, Noun, Noun, Noun, Modifier, Noun, Noun,...
#
# [6700 rows x 2 columns]

# %%
def myTokenizer(text):
    d = pd.DataFrame(okt.pos(text), columns=['morph','tag'])
    d.set_index('tag', inplace=True)
    if ('Verb' in d.index) | ('Noun' in d.index) | ('Adjective' in d.index):
        return d.loc[d.index.intersection(['Verb','Noun','Adjective']),'morph'].values
    else :
        return []

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#TF-IDF Vectorizer에 연결해주기
tfidf_pos = TfidfVectorizer(tokenizer=myTokenizer)
tfidf_pos.fit(X)
tfidf_pos.vocabulary_
# Out:
# C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# {'완전': 14275,
#  '가성': 239,
#  '비': 9318,
#  '최고': 18260,
#  '용량': 14373,
#  '토너': 19027,
#  '가격': 5,
#  '어마': 13183,
#  '무시': 7112,
#  '스킨': 11109,
#  '팩': 19370,
#  '쓰기': 11908,
#  '성분': 10643,
#  '크게': 18707,
#  '것': 1009,
#  '모찌': 6949,
#  '워터': 14490,
#  '형': 20850,
#  '아주': 12432,
#  '수분': 10860,
#  '감': 457,
#  '편이': 19521,
#  '좀': 16465,
#  '막': 6089,
#  '이': 14816,
#  '제품': 16360,
#  '신경': 11343,
#  '저렴한데': 16066,
#  '좋아요': 16574,
#  '나쁜건': 2502,
#  '없는': 13426,
#  '같고': 638,
#  '없지는': 13575,
#  '촉촉한': 18191,
#  '있는': 15376,
#  '아까웠는데': 12193,
#  '훌륭해서': 21089,
#  '해서': 20488,
#  '이름답게': 14908,
#  '않고': 12650,
#  '쓰지': 12029,
#  '써도': 11655,
#  '예전': 13939,
#  '패드': 19361,
#  '어어': 13209,
#  '무': 6998,
#  '기억': 1951,
#  '구매': 1438,
#  '실화': 11432,
#  '증정': 17030,
#  '심지어': 11471,
#  '샘플': 10419,
#  '사이즈': 10119,
#  '통': 19059,
#  '와우': 14251,
#  '게다가': 1021,
#  '물': 7255,
#  '얘': 13069,
#  '영양': 13809,
#  '공급': 1267,
#  '제대로': 16346,
#  '느낌': 3521,
#  '겨': 1042,
#  '에센스': 13596,
#  '안': 12480,
#  '발라': 7982,
#  '체력': 18079,
#  '정신': 16316,
#  '여유': 13669,
#  '두': 4778,
#  '번': 8329,
#  '크림': 18732,
#  '마무리': 6042,
#  '기초': 1968,
#  '화장품': 20967,
#  '줄': 16871,
#  '강력': 558,
#  '추천': 18306,
#  '만족해하며': 6263,
#  '입니다': 15276,
#  '아니': 12220,
#  '저렴해서': 16078,
#  '좋았고': 16659,
#  '작은': 15664,
#  '아니고': 12226,
#  '넉넉한': 2989,
#  '만족해하면서': 6264,
#  '있습니다': 15424,
#  '굳': 1483,
#  '같은': 695,
#  '썼던': 11767,
#  '떠올라서': 5506,
#  '해': 20358,
#  '본': 8713,
#  '넘': 3024,
#  '큰데': 18755,
#  '하더라구요': 20054,
#  '쓰다가': 11946,
#  '쓰니까': 11942,
#  '되는': 4610,
#  '들어요': 5161,
#  '넘나리': 3032,
#  '쓰고': 11865,
#  '그리': 1741,
#  '될': 4746,
#  '되면': 4651,
#  '발라주고': 7999,
#  '싶다면': 11533,
#  '합니다': 20342,
#  '것민': 1010,
#  '화장': 20963,
#  '기존': 1965,
#  '에멀젼': 13591,
#  '지성': 17107,
#  '여름': 13649,
#  '향': 20756,
#  '여자': 13674,
#  '향료': 20764,
#  '냄새': 2959,
#  '획': 21044,
#  '닙니디': 3608,
#  '바르고': 7721,
#  '한다는데': 20226,
#  '하시면': 20121,
#  '좋네요': 16526,
#  '좋을': 16722,
#  '같아요': 680,
#  '벌써': 8371,
#  '병': 8476,
#  '매하': 6650,
#  '이제': 15070,
#  '필수': 19851,
#  '템': 19019,
#  '지성인': 17112,
#  '나': 2412,
#  '계절': 1126,
#  '모두': 6863,
#  '사용': 10109,
#  '레이어': 5841,
#  '링': 6009,
#  '피부': 19794,
#  '게': 1020,
#  '팩용': 19372,
#  '정말': 16306,
#  '애용': 12925,
#  '공병': 1271,
#  '여행가': 13688,
#  '거': 783,
#  '하나로': 20006,
#  '전': 16223,
#  '단계': 3870,
#  '활용': 21023,
#  '정도': 16302,
#  '데': 4321,
#  '일리': 15180,
#  '바닥': 7693,
#  '타입': 18877,
#  '비도': 9330,
#  '로럴': 5868,
#  '무향': 7131,
#  '끈': 2328,
#  '적임': 16184,
#  '쫀': 17575,
#  '득': 5017,
#  '건성': 876,
#  '분': 9005,
#  '몇': 6848,
#  '후': 21057,
#  '보습': 8601,
#  '장벽': 15940,
#  '덧': 4304,
#  '트러블': 19121,
#  '중': 16911,
#  '토': 19025,
#  '다소': 3717,
#  '오버': 14004,
#  '거나': 788,
#  '각질': 314,
#  '덜': 4254,
#  '수도': 10847,
#  '재구': 15967,
#  '할수록': 20302,
#  '차는': 17750,
#  '느껴져서': 3427,
#  '담으면': 4011,
#  '긁어': 1820,
#  '느껴지는데': 3449,
#  '쓰다': 11945,
#  '보면': 8556,
#  '좋아진다': 16603,
#  '하면': 20080,
#  '닦': 3783,
#  '즐겨하는': 17014,
#  '들이라면': 5219,
#  '닦인': 3863,
#  '들': 5035,
#  '없어서는': 13486,
#  '가능하고': 55,
#  '있다': 15398,
#  '가능할': 76,
#  '거대한데다': 790,
#  '좋은': 16715,
#  '은은한': 14768,
#  '아쉬울': 12357,
#  '있겠다': 15339,
#  '갑': 514,
#  '양': 13049,
#  '믾': 7561,
#  '챱챱': 18002,
#  '흡수': 21190,
#  '기도': 1907,
#  '좋습니다': 16565,
#  '좋더라구요': 16555,
#  '좋고': 16514,
#  '와': 14247,
#  '따에요': 5368,
#  '비웠어요': 9450,
#  '작년': 15647,
#  '놀라운': 3194,
#  '촉촉하고': 18162,
#  '건조하지': 900,
#  '왔습니다': 14295,
#  '않은': 12749,
#  '만들어주는': 6161,
#  '유튜버': 14720,
#  '극찬': 1792,
#  '속': 10782,
#  '요물': 14351,
#  '대비': 4138,
#  '짱': 17513,
#  '드': 4946,
#  '건조': 879,
#  '꽤': 2278,
#  '세안': 10693,
#  '첫': 18051,
#  '점성': 16271,
#  '토로': 19031,
#  '대신': 4142,
#  '더': 4179,
#  '다음': 3753,
#  '기능': 1879,
#  '레티놀': 5847,
#  '순서': 10893,
#  '자주': 15632,
#  '손': 10796,
#  '의사': 14807,
#  '짐승': 17411,
#  '이정': 15069,
#  '라면': 5756,
#  '손해': 10817,
#  '좋다고': 16530,
#  '좋음': 16730,
#  '얇게': 13020,
#  '마르는': 6032,
#  '있음': 15497,
#  '는셈': 3566,
#  '해봤음': 20485,
#  '발라주면': 8011,
#  '잘': 15687,
#  '잡아': 15855,
#  '준다': 16852,
#  '하는데': 20030,
#  '하는': 20014,
#  '바르는게': 7750,
#  '잡아줘서': 15885,
#  '발라줘도': 8026,
#  '적다': 16105,
#  '가는듯': 49,
#  '재구매': 15968,
#  '하는게': 20027,
#  '무난': 7032,
#  '한텐': 20263,
#  '살짝': 10254,
#  '굿': 1527,
#  '따가운데': 5290,
#  '붉어지거나': 9171,
#  '촉촉하니': 18170,
#  '생기진': 10474,
#  '않았어요': 12725,
#  '민감': 7537,
#  '결론': 1078,
#  '콧물토너': 18647,
#  '중간': 16912,
#  '보시': 8605,
#  '수': 10839,
#  '콧물': 18643,
#  '금방': 1836,
#  '가끔': 34,
#  '때': 5448,
#  '깡패': 2140,
#  '유': 14608,
#  '한번': 20240,
#  '저': 16023,
#  '유지': 14709,
#  '솜': 10827,
#  '상태': 10346,
#  '처음': 18013,
#  '뾰루지': 9808,
#  '잠깐': 15813,
#  '붙이': 9233,
#  '날': 2669,
#  '돼요': 4552,
#  '않게': 12647,
#  '할': 20267,
#  '했는데': 20674,
#  '줄어들고': 16882,
#  '하기': 19981,
#  '하게': 19932,
#  '되었는데': 4691,
#  '기있어서': 1961,
#  '시켜주니': 11287,
#  '되었어요': 4703,
#  '적셔': 16135,
#  '따라': 5335,
#  '드려요': 4983,
#  '나서': 2506,
#  '닦아': 3801,
#  '준답니다': 16863,
#  '건조하지도': 902,
#  '답답하지도': 4022,
#  '있었어요': 15459,
#  '답답해서': 4035,
#  '건조해져서': 932,
#  '귀찮을': 1586,
#  '있더라구요': 15416,
#  '촉촉하게': 18160,
#  '넉넉하게': 2984,
#  '있는데': 15386,
#  '짧게': 17489,
#  '길게하면': 1990,
#  '필요한': 19885,
#  '라마': 5755,
#  '이드': 14865,
#  '히알루론산': 21213,
#  '놀': 3188,
#  '함유': 20336,
#  '쫀쫀': 17588,
#  '케어': 18578,
#  '병풀': 8480,
#  '추출': 18310,
#  '물이': 7314,
#  '진정': 17333,
#  '듬뿍': 5240,
#  '도와주고': 4366,
#  '판테': 19314,
#  '도와줘요': 4370,
#  '달아오른': 3972,
#  '해도': 20375,
#  '민감하거나': 7539,
#  '학생': 20199,
#  '임': 15260,
#  '진짜': 17336,
#  '말': 6374,
#  '형임': 20861,
#  '조금': 16400,
#  '로션': 5876,
#  '하나': 20005,
#  '선크림': 10610,
#  '표현': 19672,
#  '효과': 21048,
#  '짐': 17408,
#  '흐르는': 21119,
#  '쓰면': 11981,
#  '되고': 4592,
#  '본거': 8715,
#  '부담스러울': 8826,
#  '좋았음': 16689,
#  '같지만': 719,
#  '같아': 674,
#  '꼭': 2250,
#  '구입': 1456,
#  '단점': 3903,
#  '혜자': 20865,
#  '확': 20989,
#  '겨울': 1048,
#  '갑이죠': 525,
#  '하지만': 20184,
#  '하시는': 20110,
#  '하셔요': 20098,
#  '샀는데': 10281,
#  '쓰는게': 11930,
#  '치곤': 18393,
#  '쓰셔도': 11988,
#  '많아': 6308,
#  '좋다거나': 16529,
#  '그런건': 1670,
#  '아닌데': 12294,
#  '있어요': 15434,
#  '있어서': 15429,
#  '자극': 15531,
#  '장점': 15952,
#  '이자': 15065,
#  '면': 6820,
#  '바르기': 7736,
#  '않은게': 12754,
#  '없어서': 13485,
#  '특별하지': 19147,
#  '이건': 14828,
#  '통째': 19068,
#  '많고': 6287,
#  '순하고': 10902,
#  '착하고': 17806,
#  '아니지만': 12283,
#  '없고': 13410,
#  '쓰고있어용': 11902,
#  '듯': 5247,
#  '보충': 8697,
#  '용': 14368,
#  '순위': 10897,
#  '왜': 14308,
#  '이해': 15093,
#  '부담': 8819,
#  '때문': 5458,
#  '가요': 255,
#  '호불호': 20875,
#  '생각': 10428,
#  '갑인': 526,
#  '묻혀서': 7238,
#  '덜어': 4265,
#  '묻혀': 7236,
#  '채워질': 17972,
#  '갈': 367,
#  '않아서': 12700,
#  '크지': 18741,
#  '않을거라': 12761,
#  '됩니다': 4767,
#  '쓸': 12055,
#  '않아': 12697,
#  '귀찮아서': 1576,
#  '있긴': 15362,
#  '높은': 3265,
#  '그런지': 1677,
#  '촉촉함이': 18208,
#  '산뜻하고': 10162,
#  '강하지': 593,
#  '많아서': 6310,
#  '비싸지': 9403,
#  '덕': 4242,
#  '하진': 20189,
#  '적신': 16149,
#  '결정': 1082,
#  '돈': 4411,
#  '다시': 3718,
#  '진찌': 17341,
#  '쫀득쫀득': 17578,
#  '머': 6671,
#  '금은': 1844,
#  '무엇': 7116,
#  '량': 5803,
#  '맘': 6435,
#  '듭니': 5245,
#  '꾸': 2282,
#  '닦아내주듯': 3819,
#  '하는데요': 20034,
#  '나면': 2484,
#  '가득한': 103,
#  '넉넉히': 2991,
#  '가볍게': 212,
#  '그러고': 1645,
#  '워낙': 14484,
#  '장창': 15954,
#  '치덕치덕': 18400,
#  '마법': 6043,
#  '별': 8461,
#  '기대': 1885,
#  '뭔가': 7407,
#  '나름': 2480,
#  '보니': 8516,
#  '해주고': 20541,
#  '남아있는': 2760,
#  '해지는게': 20632,
#  '느껴져요': 3428,
#  '좋다': 16528,
#  '이런건': 14886,
#  '촉촉해져서': 18215,
#  '좋아서': 16569,
#  '흰색': 21208,
#  '색상': 10400,
#  '약간': 12982,
#  '보통': 8699,
#  '편': 19481,
#  '토니모리': 19029,
#  '원더': 14495,
#  '파팍': 19304,
#  '부드럽게': 8878,
#  '빠르게': 9528,
#  '없어요': 13490,
#  '스며드는게': 11066,
#  '더딘': 4187,
#  '되요': 4709,
#  '일단': 15170,
#  '대도': 4122,
#  '우유': 14455,
#  '색': 10386,
#  '점도': 16268,
#  '착해서': 17819,
#  '묽다기': 7332,
#  '두고': 4782,
#  '줄어드는': 16878,
#  '바를': 7803,
#  '사실': 10059,
#  '막상': 6097,
#  '내': 2878,
#  '꽉': 2274,
#  '적': 16098,
#  '다른': 3694,
#  '달리': 3962,
#  '일반': 15187,
#  '손틈': 10815,
#  '사이': 10113,
#  '난리': 2663,
#  '남': 2723,
#  '살': 10188,
#  '이유': 15057,
#  '싸서': 11597,
#  '했었다': 20717,
#  '써': 11649,
#  '채워주는': 17950,
#  '바르면': 7773,
#  '날아가는데': 2704,
#  '빠져나가서': 9543,
#  '쓰세요': 11986,
#  '없다': 13442,
#  '그런': 1666,
#  '편하다': 19558,
#  '없는데': 13435,
#  '저렴한': 16059,
#  '웬만한': 14578,
#  '못': 6985,
#  '닥토': 3779,
#  '듬': 5238,
#  '뿍': 9882,
#  '쫀득': 17577,
#  '이름': 14907,
#  '하기에': 19992,
#  '집니다': 17417,
#  '싶은': 11568,
#  '가까운': 18,
#  '특별히': 19150,
#  '복합': 8711,
#  '환절기': 21014,
#  '느껴지진': 3459,
#  '않네요': 12662,
#  '보겠습니다': 8486,
#  '테라': 18999,
#  '피': 19777,
#  '손바닥': 10804,
#  '그냥': 1608,
#  '얼굴': 13337,
#  '림': 5984,
#  '몸': 6982,
#  '쭉': 17608,
#  '지금': 17046,
#  '정착': 16325,
#  '일': 15160,
#  '알기': 12801,
#  '닦아내도': 3813,
#  '덜어서': 4269,
#  '시켜줘도': 11295,
#  '들거': 5036,
#  '잡아주는': 15868,
#  '퍼붓': 19385,
#  '했습니다': 20703,
#  '느껴지는': 3445,
#  '돌아갈': 4458,
#  '찾는': 17863,
#  '합니당': 20344,
#  '꾸준히': 2302,
#  '괜찮았어요': 1374,
#  '괜찮고': 1334,
#  '없지만': 13576,
#  '월등히': 14537,
#  '좋기': 16520,
#  '저렴하게': 16037,
#  '할인': 20320,
#  '쟁': 15993,
#  '인기': 15123,
#  '좋으니': 16703,
#  '있지요': 15507,
#  '통정': 19067,
#  '촉촉해서': 18211,
#  '한다고': 20222,
#  '느꼈던': 3477,
#  '건강': 864,
#  '힐': 21223,
#  '크리미': 18730,
#  '퍽퍽': 19427,
#  '안해': 12639,
#  '궁합': 1547,
#  '세번': 10683,
#  '극대': 1783,
#  '대': 4096,
#  '쓴': 12040,
#  '해주면': 20564,
#  '먹': 6690,
#  '였음': 13795,
#  '올리는게': 14212,
#  '화할': 20981,
#  '촉촉해요': 18212,
#  '같긴': 646,
#  '가벼웠어요': 209,
#  '좋았': 16657,
#  '리': 5930,
#  '텍스처': 19012,
#  '등': 5252,
#  '잡': 15848,
#  '히': 21210,
#  '습': 11188,
#  '니당': 3598,
#  '정': 16294,
#  '그': 1601,
#  '자체': 15638,
#  '토용': 19039,
#  '잔뜩': 15677,
#  '금고': 1831,
#  '훌륭하고요': 21081,
#  '건조해서': 930,
#  '무겁지': 7023,
#  '맞진': 6563,
#  '않았고': 12710,
#  '싶을': 11573,
#  '버리고': 8284,
#  '형도': 20854,
#  '콧물제형': 18646,
#  '날라가고': 2677,
#  '해져요': 20534,
#  '뭣하': 7411,
#  '콧물제': 18645,
#  '분기도': 9011,
#  '가장': 265,
#  '할까': 20282,
#  '않은거': 12751,
#  '같다': 655,
#  '같다고나': 659,
#  '많지': 6367,
#  '같아서': 676,
#  '괜찮을듯': 1392,
#  '좋을거': 16723,
#  '없는거': 13427,
#  '예민한': 13847,
#  '가볍지': 220,
#  '더운': 4217,
#  '무겁고': 7014,
#  '건조할': 913,
#  '자기': 15539,
#  '충전': 18372,
#  '기름': 1912,
#  '바르는': 7742,
#  '올라오거나': 14104,
#  '저렴하고': 16039,
#  '된': 4726,
#  '탄력': 18904,
#  '준': 16850,
#  '지지': 17273,
#  '낮춰주고': 2870,
#  '넣어': 3077,
#  '돼서': 4549,
#  '드립니다': 5005,
#  '탱탱하게': 18956,
#  '적당해서': 16124,
#  '산뜻하게': 10161,
#  '용도': 14371,
#  '거리': 808,
#  '진': 17311,
#  '항상': 20354,
#  '간단하게': 323,
#  '올리브영': 14220,
#  '모르고': 6896,
#  '해요': 20529,
#  '만족해요': 6262,
#  '어린': 13180,
#  '잡은': 15896,
#  '나온': 2566,
#  '큰': 18750,
#  '친구': 18429,
#  '비템': 9478,
#  '욕심': 14362,
#  '또': 5603,
#  '드라마틱한': 4961,
#  '촉촉하긴': 18169,
#  '없다면': 13453,
#  '낭비하며': 2842,
#  '바르고나서': 7723,
#  '당기는': 4048,
#  '따가웠어요': 5301,
#  '미끌미끌해서': 7450,
#  '좋을듯': 16726,
#  '건조하게': 882,
#  '피부관리': 19795,
#  '프로': 19754,
#  '쩍쩍': 17552,
#  '내내': 2886,
#  '히터': 21215,
#  '바람': 7708,
#  '바로': 7713,
#  '사막': 10004,
#  '매': 6592,
#  '땅': 5444,
#  '걸': 968,
#  '요': 14342,
#  '구원': 1455,
#  '제': 16338,
#  '구': 1418,
#  '침투': 18456,
#  '사람': 9986,
#  '주목': 16794,
#  '땐': 5460,
#  '위': 14585,
#  '오일': 14012,
#  '완벽': 14259,
#  '평생': 19607,
#  '귀찮은': 1584,
#  '귀찮러': 1575,
#  '미쳐서': 7499,
#  '마른': 6036,
#  '안되는': 12524,
#  '원하는': 14511,
#  '심할': 11499,
#  '완벽하게': 14260,
#  '미치죠': 7522,
#  '갈라진다는': 389,
#  '느끼며': 3498,
#  '나가서': 2422,
#  '후려친다': 21063,
#  '나타난': 2641,
#  '봤는데': 8784,
#  '봤자': 8807,
#  '아시져': 12404,
#  '씻고': 12142,
#  '나오자마자': 2560,
#  '한': 20202,
#  '하고': 19944,
#  '주세요': 16802,
#  '넘게도': 3026,
#  '끝나면': 2361,
#  '튼': 19167,
#  '싸다': 11592,
#  '팔아주세요': 19341,
#  '앰플': 12943,
#  '피붓결': 19800,
#  '촵챱': 18253,
#  '결': 1072,
#  '정리': 16305,
#  '제일': 16356,
#  '점': 16266,
#  '다만': 3710,
#  '분기': 9009,
#  '요즘': 14356,
#  '자꾸': 15548,
#  '텃': 18992,
#  '콤': 18635,
#  '전혀': 16250,
#  '거부': 817,
#  '오히려': 14034,
#  '부지': 8991,
#  '날씨': 2698,
#  '기름기': 1913,
#  '사계절': 9912,
#  '팩토': 19373,
#  '생각나서': 10436,
#  '붙인': 9237,
#  '되서': 4658,
#  '지나서': 17063,
#  '올라오는': 14114,
#  '가네용': 39,
#  '춥고': 18344,
#  '틀어서': 19190,
#  '썼긴': 11753,
#  '봤어요': 8796,
#  '발릴': 8120,
#  '발려요': 8069,
#  '납니다': 2795,
#  '들만': 5092,
#  '더워지니까': 4225,
#  '쓰실': 12005,
#  '느꼈': 3470,
#  '확실히': 21006,
#  '좋': 16492,
#  '부드러워져요': 8863,
#  '좋았던': 16669,
#  '없지': 13574,
#  '건조하고': 883,
#  '예민해져있을': 13856,
#  '좋았는데': 16663,
#  '아니라서': 12247,
#  '좋았어요': 16678,
#  '같다고': 658,
#  '중건': 16913,
#  '발림': 8122,
#  '설명': 10616,
#  '테스트': 19003,
#  '완료': 14256,
#  '인공': 15122,
#  '색소': 10402,
#  '동물성': 4526,
#  '원료': 14499,
#  '계면활성제': 1108,
#  '화해': 20985,
#  '연속': 13712,
#  '위너': 14587,
#  '글': 1801,
#  '로우': 5884,
#  '픽': 19818,
#  '선정': 10608,
#  '실시간': 11409,
#  '랭킹': 5801,
#  '달성': 3969,
#  '용감': 14369,
#  '비건': 9322,
#  '리지': 5958,
#  '널': 2993,
#  '비교': 9323,
#  '법': 8382,
#  '양감': 13052,
#  '용이': 14381,
#  '금세': 1840,
#  '미스트': 7487,
#  '유무': 14677,
#  '모공': 6854,
#  '티': 19194,
#  '트리': 19129,
#  '알러지': 12811,
#  '답': 4013,
#  '묽은': 7338,
#  '가능해요': 86,
#  '있어': 15427,
#  '민감한': 7546,
#  '없었고': 13525,
#  '순하게': 10901,
#  '해보았어요': 20427,
#  '했을': 20728,
#  '되면서': 4652,
#  '막는': 6093,
#  '맞으면': 6541,
#  '느껴졌어요': 3434,
#  '대학생': 4164,
#  '인터넷': 15150,
#  '되어요': 4673,
#  '샀던': 10291,
#  '합리': 20345,
#  '부족함': 8981,
#  '베스트셀러': 8415,
#  '지도': 17089,
#  '있는거': 15377,
#  '묽지도': 7342,
#  '만족합니다': 6255,
#  '는': 3558,
#  '하서': 20088,
#  '비슷하다고': 9355,
#  '골랐어요': 1249,
#  '샵': 10514,
#  '최대': 18268,
#  '자마자': 15569,
#  '사랑': 9989,
#  '정말루': 16307,
#  '쓰는': 11919,
#  '이라길래': 14870,
#  '믿고': 7565,
#  '느껴짐': 3465,
#  '시원해지는게': 11265,
#  '만족': 6203,
#  '대용': 4147,
#  '적셔서': 16137,
#  '올려': 14160,
#  '두면': 4852,
#  '먹습니다': 6716,
#  '초대': 18126,
#  '주로': 16782,
#  '겉도': 1015,
#  '쫀쫀하': 17591,
#  '만': 6110,
#  '아쉬운': 12350,
#  '어려워요': 13148,
#  '만족스럽기에': 6225,
#  '하려고': 20071,
#  '되지만': 4723,
#  '들어준다는': 5179,
#  '평소': 19608,
#  '그대로': 1613,
#  '완성': 14274,
#  '틈틈이': 19193,
#  '뿌리': 9848,
#  '집': 17412,
#  '마구': 6013,
#  '오래오래': 13976,
#  '계속': 1113,
#  '비싼': 9407,
#  '아까운데': 12189,
#  '아깝고': 12195,
#  '시원해지고': 11263,
#  '촉촉해져요': 18216,
#  '있으니': 15471,
#  '있다는': 15404,
#  '적고': 16102,
#  '시켜주면': 11289,
#  '써주면': 11712,
#  '담아서': 4009,
#  '뿌려줘도': 9838,
#  '무너질': 7064,
#  '생각날': 10440,
#  '뿌리는데': 9859,
#  '하다': 20043,
#  '뿌려도': 9817,
#  '하면서': 20081,
#  '쓰게': 11854,
#  '이었습니다': 15037,
#  '적거': 16099,
#  '찾으시는': 17914,
#  '가렵거': 165,
#  '뭐': 7400,
#  '쫀존': 17586,
#  '선호': 10614,
#  '양도': 13053,
#  '만족했어요': 6271,
#  '좋았어용': 16679,
#  '올라오지': 14129,
#  '시켜줘요': 11298,
#  '톤': 19053,
#  '고': 1129,
#  '업되': 13394,
#  '쓰': 11849,
#  '맑아져요': 6429,
#  '고픈': 1226,
#  '입니당': 15280,
#  '독도': 4398,
#  '주기도': 16766,
#  '알': 12773,
#  '라운드': 5767,
#  '랩': 5798,
#  '유명해서': 14658,
#  '좋아용': 16576,
#  '유명한지': 14652,
#  '해봤어요': 20480,
#  '잡아주고': 15863,
#  '아이': 12416,
#  '달래': 3956,
#  '사춘기': 10133,
#  '매우': 6635,
#  '쫙': 17599,
#  '겹': 1089,
#  '커서': 18523,
#  '해주는': 20548,
#  '뿌려서': 9818,
#  '해주기도': 20546,
#  '정석': 16312,
#  '산뜻한': 10169,
#  '순해서': 10936,
#  '않는': 12663,
#  '나지도': 2634,
#  '젠': 16364,
#  '여드름': 13644,
#  '너': 2972,
#  '별로': 8467,
#  '짜': 17453,
#  '맞을수도': 6557,
#  '뒤집': 4922,
#  '져서': 16374,
#  '버렸어요': 8277,
#  '해본': 20447,
#  '였어요': 13789,
#  '있겠다고': 15340,
#  '눈': 3353,
#  '성인': 10650,
#  '테': 18996,
#  '좋다길래': 16537,
#  '사봤는데': 10036,
#  '보진': 8696,
#  '했지만': 20734,
#  '된게': 4730,
#  '보였어요': 8642,
#  '맞았어요': 6534,
#  '순한': 10922,
#  '적절한': 16190,
#  '수월한': 10871,
#  '같습니다': 672,
#  '보다': 8517,
#  '건조한': 905,
#  '도움': 4372,
#  '가진': 297,
#  '하지': 20179,
#  '않': 12643,
#  '되지': 4720,
#  '않습니다': 12695,
#  '뛰어나지': 5666,
#  '채워주기': 17948,
#  '촉촉했어요': 18229,
#  '빠른': 9534,
#  '솔직히': 10825,
#  '아니여도': 12271,
#  '좋을것': 16725,
#  '느낌이였고': 3542,
#  '편이였어요': 19538,
#  '모르겠지만': 6895,
#  '제거': 16339,
#  '마음': 6065,
#  '들것': 5039,
#  '은근': 14754,
#  '사면': 10005,
#  '딱히': 5417,
#  '엄청난': 13383,
#  ...}

# %%
len(tfidf_pos.vocabulary_)
# Out:
# 21283

# %%
# 실제 문장에 단어를 토큰값으로 변환해주는 작업 진행 : 8분정도 걸림
X_trains = tfidf_pos.transform(X)

# %%
X_trains
# Out:
# <6700x21283 sparse matrix of type '<class 'numpy.float64'>'
# 	with 204142 stored elements in Compressed Sparse Row format>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_trains, y, test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((5360, 21283), (1340, 21283), (5360,), (1340,))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier() # 하이퍼 파라미터 조절 X / 랜덤포레스트 기 모델

# %%
# 교차검증 - 예상 성능 확인해보기
from sklearn.model_selection import cross_val_score

rs = cross_val_score(rf_model, X_train, y_train, cv = 5)
print(rs)
print(rs.mean())

# %%
# 모델 학습 및 평가
rf_model.fit(X_train, y_train)

# %%
rf_model.score(X_train, y_train)

# %%
rf_model.score(X_test, y_test)

# %%
# 하이퍼 파라미터 조합찾기
from sklearn.model_selection import GridSearchCV

# %%
# 하이퍼 파라미터 조절
# 내가 하이퍼 파라미터 뭉텡이를 던져주면 조합식을 짜서 최적의 조합을 짜줌
# 이때 사용하는건 교차검증 점수
param = { 'n_estimators' : [500, 1000, 1500, 2000, 2500], # 트리의 갯수 갯수가 많을수록 시간이 오래걸림
          'max_depth': range(1,6), # 트리의 최대 깊이 최대 깊이는 5를 안넘는게 좋음...
          #'min_samples_split': range(1,6),
          #'min_samples_leaf' : range(1,6)

        }

# range(100, 5001, 100) - 100부터 5000까지 100씩 증가 시켜주세요
grid_model = GridSearchCV(rf_model, param, n_jobs=-1, cv = 5)

# %%
grid_model.fit(X_train, y_train) #시간 좀 걸림

# %%
print(f" 최적 교차검증 점수 : {grid_model.best_score_}") # 최적 파라미터로 찾은 교차검증 점수
print(f" 최적 교차검증 파라미터 목록 : {grid_model.best_params_}") # 최적 파라미터 목록

# %%
best_model = grid_model.best_estimator_ # 최적 모델 만들기

# %%
best_model.fit(X_train, y_train) # 최적 모델 학습

# %%
best_model.score(X_train, y_train) # 최적 모델 훈련 점수

# %%
best_model.score(X_test, y_test) # 최적 모델 평가 점수

# %%
# rf 활용
# predict_proba : 각 클래스별 불확실성 확률 -> 예측확률을 정답별로 표시
# target_names = ['부정', '중립' ,'긍정']
target_names = np.array(["부정", "중립", "긍정"])
review = ['이 화장품은 촉촉해서 건성 피부를 가지신 분이라면 좋을것 같아요']
vect_review = tfidf_pos.transform(review) # 토큰화 변환 진행 코드
pre = rf_model.predict(vect_review)
print(f"{review[0]} 문장은 {rf_model.predict_proba(vect_review).max()*100:.2f}%로 {target_names[pre[0]]} 리뷰입니다!")

# %%
pre1 = rf_model.predict(X_test)
pre1

# %%
translated_pre1 = target_names[pre1]
translated_pre1
