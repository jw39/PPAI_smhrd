# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('./data/result_review_18.csv')
data.drop('review_idx', axis = 1, inplace = True)
data.columns = ['제품명', '닉네임', '평점', '리뷰내용']
data

# %%
fi_review = data["리뷰내용"]
fi_review
# Out:
# 0         샘플링 이벤트로 받아서 사용했습니다 크림토너라 촉촉하고 보습력이 좋아서 건조하지않아...
# 1         로션같은 질감의 토너라서 촉촉하게 바르기 좋아요! 여름보다는 가을 겨울에 잘 쓸 수...
# 2         샘플링 당첨되어 사용해본 결과 로션같은 토너같다고 해야하나? 크림토너같은 제형이라 ...
# 3         밀크토너 느낌이에요, 보습력이 좋은토너여서 건성피부에 좋은제품입니다!!  묵직한 느...
# 4         여름에는 이거 하라로 기초 끝내도 될정도로 촉촉해요. 겨울에도 보습력 있는 토너 하...
#                                 ...
# 183000                                   샀는데 두피가따가워서 안써요 ㅠㅠ
# 183001    기본샀더니 고정안되고 자꾸흘러내려서 집게있는거 구입했더니 집은부분 자국남음 아놔 4...
# 183002    그냥 헤어컬있는거보다는 집게가 같이 든게 움직여도 잘 안떨어져서 편한데 자국이 남고...
# 183003    앞머리 있는지 꽤 오래됐는데 한번도 롤을 사본 적이 없었어요 친구들이 다 쓰길래 한...
# 183004    한번쓰고 두번다시는 안써요; 머리자국 오지게 납니다 집게는 그렇다 치고 롤? 이너무...
# Name: 리뷰내용, Length: 183005, dtype: object

# %%
# 평점 기준
# 긍정 : 5, 4
# 중립 : 3
# 부정 : 2, 1

data['평점']

# 평점 기준
def rating_replace(rating):
    if rating in [5, 4]:  # 긍정은 2로 변경
        return 2
    elif rating == 3:  # 중립은 1로 변경
        return 1
    else:  # 부정은 0으로 변경
        return 0

data['감성분석 결과'] = data['평점'].apply(rating_replace)
data
# Out:
#                           제품명      닉네임  평점  \
# 0       펩타이드 크림 스킨 모이스처라이징 토너   hiinaa   5
# 1       펩타이드 크림 스킨 모이스처라이징 토너     이뿌닝히   5
# 2       펩타이드 크림 스킨 모이스처라이징 토너   0moon2   5
# 3       펩타이드 크림 스킨 모이스처라이징 토너      바비쏭   5
# 4       펩타이드 크림 스킨 모이스처라이징 토너     윤이나씨   5
# ...                       ...      ...  ..
# 183000                집게형 헤어컬       효응   2
# 183001                집게형 헤어컬       댕쓰   2
# 183002                집게형 헤어컬     옹새미로   2
# 183003                집게형 헤어컬  jjj0526   1
# 183004                집게형 헤어컬      해또리   1
#
#                                                      리뷰내용  감성분석 결과
# 0       샘플링 이벤트로 받아서 사용했습니다 크림토너라 촉촉하고 보습력이 좋아서 건조하지않아...        2
# 1       로션같은 질감의 토너라서 촉촉하게 바르기 좋아요! 여름보다는 가을 겨울에 잘 쓸 수...        2
# 2       샘플링 당첨되어 사용해본 결과 로션같은 토너같다고 해야하나? 크림토너같은 제형이라 ...        2
# 3       밀크토너 느낌이에요, 보습력이 좋은토너여서 건성피부에 좋은제품입니다!!  묵직한 느...        2
# 4       여름에는 이거 하라로 기초 끝내도 될정도로 촉촉해요. 겨울에도 보습력 있는 토너 하...        2
# ...                                                   ...      ...
# 183000                                 샀는데 두피가따가워서 안써요 ㅠㅠ        0
# 183001  기본샀더니 고정안되고 자꾸흘러내려서 집게있는거 구입했더니 집은부분 자국남음 아놔 4...        0
# 183002  그냥 헤어컬있는거보다는 집게가 같이 든게 움직여도 잘 안떨어져서 편한데 자국이 남고...        0
# 183003  앞머리 있는지 꽤 오래됐는데 한번도 롤을 사본 적이 없었어요 친구들이 다 쓰길래 한...        0
# 183004  한번쓰고 두번다시는 안써요; 머리자국 오지게 납니다 집게는 그렇다 치고 롤? 이너무...        0
#
# [183005 rows x 5 columns]

# %%
data[data['감성분석 결과']==2].count()
# Out:
# 제품명        133858
# 닉네임        133858
# 평점         133858
# 리뷰내용       133858
# 감성분석 결과    133858
# dtype: int64

# %%
# 리뷰 내용 전처리
X = data['리뷰내용']
y = data['감성분석 결과']

# %%
# 라이브러리 불러오기
from konlpy.tag import Okt
okt = Okt()

# %%
okt.tagset
# Out:
# {'Adjective': '형용사',
#  'Adverb': '부사',
#  'Alpha': '알파벳',
#  'Conjunction': '접속사',
#  'Determiner': '관형사',
#  'Eomi': '어미',
#  'Exclamation': '감탄사',
#  'Foreign': '외국어, 한자 및 기타기호',
#  'Hashtag': '트위터 해쉬태그',
#  'Josa': '조사',
#  'KoreanParticle': '(ex: ㅋㅋ)',
#  'Noun': '명사',
#  'Number': '숫자',
#  'PreEomi': '선어말어미',
#  'Punctuation': '구두점',
#  'ScreenName': '트위터 아이디',
#  'Suffix': '접미사',
#  'Unknown': '미등록어',
#  'Verb': '동사'}

# %%
list_ = []

for i in X:
  list_.append(okt.pos(i, join=True))

list_
# Out:
# [['샘플링/Noun',
#   '이벤트/Noun',
#   '로/Josa',
#   '받아서/Verb',
#   '사용/Noun',
#   '했습니다/Verb',
#   '크림/Noun',
#   '토너/Noun',
#   '라/Josa',
#   '촉촉하고/Adjective',
#   '보습/Noun',
#   '력/Suffix',
#   '이/Josa',
#   '좋아서/Adjective',
#   '건조하지/Adjective',
#   '않아요/Verb',
#   '라네즈/Noun',
#   '크림/Noun',
#   '스킨/Noun',
#   '을/Josa',
#   '미스트/Noun',
#   '로/Josa',
#   '쓰고있는데/Verb',
#   '라네즈/Noun',
#   '와는/Josa',
#   '제/Modifier',
#   '형/Noun',
#   '이/Josa',
#   '많이/Adverb',
#   '달라/Noun',
#   '요/Josa',
#   '은은하게/Adjective',
#   '달달/Noun',
#   '한/Josa',
#   '향/Noun',
#   '이/Josa',
#   '기분/Noun',
#   '좋아요/Adjective'],
#  ['로션/Noun',
#   '같은/Adjective',
#   '질감/Noun',
#   '의/Josa',
#   '토너/Noun',
#   '라서/Josa',
#   '촉촉하게/Adjective',
#   '바르기/Verb',
#   '좋아요/Adjective',
#   '!/Punctuation',
#   '여름/Noun',
#   '보다는/Josa',
#   '가을/Noun',
#   '겨울/Noun',
#   '에/Josa',
#   '잘/Verb',
#   '쓸/Verb',
#   '수/Noun',
#   '있을/Adjective',
#   '것/Noun',
#   '같아요/Adjective',
#   '~/Punctuation'],
#  ['샘플링/Noun',
#   '당첨/Noun',
#   '되어/Verb',
#   '사용/Noun',
#   '해본/Verb',
#   '결과/Noun',
#   '로션/Noun',
#   '같은/Adjective',
#   '토너/Noun',
#   '같다고/Adjective',
#   '해야하나/Verb',
#   '?/Punctuation',
#   '크림/Noun',
#   '토너/Noun',
#   '같은/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '이라/Josa',
#   '촉촉하고/Adjective',
#   '보습/Noun',
#   '감도/Verb',
#   '있어서/Adjective',
#   '한번/Noun',
#   '만/Josa',
#   '발라/Noun',
#   '도/Josa',
#   '건조하지/Adjective',
#   '않아서/Verb',
#   '좋더라구요/Adjective',
#   '!!/Punctuation',
#   '일단/Noun',
#   '제/Noun',
#   '기준/Noun',
#   '에서는/Josa',
#   '합격/Noun',
#   '입니다/Adjective',
#   'ㅎㅎ/KoreanParticle'],
#  ['밀크/Noun',
#   '토너/Noun',
#   '느낌/Noun',
#   '이에요/Josa',
#   ',/Punctuation',
#   '보습/Noun',
#   '력/Suffix',
#   '이/Josa',
#   '좋은/Adjective',
#   '토너/Noun',
#   '여서/Josa',
#   '건성/Noun',
#   '피부/Noun',
#   '에/Josa',
#   '좋은/Adjective',
#   '제품/Noun',
#   '입니다/Adjective',
#   '!!/Punctuation',
#   '묵직한/Adjective',
#   '느낌/Noun',
#   '이지만/Josa',
#   ',,/Punctuation',
#   '흡수/Noun',
#   '력/Suffix',
#   '은/Josa',
#   '좋은/Adjective',
#   '편이/Noun',
#   '라서/Josa',
#   '편하게/Adjective',
#   '바를수/Verb',
#   '있는/Adjective',
#   '토너/Noun',
#   '예요/Josa',
#   '!!~~/Punctuation',
#   '손/Noun',
#   '으로/Josa',
#   '적당히/Adjective',
#   '덜어서/Verb',
#   '촵촵/Noun',
#   '해주기/Verb',
#   '좋은/Adjective',
#   '토너/Noun',
#   '랍니/Noun',
#   '다/Josa',
#   '!!^^/Punctuation'],
#  ['여름/Noun',
#   '에는/Josa',
#   '이/Determiner',
#   '거/Noun',
#   '하라/Noun',
#   '로/Josa',
#   '기초/Noun',
#   '끝내도/Verb',
#   '될/Verb',
#   '정도/Noun',
#   '로/Josa',
#   '촉촉해요/Adjective',
#   './Punctuation',
#   '겨울/Noun',
#   '에도/Josa',
#   '보습/Noun',
#   '력/Suffix',
#   '있는/Adjective',
#   '토너/Noun',
#   '하나/Noun',
#   '추가/Noun',
#   '해도/Verb',
#   '훨씬/Adverb',
#   '촉촉한게/Adjective',
#   '오래/Adverb',
#   '가써요/Verb',
#   './Punctuation',
#   '콧물제형/Noun',
#   '이고/Josa',
#   '보습/Noun',
#   '지속/Noun',
#   '력/Suffix',
#   '도/Josa',
#   '좋은데/Adjective',
#   '끈/Noun',
#   '적/Suffix',
#   '이/Determiner',
#   '거나/Noun',
#   '겉/Noun',
#   '도/Josa',
#   '는거/Verb',
#   '없어서/Adjective',
#   '화장/Noun',
#   '전/Noun',
#   '에도/Josa',
#   '부담/Noun',
#   '없어요/Adjective',
#   './Punctuation'],
#  ['은은하게/Adjective',
#   '복숭아/Noun',
#   '향/Noun',
#   '이/Josa',
#   '나고/Verb',
#   '흡수/Noun',
#   '가/Josa',
#   '몇번/Noun',
#   '두드리니까/Verb',
#   '보송보송/Noun',
#   '빠르게/Adjective',
#   '되서/Verb',
#   '좋아요/Adjective',
#   '한번/Noun',
#   '바르고/Verb',
#   '약간/Noun',
#   '당김/Verb',
#   '느껴지는거/Verb',
#   '같아서/Adjective',
#   '한번/Noun',
#   '더/Noun',
#   './Punctuation'],
#  ['스킨/Noun',
#   '치고/Josa',
#   '비싸다고/Adjective',
#   '생각/Noun',
#   '했는데/Verb',
#   '기/Modifier',
#   '대/Modifier',
#   '이상/Noun',
#   '이네/Josa',
#   '요/Noun',
#   './Punctuation',
#   '여름/Noun',
#   '이라/Josa',
#   '에센스/Noun',
#   '대용/Noun',
#   '으로도/Josa',
#   '사용/Noun',
#   '가능할/Adjective',
#   '정도/Noun',
#   '로/Josa',
#   '촉촉하고/Adjective',
#   '피부/Noun',
#   '에/Josa',
#   '부족함/Noun',
#   '없이/Adverb',
#   '잘/Verb',
#   '스며들어요/Verb',
#   './Punctuation',
#   '민감/Noun',
#   '성/Suffix',
#   '인데/Josa',
#   '자극/Noun',
#   '이/Josa',
#   '없네요/Adjective',
#   './Punctuation',
#   '스킨/Noun',
#   '으로는/Josa',
#   '솜/Noun',
#   '에/Josa',
#   '뭍/Noun',
#   '여서/Josa',
#   '닦아내고/Verb',
#   '에센스/Noun',
#   '로는/Josa',
#   '한번/Noun',
#   '더/Noun',
#   '발라/Noun',
#   '줬어요/Verb',
#   '^^/Punctuation',
#   '달달/Noun',
#   '한/Josa',
#   '향/Noun',
#   '이/Josa',
#   '기분/Noun',
#   '좋게/Adjective',
#   '하네요/Verb',
#   './Punctuation'],
#  ['스킨/Noun',
#   '만/Josa',
#   '발라/Noun',
#   '도/Josa',
#   '될/Verb',
#   '정도/Noun',
#   '의/Josa',
#   '쫀쫀/Noun',
#   '한/Determiner',
#   '제/Modifier',
#   '형/Noun',
#   '이에요/Josa',
#   '세안/Noun',
#   '후/Noun',
#   '바르니/Verb',
#   '당김/Verb',
#   '없고/Adjective',
#   '산뜻해서/Adjective',
#   '좋았어요/Adjective'],
#  ['여름/Noun',
#   '에/Josa',
#   '에센스/Noun',
#   '대신/Noun',
#   '쓸만큼/Verb',
#   '촉촉해용/Adjective',
#   '3/Number',
#   '번/Noun',
#   '~/Punctuation',
#   '5/Number',
#   '번/Noun',
#   '정도/Noun',
#   '바르고/Verb',
#   '바로/Noun',
#   '화장/Noun',
#   '해도/Verb',
#   '될만큼/Verb',
#   '보습/Noun',
#   '력/Suffix',
#   '이/Josa',
#   '좋아요/Adjective'],
#  ['진짜/Noun',
#   '최고/Noun',
#   '예요/Josa',
#   '.../Punctuation',
#   '보습/Noun',
#   '력/Suffix',
#   '대박/Noun',
#   '에/Josa',
#   '바르면/Verb',
#   '바로/Noun',
#   '피부/Noun',
#   '보들보들/Adverb',
#   '해져요/Verb',
#   '진짜/Noun',
#   '최고/Noun',
#   '.../Punctuation',
#   '랩/Noun',
#   '클/Verb',
#   '스킨/Noun',
#   '케어/Noun',
#   '라인/Noun',
#   '다/Adverb',
#   '좋아요/Adjective',
#   '바르고/Verb',
#   '다음/Noun',
#   '날/Noun',
#   '부터/Josa',
#   '바로/Noun',
#   '피부/Noun',
#   '광남/Noun',
#   '../Punctuation'],
#  ['보습/Noun',
#   '력/Suffix',
#   '대박/Noun',
#   '이/Suffix',
#   '예요/Josa',
#   '!/Punctuation',
#   '피부/Noun',
#   '컨디션/Noun',
#   '이/Josa',
#   '푸석푸석하고/Adjective',
#   '안좋은/Adjective',
#   '날/Noun',
#   '3/Number',
#   '번/Noun',
#   '덧/Noun',
#   '바르고/Verb',
#   '크림/Noun',
#   '만/Josa',
#   '바르고/Verb',
#   '잤더니/Verb',
#   '다음/Noun',
#   '날/Noun',
#   '피부/Noun',
#   '컨디션/Noun',
#   '이/Josa',
#   '정말/Noun',
#   '좋아졌어요/Verb',
#   'ㅎㅎ/KoreanParticle',
#   '무향/Noun',
#   '이고/Josa',
#   '미끌거리지/Verb',
#   '않아서/Verb',
#   '더/Noun',
#   '좋았어요/Adjective'],
#  ['토너/Noun',
#   '화장/Noun',
#   '솜/Noun',
#   '에/Josa',
#   '묻혀/Verb',
#   '피부/Noun',
#   '에/Josa',
#   '가볍게/Adjective',
#   '닦/Verb',
#   '기/Noun',
#   '좋은/Adjective',
#   '자극/Noun',
#   '없는/Adjective',
#   '제품/Noun',
#   '최고/Noun',
#   '!!/Punctuation',
#   '지난번/Noun',
#   '사용/Noun',
#   '한적/Noun',
#   '있었는데/Adjective',
#   '좋았다/Adjective',
#   '생각/Noun',
#   '했었거든요/Verb',
#   '!!/Punctuation'],
#  ['제/Noun',
#   '가/Josa',
#   '쓰것/Verb',
#   '중/Noun',
#   '에/Josa',
#   '간편하고/Adjective',
#   '좋아요/Adjective',
#   '향/Noun',
#   '도/Josa',
#   '진하지/Adjective',
#   '않고/Verb',
#   '끈/Noun',
#   '적임/Noun',
#   '도/Josa',
#   '덜함/Adjective',
#   './Punctuation',
#   '피부/Noun',
#   '가/Josa',
#   '건조/Noun',
#   '햇/Noun',
#   '는데/Verb',
#   '이/Determiner',
#   '거/Noun',
#   '쓰고나서/Verb',
#   '덜하고/Adjective',
#   '부들부들/Noun',
#   '거려/Noun',
#   '요/Josa',
#   '믿고/Verb',
#   '쓸만/Verb',
#   '하네용/Verb',
#   'ㅎㅎ/KoreanParticle',
#   '촉촉함이/Adjective',
#   '오래/Adverb',
#   '남아/Noun',
#   '잇어서/Verb',
#   '좋아요/Adjective',
#   'ㅎㅎㅎ/KoreanParticle',
#   '저/Noun',
#   '같은/Adjective',
#   '피부/Noun',
#   '엔/Josa',
#   '딱이에/Adjective',
#   '용/Noun'],
#  ['약간/Noun',
#   '의/Josa',
#   '유/Noun',
#   '분기/Noun',
#   '가/Josa',
#   '느껴지는데/Verb',
#   '흡수/Noun',
#   '도/Josa',
#   '빠르고/Adjective',
#   '끈/Noun',
#   '적임/Noun',
#   '이/Josa',
#   '없는/Adjective',
#   '스킨/Noun',
#   '입니다/Adjective',
#   './Punctuation',
#   '소량/Noun',
#   '만/Josa',
#   '써도/Verb',
#   '피부/Noun',
#   '가/Josa',
#   '촉촉하고/Adjective',
#   ',/Punctuation',
#   '보습/Noun',
#   '감/Noun',
#   '이/Josa',
#   '좋아서/Adjective',
#   '피부/Noun',
#   '건조한/Adjective',
#   '사람/Noun',
#   '은/Josa',
#   '계절/Noun',
#   '상관없이/Adjective',
#   '쓰기/Noun',
#   '좋아/Adjective',
#   '보입니다/Verb',
#   './Punctuation',
#   '개인/Noun',
#   '적/Suffix',
#   '으로는/Josa',
#   '화장/Noun',
#   '솜/Noun',
#   '에/Josa',
#   '덜어/Verb',
#   '쓰기/Noun',
#   '보다는/Josa',
#   '손/Noun',
#   '에/Josa',
#   '덜어/Verb',
#   '쓰는/Verb',
#   '것/Noun',
#   '이/Josa',
#   '더/Noun',
#   '좋았고요/Adjective',
#   './Punctuation',
#   '보습/Noun',
#   '유지/Noun',
#   '력/Suffix',
#   '도/Josa',
#   '괜찮은/Adjective',
#   '편입/Noun',
#   '니/Noun',
#   '다/Josa',
#   './Punctuation',
#   '피부/Noun',
#   '가/Josa',
#   '답답하지/Adjective',
#   '않으면서/Verb',
#   '피부/Noun',
#   '속/Modifier',
#   '당/Modifier',
#   '김/Noun',
#   '도/Josa',
#   '잘/Verb',
#   '잡아줘서/Verb',
#   '여름/Noun',
#   '에는/Josa',
#   '요/Modifier',
#   '거/Noun',
#   '하나/Noun',
#   '만/Josa',
#   '발라/Noun',
#   '도/Josa',
#   '괜찮을/Adjective',
#   '것/Noun',
#   '같아요/Adjective',
#   './Punctuation'],
#  ['흰색/Noun',
#   '의/Josa',
#   '약간/Noun',
#   '묽은/Adjective',
#   '로션/Noun',
#   '같은/Adjective',
#   '느낌/Noun',
#   '의/Josa',
#   '제/Modifier',
#   '형/Noun',
#   '이에요/Josa',
#   '제/Modifier',
#   '형/Noun',
#   '덕분/Noun',
#   '에/Josa',
#   '일반/Noun',
#   '물/Noun',
#   '같은/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '의/Josa',
#   '토너/Noun',
#   '보다/Josa',
#   '훨씬/Adverb',
#   '촉촉하고/Adjective',
#   '그/Noun',
#   '지/Modifier',
#   '속성/Noun',
#   '이/Josa',
#   '오래/Adverb',
#   '가는/Verb',
#   '것/Noun',
#   '같아요/Adjective',
#   '향/Noun',
#   '도/Josa',
#   '좋음/Adjective'],
#  ['글/Noun',
#   '로우/Noun',
#   '픽/Noun',
#   '이벤트/Noun',
#   '로/Josa',
#   '샘플/Noun',
#   '을/Josa',
#   '받아/Verb',
#   '사용/Noun',
#   '해봤는데/Verb',
#   '함께/Adverb',
#   '온/Noun',
#   '다른/Noun',
#   '제품/Noun',
#   '샘플/Noun',
#   '들/Suffix',
#   '중/Noun',
#   '가장/Noun',
#   '맘/Noun',
#   '에/Josa',
#   '들었던/Verb',
#   '제품/Noun',
#   '이에요/Josa',
#   '크림/Noun',
#   '스킨/Noun',
#   '은/Josa',
#   '타/Modifier',
#   '사제품/Noun',
#   '으로/Josa',
#   '사용/Noun',
#   '해봤는데/Verb',
#   '유/Noun',
#   '분/Suffix',
#   '이/Josa',
#   '많아/Adjective',
#   '기대/Noun',
#   '이하/Noun',
#   '였었는데/Verb',
#   '랩/Noun',
#   '클/Verb',
#   '크림/Noun',
#   '스킨/Noun',
#   '은/Josa',
#   '유/Noun',
#   '분/Suffix',
#   '이/Josa',
#   '과/Noun',
#   '하지/Verb',
#   '않아/Verb',
#   '특히/Adverb',
#   '좋았어요/Adjective',
#   '우윳빛/Noun',
#   '의/Josa',
#   '토너/Noun',
#   '로/Josa',
#   '향/Noun',
#   '도/Josa',
#   '미세하고/Adjective',
#   '은은하게/Adjective',
#   '나서/Verb',
#   '부담/Noun',
#   '스럽지/Josa',
#   '않고/Verb',
#   '촉촉하게/Adjective',
#   '스며들고/Verb',
#   '좋았어요/Adjective'],
#  ['물/Noun',
#   '처럼/Josa',
#   '흐르고/Verb',
#   '가벼운/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '의/Josa',
#   '토너/Noun',
#   '에요/Josa',
#   '하얀색/Noun',
#   '이라/Josa',
#   '우유/Noun',
#   '같고/Adjective',
#   '촉촉함이/Adjective',
#   '정말/Noun',
#   '남다르더라구요/Adjective',
#   '!/Punctuation',
#   '피부/Noun',
#   '에/Josa',
#   '올렸을/Verb',
#   '때/Noun',
#   '무겁지/Adjective',
#   '않고/Verb',
#   '건조함만/Adjective',
#   '딱/Adverb',
#   '잡아주는/Verb',
#   '느낌/Noun',
#   '이라/Josa',
#   '기초/Noun',
#   '템/Noun',
#   '으로/Josa',
#   '강추/Noun',
#   '❤/Foreign'],
#  ['랩/Noun',
#   '클/Verb',
#   '펩타이드/Noun',
#   '라인/Noun',
#   '이/Josa',
#   '순하고/Adjective',
#   '촉촉해서/Adjective',
#   '좋아요/Adjective',
#   '랩/Noun',
#   '클/Verb',
#   '펩타이드/Noun',
#   '크림/Noun',
#   '을/Josa',
#   '글픽/Noun',
#   '평가/Noun',
#   '단/Noun',
#   '으로/Josa',
#   '처음/Noun',
#   '써/Verb',
#   '보고/Noun',
#   '너무/Adverb',
#   '만족스러워서/Adjective',
#   '같은/Adjective',
#   '팹/Noun',
#   '타/Modifier',
#   '이드/Noun',
#   '라인/Noun',
#   '의/Josa',
#   '크림/Noun',
#   '스킨/Noun',
#   '도/Josa',
#   '써/Verb',
#   '봤는데/Verb',
#   '역시/Noun',
#   '좋네요/Adjective',
#   '건조/Noun',
#   '감/Noun',
#   '잡아주는데/Verb',
#   '너무/Adverb',
#   '좋은데/Adjective',
#   '그렇다고/Conjunction',
#   '과/Noun',
#   '하게/Verb',
#   '무겁거나/Adjective',
#   '끈/Noun',
#   '적/Suffix',
#   '이지/Josa',
#   '않아요/Verb',
#   '바르고/Verb',
#   '촥촥/Noun',
#   '두드려주면/Verb',
#   '잘/Verb',
#   '흡수/Noun',
#   '돼요/Verb'],
#  ['건성/Noun',
#   '+/Punctuation',
#   '민감/Noun',
#   '성/Suffix',
#   '+/Punctuation',
#   '여드름/Noun',
#   '성/Suffix',
#   '피부/Noun',
#   '를/Josa',
#   '가졌으며/Verb',
#   '클렌징/Noun',
#   '을/Josa',
#   '좀/Noun',
#   '세게/Verb',
#   '하는/Verb',
#   '편이/Noun',
#   '라/Josa',
#   '스킨/Noun',
#   '토너/Noun',
#   '부터가/Josa',
#   '장벽/Noun',
#   '강화/Noun',
#   '가/Josa',
#   '되는/Verb',
#   '제품/Noun',
#   '을/Josa',
#   '선호/Noun',
#   '하고/Josa',
#   '사용/Noun',
#   '하고/Josa',
#   '있습니다/Adjective',
#   './Punctuation',
#   '크림/Noun',
#   '스킨/Noun',
#   '은/Josa',
#   '라/Josa',
#   '**/Punctuation',
#   '가/Verb',
#   '유명하지만/Adjective',
#   '크림/Noun',
#   '스킨/Noun',
#   '을/Josa',
#   '좋아해서/Adjective',
#   '타사/Verb',
#   '브랜드/Noun',
#   '도/Josa',
#   '많이/Adverb',
#   '접/Noun',
#   '해봐서/Verb',
#   '이/Noun',
#   '스킨/Noun',
#   '이/Josa',
#   '궁금했습니다/Adjective',
#   './Punctuation',
#   '약간/Noun',
#   '에/Josa',
#   '풀향/Noun',
#   '이/Josa',
#   '나/Noun',
#   '는/Josa',
#   '점성/Noun',
#   '이/Josa',
#   '있는/Adjective',
#   '스킨/Noun',
#   '으로/Josa',
#   '스킨/Noun',
#   '하나로/Noun',
#   '도/Josa',
#   '촉촉함이/Adjective',
#   '남다릅니다/Adjective',
#   './Punctuation',
#   '특히/Adverb',
#   '나/Noun',
#   '두/Determiner',
#   '세번/Noun',
#   '레이어/Noun',
#   '링/Noun',
#   '했는데/Verb',
#   '세/Modifier',
#   '럼/Noun',
#   '이나/Josa',
#   '크림/Noun',
#   '을/Josa',
#   '한동안/Adverb',
#   '바르지/Verb',
#   '않았는데도/Verb',
#   '건조함이/Adjective',
#   '느껴지지/Verb',
#   '않았습니다/Verb',
#   './Punctuation',
#   '트러블/Noun',
#   '같은/Adjective',
#   '이상/Noun',
#   '반응/Noun',
#   '도/Josa',
#   '없이/Adverb',
#   '피부/Noun',
#   '가/Josa',
#   '편안한/Adjective',
#   '느낌/Noun',
#   '이/Josa',
#   '참/Verb',
#   '좋았습니다/Adjective',
#   './Punctuation',
#   '사용/Noun',
#   '기한/Noun',
#   '이/Josa',
#   '길어지면/Verb',
#   '미백/Noun',
#   '주름/Noun',
#   '기능/Noun',
#   '도/Josa',
#   '있을지/Adjective',
#   '기대/Noun',
#   '가/Josa',
#   '되는/Verb',
#   '제품/Noun',
#   '입니다/Adjective',
#   './Punctuation',
#   '전체/Noun',
#   '적/Suffix',
#   '으로/Josa',
#   '제/Noun',
#   '피부/Noun',
#   '타입/Noun',
#   '에/Josa',
#   '잘/Verb',
#   '맞아서/Verb',
#   '좋은/Adjective',
#   '경험/Noun',
#   '이/Josa',
#   '였습니다/Verb',
#   './Punctuation'],
#  ['제/Noun',
#   '얼굴/Noun',
#   '은/Josa',
#   '악/Noun',
#   '건성/Noun',
#   '인데/Josa',
#   '발라/Noun',
#   '보니/Verb',
#   '수분/Noun',
#   '도/Josa',
#   '많고/Adjective',
#   '너무/Adverb',
#   '좋아요/Adjective',
#   '수시로/Adverb',
#   '저녁/Noun',
#   '에/Josa',
#   '바르고/Verb',
#   '자면/Verb',
#   '아침/Noun',
#   '에/Josa',
#   '화장/Noun',
#   '이/Josa',
#   './Punctuation',
#   '잘/Verb',
#   '머/Noun',
#   '금고/Noun',
#   './Punctuation',
#   '피부/Noun',
#   '에도/Josa',
#   '좋아요/Adjective'],
#  ['글/Noun',
#   '로우/Noun',
#   '픽/Noun',
#   '이벤트/Noun',
#   '로/Josa',
#   '샘플/Noun',
#   '받아/Verb',
#   '써/Verb',
#   '봤어요/Verb',
#   './Punctuation',
#   '전/Noun',
#   '여름/Noun',
#   '에/Josa',
#   '유/Noun',
#   '분기/Noun',
#   '가/Josa',
#   '많아져서/Verb',
#   '토너/Noun',
#   '하나/Noun',
#   '만/Josa',
#   '바르고/Verb',
#   '지내는/Verb',
#   '상태/Noun',
#   '이지만/Josa',
#   '에어컨/Noun',
#   '틀었을/Verb',
#   '땐/Noun',
#   '피부/Noun',
#   '가/Josa',
#   '건조해져서/Adjective',
#   '수분/Noun',
#   '에센스/Noun',
#   '덧/Noun',
#   '발라/Noun',
#   '야/Josa',
#   '하는데/Verb',
#   ',/Punctuation',
#   '에센스/Noun',
#   '대신/Noun',
#   '덧/Noun',
#   '바르기/Verb',
#   '좋네요/Adjective',
#   './Punctuation',
#   '일반/Noun',
#   '토너/Noun',
#   '보다는/Josa',
#   '좀/Noun',
#   '더/Noun',
#   '유액/Noun',
#   '같은/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '이라/Josa',
#   '닦는/Verb',
#   '토너/Noun',
#   '로는/Josa',
#   '맞지/Verb',
#   '않는데/Verb',
#   ',/Punctuation',
#   '에센스/Noun',
#   '와/Josa',
#   '토너/Noun',
#   '가/Josa',
#   '합쳐졌다는/Verb',
#   '느낌/Noun',
#   '으로/Josa',
#   '손/Noun',
#   '으로/Josa',
#   '찹/Verb',
#   '찹/Verb',
#   '흡수/Noun',
#   '시키면서/Verb',
#   '쓰기/Noun',
#   '괜찮아요/Adjective',
#   './Punctuation',
#   '펩타이드/Noun',
#   '와/Josa',
#   '미백/Noun',
#   '기능/Noun',
#   '성/Suffix',
#   '성분/Noun',
#   '이/Josa',
#   '들어있어/Verb',
#   '토너/Noun',
#   '하나/Noun',
#   '만/Josa',
#   '발라/Noun',
#   '도/Josa',
#   '뭔가/Noun',
#   '케어/Noun',
#   '를/Josa',
#   '더/Noun',
#   '하는/Verb',
#   '것/Noun',
#   '같아/Adjective',
#   '맘/Noun',
#   '에/Josa',
#   '드네/Noun',
#   '요/Josa',
#   './Punctuation',
#   '여름/Noun',
#   '에/Josa',
#   '다른/Noun',
#   '기초/Noun',
#   '없이/Adverb',
#   '(/Punctuation',
#   '선크림/Noun',
#   '은/Josa',
#   '필수/Noun',
#   '!)/Punctuation',
#   '이/Determiner',
#   '것/Noun',
#   '만/Josa',
#   '써도/Verb',
#   '꽤/Noun',
#   '촉촉했어요/Adjective',
#   './Punctuation',
#   '환절기/Noun',
#   '나/Josa',
#   '건조한/Adjective',
#   '계절/Noun',
#   '에/Josa',
#   '보습/Noun',
#   '감/Noun',
#   '이/Josa',
#   '좋은/Adjective',
#   '토너/Noun',
#   '찾는/Verb',
#   '분/Noun',
#   '들께도/Verb',
#   '좋을/Adjective',
#   '듯/Noun',
#   '해요/Verb',
#   './Punctuation'],
#  ['굉장히/Adjective',
#   '순하고/Adjective',
#   '에멀젼/Noun',
#   '타입/Noun',
#   '의/Josa',
#   '토너/Noun',
#   '인데/Josa',
#   '무겁지/Adjective',
#   '않고/Verb',
#   '가볍게/Adjective',
#   '바르기/Verb',
#   '좋아요/Adjective',
#   '!!!/Punctuation',
#   '저/Noun',
#   '는/Josa',
#   '원래/Noun',
#   '닦/Verb',
#   '토파/Noun',
#   '인데/Josa',
#   '이/Determiner',
#   '토너/Noun',
#   '는/Josa',
#   '그냥/Noun',
#   '바르기만/Verb',
#   '해도/Noun',
#   '피부/Noun',
#   '결/Noun',
#   '이/Josa',
#   '부드러워지는게/Adjective',
#   '느껴집니다/Verb',
#   './Punctuation',
#   '재구매/Verb',
#   '의사/Noun',
#   '100%/Number',
#   '!/Foreign'],
#  ['크리미/Noun',
#   '한/Josa',
#   '토너/Noun',
#   '로/Josa',
#   '촉촉하게/Adjective',
#   '수분/Noun',
#   '을/Josa',
#   '채워주는/Verb',
#   '제품/Noun',
#   '이에요/Josa',
#   './Punctuation',
#   '건조하거나/Adjective',
#   '수분/Noun',
#   '충전/Noun',
#   '이/Josa',
#   '필요할/Adjective',
#   '때/Noun',
#   '쓰면/Verb',
#   '좋을/Adjective',
#   '것/Noun',
#   '같아요/Adjective',
#   './Punctuation',
#   '완전/Noun',
#   '이/Josa',
#   '물/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '이/Josa',
#   '아니라서/Adjective',
#   '흡수/Noun',
#   '되고/Verb',
#   '나서도/Verb',
#   '건조하지/Adjective',
#   '않아요/Verb',
#   './Punctuation',
#   '적당/Noun',
#   '이/Josa',
#   '촉촉함과/Adjective',
#   '아주/Noun',
#   '약간/Noun',
#   '의/Josa',
#   '유/Noun',
#   '분/Suffix',
#   '감/Noun',
#   '이/Josa',
#   '있어서/Adjective',
#   '금방/Noun',
#   '건조해지지는/Adjective',
#   '않아요/Verb',
#   './Punctuation',
#   '닦/Verb',
#   '토/Noun',
#   '용은/Verb',
#   '아니라서/Adjective',
#   '흡/Exclamation',
#   '토로/Noun',
#   '사용/Noun',
#   '중/Suffix',
#   '인데/Josa',
#   '무난/Noun',
#   '무난/Noun',
#   '하/Suffix',
#   '게/Josa',
#   '만족합니다/Adjective',
#   './Punctuation',
#   '속/Modifier',
#   '건조/Noun',
#   '심하거나/Adjective',
#   '클렌징/Noun',
#   '과/Noun',
#   '하게/Verb',
#   '했을/Verb',
#   '때/Noun',
#   '사용/Noun',
#   '중이/Noun',
#   '에요/Josa',
#   './Punctuation',
#   '트러블/Noun',
#   '도/Josa',
#   '없고/Adjective',
#   '촉촉해서/Adjective',
#   '겨울/Noun',
#   '에/Josa',
#   '쓰기/Noun',
#   '좋을/Adjective',
#   '것/Noun',
#   '같네요/Adjective',
#   '!/Punctuation'],
#  ['제/Modifier',
#   '형/Noun',
#   '은/Josa',
#   '워터/Noun',
#   '리/Noun',
#   '한/Josa',
#   '물/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '느낌/Noun',
#   '이/Josa',
#   '아니고/Adjective',
#   '점성/Noun',
#   '이/Josa',
#   '있는/Adjective',
#   '크림/Noun',
#   '스킨/Noun',
#   '점성/Noun',
#   '이/Josa',
#   '있어서/Adjective',
#   '닦/Verb',
#   '토/Noun',
#   '대신/Noun',
#   '손/Noun',
#   '으로/Josa',
#   '펴/Verb',
#   '바르는게/Verb',
#   '좋아요/Adjective',
#   '!/Punctuation',
#   '끈/Noun',
#   '적임/Noun',
#   '없이/Adverb',
#   '보습/Noun',
#   '감/Noun',
#   '흡수/Noun',
#   '력/Suffix',
#   '이/Josa',
#   '좋고/Adjective',
#   '수/Modifier',
#   '부지/Noun',
#   '인/Josa',
#   '저/Noun',
#   '한테/Josa',
#   '잘/Verb',
#   '맞는거/Verb',
#   '같아요/Adjective',
#   '!/Punctuation'],
#  ['저/Noun',
#   '는/Josa',
#   '평소/Noun',
#   '에도/Josa',
#   '수분/Noun',
#   '감/Noun',
#   '가득하고/Adjective',
#   '발림/Noun',
#   '성/Suffix',
#   '이/Josa',
#   '깔끔해서/Adjective',
#   '겉/Noun',
#   '에만/Josa',
#   '촉촉한/Adjective',
#   '토너/Noun',
#   '가/Josa',
#   '아닌/Adjective',
#   '속/Noun',
#   '까지/Josa',
#   '촉촉함이/Adjective',
#   '점점/Noun',
#   '스며드는/Verb',
#   '토너/Noun',
#   '를/Josa',
#   '선호/Noun',
#   '하는데요/Verb',
#   '!/Punctuation',
#   '특히/Adverb',
#   '요즘/Noun',
#   '같은/Adjective',
#   '여름/Noun',
#   '부터/Josa',
#   '가을/Noun',
#   '까지/Josa',
#   '속/Modifier',
#   '건조/Noun',
#   '잡기/Noun',
#   '가/Josa',
#   '힘든/Adjective',
#   '계절/Noun',
#   '에는/Josa',
#   '토너/Noun',
#   '를/Josa',
#   '건너/Noun',
#   '뛰거나/Verb',
#   '기초/Noun',
#   '화장/Noun',
#   '을/Josa',
#   '대충/Noun',
#   '해서/Verb',
#   '엄청/Adverb',
#   '건조하지/Adjective',
#   '않아도/Verb',
#   '화장/Noun',
#   '이/Josa',
#   '뜨는/Verb',
#   '경우/Noun',
#   '가/Josa',
#   '대/Modifier',
#   '반수/Noun',
#   '였는데요/Verb',
#   '피부/Noun',
#   '속/Noun',
#   '부터/Josa',
#   '수분/Noun',
#   '감/Noun',
#   '을/Josa',
#   '채워/Verb',
#   '넣어/Verb',
#   '속/Modifier',
#   '건조/Noun',
#   '완화/Noun',
#   '에/Josa',
#   '도움/Noun',
#   '이/Josa',
#   '되는/Verb',
#   '토너/Noun',
#   '가/Josa',
#   '있다고/Adjective',
#   '해서/Verb',
#   '사용/Noun',
#   '해봤어요/Verb',
#   '!/Punctuation',
#   '글로우픽/Noun',
#   '에서/Josa',
#   '2021년/Number',
#   '도에/Foreign',
#   '이미/Adverb',
#   '1등/Number',
#   '을/Foreign',
#   '했어서/Verb',
#   '다/Adverb',
#   '들/Verb',
#   '잘/Verb',
#   '아실거라고/Verb',
#   '생각/Noun',
#   '해요/Verb',
#   '!!/Punctuation',
#   '일반/Noun',
#   '화장품/Noun',
#   '회사/Noun',
#   '가/Josa',
#   '아닌/Adjective',
#   '현/Modifier',
#   '대/Modifier',
#   '약품/Noun',
#   '에서/Josa',
#   '제조/Noun',
#   '한/Josa',
#   '화장품/Noun',
#   '으로/Josa',
#   '펩타이드/Noun',
#   '5/Number',
#   '종이/Noun',
#   '들어가있어/Verb',
#   '피부/Noun',
#   '속/Modifier',
#   '건조/Noun',
#   '뿐/Suffix',
#   '만/Josa',
#   '아니라/Adjective',
#   '탱/Adverb',
#   '글함/Noun',
#   '까지/Josa',
#   '잡아주는/Verb',
#   '건성/Noun',
#   '맞춤/Noun',
#   '템/Noun',
#   '이었습니다/Verb',
#   '!/Punctuation',
#   '기초/Noun',
#   '화장/Noun',
#   '이/Josa',
#   '너무/Adverb',
#   '두꺼우면/Adjective',
#   '밀리는/Verb',
#   '요즘/Noun',
#   '펩타이드/Noun',
#   '토너/Noun',
#   '써/Verb',
#   '보면/Verb',
#   '어떠세요/Adjective',
#   '?/Punctuation'],
#  ['엄청/Adverb',
#   '워터/Noun',
#   '리/Noun',
#   '한/Josa',
#   '제/Modifier',
#   '형/Noun',
#   '이/Josa',
#   '아니라서/Adjective',
#   '흡수/Noun',
#   '가/Josa',
#   '덜/Noun',
#   '될/Verb',
#   '줄/Noun',
#   '알았는데/Verb',
#   '아닙니다/Adjective',
#   '../Punctuation',
#   '흡수/Noun',
#   '도/Josa',
#   '잘/VerbPrefix',
#   '되고/Verb',
#   '피부/Noun',
#   '가/Josa',
#   '쫀쫀/Noun',
#   '해져요/Verb',
#   '!/Punctuation',
#   '개인/Noun',
#   '적/Suffix',
#   '으로/Josa',
#   '흡/Exclamation',
#   '토/Noun',
#   '정말/Noun',
#   '좋아하는데/Adjective',
#   '이/Noun',
#   '친구/Noun',
#   '흡/Exclamation',
#   '토/Noun',
#   '하기/Verb',
#   '좋은/Adjective',
#   '토너/Noun',
#   '입니다/Adjective',
#   '~/Punctuation',
#   '피부/Noun',
#   '결/Noun',
#   '도/Josa',
#   '정돈/Noun',
#   '되고/Verb',
#   '가볍습니다/Adjective',
#   '!/Punctuation',
#   '속/Modifier',
#   '건조/Noun',
#   '까지/Josa',
#   '잡아주는데/Verb',
#   '../Punctuation',
#   '샘플링/Noun',
#   '으로/Josa',
#   '받은거라/Verb',
#   '양/Noun',
#   '이/Josa',
#   '적어서/Verb',
#   '그냥/Noun',
#   '이참/Noun',
#   '에/Josa',
#   '넘/Verb',
#   '좋아서/Adjective',
#   '하나/Noun',
#   '사/Noun',
#   '버렸어요/Verb',
#   '../Punctuation'],
#  ['향/Noun',
#   '이/Josa',
#   '상큼/Noun',
#   '한/Josa',
#   '과일/Noun',
#   '향/Noun',
#   '인/Josa',
#   '듯/Noun',
#   '하면서/Verb',
#   '뭔가/Noun',
#   '오묘해요/Adjective',
#   'ㅋㅋㅋ/KoreanParticle',
#   '저/Noun',
#   '는/Josa',
#   '개인/Noun',
#   '적/Suffix',
#   '으로/Josa',
#   '호/Noun',
#   '입니다/Adjective',
#   '!/Punctuation',
#   '지성인/Noun',
#   '저/Noun',
#   '는/Josa',
#   '여름/Noun',
#   '에/Josa',
#   '아침/Noun',
#   '에/Josa',
#   '바쁠/Adjective',
#   '때/Noun',
#   '요/Modifier',
#   '거/Noun',
#   '하나/Noun',
#   '만/Josa',
#   '후다닥/Noun',
#   '발라/Noun',
#   '도/Josa',
#   '안/VerbPrefix',
#   '건조하고/Adjective',
#   '화장/Noun',
#   '잘/VerbPrefix',
#   '먹어서/Verb',
#   '유용하게/Adjective',
#   '써요/Verb',
#   '!/Punctuation',
#   '건성/Noun',
#   '분들/Suffix',
#   '은/Josa',
#   '겨울/Noun',
#   '에/Josa',
#   '스킨/Noun',
#   '단계/Noun',
#   '에/Josa',
#   '쓰면/Verb',
#   '촉촉할것/Adjective',
#   '같아용/Adjective',
#   '지성은/Noun',
#   '여름/Noun',
#   '에/Josa',
#   '요/Modifier',
#   '거/Noun',
#   '하나/Noun',
#   '만/Josa',
#   '써도/Verb',
#   '괜찮습니다/Adjective',
#   '!!/Punctuation'],
#  ['❤️/Foreign',
#   '독일/Noun',
#   '더마/Adjective',
#   '테스트/Noun',
#   '로/Josa',
#   '인정받은/Verb',
#   '100시간/Number',
#   '고/Modifier',
#   '보습/Noun',
#   '스킨/Noun',
#   '❤️/Foreign',
#   '크림/Noun',
#   '스킨/Noun',
#   '이란/Josa',
#   '이름/Noun',
#   '대로/Josa',
#   '점성/Noun',
#   '있는/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '의/Josa',
#   '촉촉한/Adjective',
#   '토너/Noun',
#   '이자/Noun',
#   '가벼운/Adjective',
#   '수분/Noun',
#   '감/Noun',
#   '❤️/Foreign',
#   '끈/Noun',
#   '적임/Noun',
#   '없이/Adverb',
#   '스며드는/Verb',
#   '흡수/Noun',
#   '감/Noun',
#   '❤️/Foreign',
#   '두/Determiner',
#   '번/Noun',
#   '레이어/Noun',
#   '링/Noun',
#   '해서/Verb',
#   '바르면/Verb',
#   '다른/Noun',
#   '크림/Noun',
#   '이/Josa',
#   '필요/Noun',
#   '없을/Adjective',
#   '정도/Noun',
#   '의/Josa',
#   '보습/Noun',
#   '감/Noun',
#   '까지/Josa',
#   '완벽/Noun',
#   '❤️/Foreign',
#   '펩타이드/Noun',
#   '성분/Noun',
#   '으로/Josa',
#   '민감/Noun',
#   '성/Suffix',
#   '피부/Noun',
#   '도/Josa',
#   '사용/Noun',
#   '가능/Noun',
#   '❤️/Foreign',
#   '속/Modifier',
#   '건조/Noun',
#   '를/Josa',
#   '잡는/Verb',
#   '크림/Noun',
#   '스킨/Noun',
#   '(/Punctuation',
#   '미스트/Noun',
#   '용기/Noun',
#   '에/Josa',
#   '넣으면/Verb',
#   '크림/Noun',
#   '미스트/Noun',
#   '로/Josa',
#   '사용/Noun',
#   '가능/Noun',
#   ')/Punctuation',
#   '❤️/Foreign',
#   '영양가/Noun',
#   '듬뿍/Noun',
#   '들어가/Verb',
#   '있어서/Adjective',
#   '믿음직함/Adjective',
#   '✔️/Foreign',
#   '아쉬운/Adjective',
#   '점/Noun',
#   ')/Punctuation',
#   '향/Noun',
#   '이/Josa',
#   '아쉽습니다/Adjective',
#   'ㅜㅜ/KoreanParticle'],
#  ['일단/Noun',
#   '향/Noun',
#   '이/Josa',
#   '너무/Adverb',
#   '은은하고/Adjective',
#   '좋아서/Adjective',
#   '첫/Noun',
#   '느낌/Noun',
#   '부터/Josa',
#   '합격/Noun',
#   '!!!/Punctuation',
#   '크림/Noun',
#   '스킨/Noun',
#   '특유/Noun',
#   '의/Josa',
#   '묽고/Adjective',
#   '텁텁/Noun',
#   '한/Josa',
#   '느낌/Noun',
#   '보다/Josa',
#   '산뜻한/Adjective',
#   '마무리/Noun',
#   '감/Noun',
#   '과/Josa',
#   '여러/Modifier',
#   '번/Noun',
#   '템팅/Noun',
#   '할수록/Verb',
#   '쫀쫀/Noun',
#   '한/Josa',
#   '피부/Noun',
#   '결/Noun',
#   '이/Josa',
#   '느껴지고/Verb',
#   ',/Punctuation',
#   '보습/Noun',
#   '감/Noun',
#   '상승/Noun',
#   '만렙/Noun',
#   './Punctuation',
#   '여름/Noun',
#   '에/Josa',
#   '기초/Noun',
#   '많이/Adverb',
#   '바르지/Verb',
#   '않기/Verb',
#   '때문/Noun',
#   '에/Josa',
#   '크림/Noun',
#   '토너/Noun',
#   '하나/Noun',
#   '레이어/Noun',
#   '링/Noun',
#   '하고/Verb',
#   '젤/Noun',
#   '로션/Noun',
#   '같은거/Adjective',
#   '마무리/Noun',
#   '하면/Verb',
#   '여름/Noun',
#   '기초/Noun',
#   '는/Josa',
#   '이/Determiner',
#   '걸/Noun',
#   '로/Josa',
#   '충분/Noun',
#   '!!!/Punctuation'],
#  ['하얀색/Noun',
#   '토너/Noun',
#   '에요/Josa',
#   '액체/Noun',
#   '보다는/Josa',
#   '점성/Noun',
#   '이/Josa',
#   '있지만/Adjective',
#   '에센스/Noun',
#   '보다는/Josa',
#   '확실히/Adjective',
#   '묽은/Adjective',
#   '제품/Noun',
#   '이에요/Josa',
#   '가볍게/Adjective',
#   '여름/Noun',
#   '에/Josa',
#   '사용/Noun',
#   '하기/Verb',
#   '좋아요/Adjective',
#   './Punctuation',
#   '토너/Noun',
#   '랑/Josa',
#   '에센스/Noun',
#   '를/Josa',
#   '한번/Noun',
#   '에/Josa',
#   '쓰는/Verb',
#   '느낌/Noun',
#   '이고/Josa',
#   '가볍게/Adjective',
#   '여러/Modifier',
#   '번/Noun',
#   '발라/Noun',
#   '도/Josa',
#   '괜찮네요/Adjective',
#   './Punctuation',
#   '지성/Noun',
#   '분들/Suffix',
#   '에게/Josa',
#   '추천/Noun',
#   '하고/Josa',
#   '저/Noun',
#   '는/Josa',
#   '이/Determiner',
#   '거/Noun',
#   '바르고/Verb',
#   '세/Modifier',
#   '럼/Noun',
#   '바르고/Verb',
#   '크림/Noun',
#   '도/Josa',
#   '바릅니다/Verb',
#   '일단/Noun',
#   '세안/Noun',
#   '후/Noun',
#   '톤/Noun',
#   '정리/Noun',
#   '하기에는/Verb',
#   '좋아요/Adjective'],
#  ['로션/Noun',
#   '도/Josa',
#   '토너/Noun',
#   '도/Josa',
#   '아닌/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '이라/Josa',
#   '반신반의/Noun',
#   '했는데/Verb',
#   '좋아요/Adjective',
#   '향기도/Noun',
#   '은은하고/Adjective',
#   '토너/Noun',
#   '치고는/Josa',
#   '촉촉하면서/Adjective',
#   '로션/Noun',
#   '보단/Josa',
#   '가벼워서/Adjective',
#   '여름/Noun',
#   '용/Noun',
#   '으로/Josa',
#   '잘/Verb',
#   '씁니다/Verb'],
#  ['점성/Noun',
#   '있는/Adjective',
#   '토너/Noun',
#   '라서/Josa',
#   '기/Modifier',
#   '초단/Noun',
#   '계/Suffix',
#   '의/Josa',
#   '첫/Modifier',
#   '단계/Noun',
#   '로/Josa',
#   '보습/Noun',
#   '감/Noun',
#   '을/Josa',
#   '어느/Modifier',
#   '정도/Noun',
#   '채워줄수/Verb',
#   '있어서/Adjective',
#   '좋더라고요/Adjective',
#   '!/Punctuation',
#   '그/Noun',
#   '다음/Noun',
#   '로션/Noun',
#   '을/Josa',
#   '바르면/Verb',
#   '더욱더/Noun',
#   '촉촉함이/Adjective',
#   '남아/Noun',
#   '있어서/Adjective',
#   '건성/Noun',
#   '피부/Noun',
#   '에/Josa',
#   '아주/Noun',
#   '딱/Adverb',
#   '잘/Verb',
#   '맞을것/Verb',
#   '같아요/Adjective',
#   '!!/Punctuation',
#   '자극/Noun',
#   '적/Suffix',
#   '인/Josa',
#   '향/Noun',
#   '도/Josa',
#   '없고/Adjective',
#   '!/Punctuation',
#   '사용/Noun',
#   '하면서/Verb',
#   '트러블/Noun',
#   '도/Josa',
#   '안/Noun',
#   '올라오고/Verb',
#   '!/Punctuation'],
#  ['랩/Noun',
#   '클/Verb',
#   '제품/Noun',
#   '은/Josa',
#   '펩타이드/Noun',
#   '수분크림/Noun',
#   '을/Josa',
#   '한/Verb',
#   '번/Noun',
#   '사용/Noun',
#   '한/Josa',
#   '적/Noun',
#   '이/Josa',
#   '있어서/Adjective',
#   '이미/Adverb',
#   '잘/Verb',
#   '알/Noun',
#   '고/Josa',
#   '있는/Adjective',
#   '제품/Noun',
#   '이/Josa',
#   '랍니/Noun',
#   '다/Josa',
#   '~/Punctuation',
#   '독일/Noun',
#   '더마/Adjective',
#   '테스트/Noun',
#   'excellent/Alpha',
#   '인증/Noun',
#   '~/Punctuation',
#   '단백질/Noun',
#   '단위체/Noun',
#   '인/Josa',
#   '아미노산/Noun',
#   '여러/Modifier',
#   '개/Noun',
#   '로/Josa',
#   '구성/Noun',
#   '된/Verb',
#   '물질/Noun',
#   '이네/Josa',
#   '요/Noun',
#   '~/Punctuation',
#   '콜라겐/Noun',
#   ',/Punctuation',
#   '엘라스/Noun',
#   '틴/Noun',
#   '생/Noun',
#   '성/Suffix',
#   '을/Josa',
#   '위해/Noun',
#   '필요/Noun',
#   '!/Punctuation',
#   '필요/Noun',
#   '!/Punctuation',
#   '\u200b/Foreign',
#   '전/Modifier',
#   '성분/Noun',
#   '부터/Josa',
#   '확인/Noun',
#   '합니다/Verb',
#   '~/Punctuation',
#   '현대/Noun',
#   '약품/Noun',
#   '독자/Noun',
#   '조성/Noun',
#   '으로/Josa',
#   '헥사/Noun',
#   '펩타이드/Noun',
#   ',/Punctuation',
#   '아세/Verb',
#   '틸헥/Noun',
#   '사/Modifier',
#   '펩타이드/Noun',
#   '등/Noun',
#   '펩타이드/Noun',
#   '5/Number',
#   '종이/Noun',
#   '함유/Noun',
#   '되어/Verb',
#   '있어/Adjective',
#   '토너/Noun',
#   '하나/Noun',
#   '만으로/Josa',
#   '쫀쫀/Noun',
#   '하고/Josa',
#   '탄탄하게/Adjective',
#   '~/Punctuation',
#   '미백/Noun',
#   ',/Punctuation',
#   '주름/Noun',
#   '개선/Noun',
#   ',/Punctuation',
#   '탄력/Noun',
#   '을/Josa',
#   '케어/Noun',
#   '해주네요/Verb',
#   '~/Punctuation',
#   '레몬/Noun',
#   ',/Punctuation',
#   '오렌지/Noun',
#   '껍질/Noun',
#   '추출/Noun',
#   '물/Noun',
#   '을/Josa',
#   '발효/Noun',
#   '한/Josa',
#   '업/Noun',
#   '사이클링/Noun',
#   '원료/Noun',
#   '뿐/Noun',
#   '만/Josa',
#   '아니라/Adjective',
#   '35/Number',
#   '종/Noun',
#   '걱정/Noun',
#   '성분/Noun',
#   '무/Noun',
#   '첨가/Noun',
#   '스킨/Noun',
#   '케어/Noun',
#   '첫/Noun',
#   '단계/Noun',
#   '부터/Josa',
#   '꼼꼼하게/Adjective',
#   '신경/Noun',
#   '써주네요/Verb',
#   '~/Punctuation',
#   '일반/Noun',
#   '토너/Noun',
#   '처럼/Josa',
#   '투명하지/Adjective',
#   '않고/Verb',
#   '밀키/Noun',
#   '한/Josa',
#   '느낌/Noun',
#   '~/Punctuation',
#   '크림/Noun',
#   '의/Josa',
#   '보습/Noun',
#   '감/Noun',
#   '이/Josa',
#   '눈/Noun',
#   '으로도/Josa',
#   '느껴지는/Verb',
#   '~/Punctuation',
#   '끈/Noun',
#   '적/Suffix',
#   '이지/Josa',
#   '않지만/Verb',
#   '그렇다고/Conjunction',
#   '물/Noun',
#   '처럼/Josa',
#   '묽지/Adjective',
#   '않는/Verb',
#   '제/Modifier',
#   '형/Noun',
#   '~/Punctuation',
#   '흡/Exclamation',
#   '토로/Noun',
#   '톡톡/Noun',
#   '톡/Noun',
#   '두드리면서/Verb',
#   '사용/Noun',
#   '하면/Verb',
#   '좋을/Adjective',
#   '듯/Noun',
#   '하네요/Verb',
#   '~/Punctuation',
#   '속/Noun',
#   '부터/Josa',
#   '채워지는/Verb',
#   '수분/Noun',
#   '으로/Josa',
#   '반/Modifier',
#   '딱/Modifier',
#   '반/Modifier',
#   '딱/Modifier',
#   '투명하게/Adjective',
#   '광/Noun',
#   '이/Josa',
#   '~~/Punctuation',
#   '그리/Verb',
#   '무겁지/Adjective',
#   '않은/Verb',
#   '토너/Noun',
#   '라/Josa',
#   '레이어/Noun',
#   '링/Noun',
#   '하/Suffix',
#   '면/Josa',
#   '당김이나/Verb',
#   '속/Modifier',
#   '보습/Noun',
#   ',/Punctuation',
#   '광채/Noun',
#   '가/Josa',
#   '개선/Noun',
#   '될/Verb',
#   '수/Noun',
#   '있을/Adjective',
#   '것/Noun',
#   '같아요/Adjective',
#   '~/Punctuation'],
#  ['세상/Noun',
#   '에/Josa',
#   '무슨/Modifier',
#   '일이/Noun',
#   '야/Josa',
#   '성분/Noun',
#   '진짜/Noun',
#   '착해/Adjective',
#   '!!/Punctuation',
#   '사랑/Noun',
#   '해요/Verb',
#   '랩/Noun',
#   '클/Verb',
#   '저/Noun',
#   '는/Josa',
#   '이/Determiner',
#   '거/Noun',
#   '아껴/Verb',
#   '뒀다가/Verb',
#   '가을/Noun',
#   '겨울/Noun',
#   '에/Josa',
#   '쓸게/Verb',
#   '오/Noun',
#   '../Punctuation',
#   '흔들어서/Verb',
#   '사용/Noun',
#   '하시구/Verb',
#   '닦/Verb',
#   '토/Noun',
#   '말고/Josa',
#   '흡/Exclamation',
#   '토로/Noun',
#   '!/Punctuation',
#   '속/Modifier',
#   '건조/Noun',
#   '를/Josa',
#   '잡으세요/Verb',
#   '!/Punctuation',
#   '향/Noun',
#   '이/Josa',
#   '쫌/Noun',
#   '호불호/Noun',
#   '가/Josa',
#   '갈릴/Noun',
#   '수/Noun',
#   '있으나/Adjective',
#   '내/Noun',
#   '피부/Noun',
#   '가/Josa',
#   '좋아하면/Adjective',
#   '상관없다/Adjective',
#   '!/Punctuation'],
#  ['랩/Noun',
#   '클/Verb',
#   '제품/Noun',
#   '은/Josa',
#   '클렌징/Noun',
#   '제품/Noun',
#   '부터/Josa',
#   '저/Determiner',
#   '자극/Noun',
#   '이라/Josa',
#   '좋아했는데/Adjective',
#   '토너/Noun',
#   '도/Josa',
#   '완전/Noun',
#   '좋아서/Adjective',
#   '쓰면서/Verb',
#   '놀랬어요/Adjective',
#   '…/Punctuation',
#   '🥹/Foreign',
#   '일단/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '자체/Noun',
#   '도/Josa',
#   '피부/Noun',
#   '속/Modifier',
#   '건조/Noun',
#   '완전/Noun',
#   '심한/Adjective',
#   '악/Noun',
#   '건성/Noun',
#   '의/Josa',
#   '피부/Noun',
#   '결/Noun',
#   '을/Josa',
#   '정돈/Noun',
#   '해주고/Verb',
#   ',/Punctuation',
#   '보습/Noun',
#   '감도/Verb',
#   '줄/Noun',
#   '만큼/Noun',
#   '촉촉/Noun',
#   '한/Determiner',
#   '데/Noun',
#   '다/Josa',
#   '부드럽/Adjective',
#   '게/Noun',
#   '까지/Josa',
#   '해서/Verb',
#   '자극/Noun',
#   '없이/Adverb',
#   '잘/Verb',
#   '사용/Noun',
#   '중/Suffix',
#   '이에요/Josa',
#   ':)/Punctuation',
#   '그리고/Conjunction',
#   '워낙/Noun',
#   '수분/Noun',
#   '감/Noun',
#   '이/Josa',
#   '많고/Adjective',
#   '이름/Noun',
#   '처럼/Josa',
#   '크림/Noun',
#   '스킨/Noun',
#   '이어서/Josa',
#   '소량/Noun',
#   '으로도/Josa',
#   '얼굴/Noun',
#   '전체/Noun',
#   '를/Josa',
#   '커버/Noun',
#   '할/Verb',
#   '수/Noun',
#   '있어용/Adjective',
#   '건조함이/Adjective',
#   '심할/Adjective',
#   '땐/Noun',
#   '레이어/Noun',
#   '링/Noun',
#   '해서/Verb',
#   '두/Determiner',
#   '번/Noun',
#   '세번/Noun',
#   '발라/Noun',
#   '도/Josa',
#   '때/Noun',
#   '처럼/Josa',
#   '밀리거나/Verb',
#   '뭉침이/Verb',
#   '없이/Adverb',
#   '말끔/Adverb',
#   '하게/Verb',
#   '흡수/Noun',
#   '되어서/Verb',
#   '앰플/Noun',
#   '바른/Verb',
#   '듯/Noun',
#   '촉촉하기까지/Adjective',
#   '해/Noun',
#   '요/Josa',
#   '👍/Foreign',
#   '한/Determiner',
#   '통/Noun',
#   '사면/Noun',
#   '한참/Noun',
#   '쓸/Verb',
#   '수/Noun',
#   '있을/Adjective',
#   '것/Noun',
#   '같아/Adjective',
#   '더/Noun',
#   '만족/Noun',
#   '이에요/Josa',
#   '🙏/Foreign'],
#  ['촉촉하고/Adjective',
#   '예민한/Adjective',
#   '피부/Noun',
#   '인/Josa',
#   '저/Noun',
#   '한테/Josa',
#   '딱인/Adjective',
#   '크림/Noun',
#   '토너/Noun',
#   '에요/Josa',
#   '~!/Punctuation',
#   '작년/Noun',
#   '겨울/Noun',
#   '부터/Josa',
#   '현재/Noun',
#   '까지/Josa',
#   '쓰고있는데/Verb',
#   '촉촉해서/Adjective',
#   '좋아요/Adjective'],
#  ['샘플/Noun',
#   '로/Josa',
#   '받아서/Verb',
#   '사용/Noun',
#   '해봤는데/Verb',
#   '민감/Noun',
#   '성/Modifier',
#   '피부/Noun',
#   '라/Josa',
#   '먼저/Noun',
#   '피부/Noun',
#   '에/Josa',
#   '테스트/Noun',
#   '후/Noun',
#   '괜찮아서/Adjective',
#   '얼굴/Noun',
#   '에/Josa',
#   '발라/Noun',
#   '봤는데/Verb',
#   '크림/Noun',
#   '스킨/Noun',
#   '이라서/Josa',
#   '촉촉하게/Adjective',
#   '잘/Verb',
#   '발려서/Verb',
#   '좋았고/Adjective',
#   ',/Punctuation',
#   '인공/Noun',
#   '적/Suffix',
#   '이지/Josa',
#   '않고/Verb',
#   ',/Punctuation',
#   '은은하게/Adjective',
#   '기분/Noun',
#   '좋은/Adjective',
#   '복숭아/Noun',
#   '향/Noun',
#   '?/Punctuation',
#   '은은하게/Adjective',
#   '나서/Verb',
#   '사용/Noun',
#   '하면서/Verb',
#   '기분/Noun',
#   '이/Josa',
#   '좋았어요/Adjective',
#   ':)/Punctuation',
#   '트러블/Noun',
#   '도/Josa',
#   '없고/Adjective',
#   ',/Punctuation',
#   '자극/Noun',
#   '없이/Adverb',
#   '순해서/Adjective',
#   '본/Modifier',
#   '품/Noun',
#   '사용/Noun',
#   '해보고/Verb',
#   '싶은데/Verb',
#   '가격/Noun',
#   '이/Josa',
#   '비싼게/Adjective',
#   '단점/Noun',
#   '이네/Josa',
#   '요/Noun',
#   'ㅠㅠ/KoreanParticle'],
#  ['민감/Noun',
#   '극/Modifier',
#   '건성/Noun',
#   '피부/Noun',
#   '라/Josa',
#   '토너/Noun',
#   '제품/Noun',
#   '보습/Noun',
#   '력/Suffix',
#   '좋은/Adjective',
#   '콧물/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '을/Josa',
#   '주로/Noun',
#   '선호/Noun',
#   '하는데/Verb',
#   '무겁거나/Adjective',
#   '답답한/Adjective',
#   '느낌/Noun',
#   '이/Josa',
#   '있어/Adjective',
#   '불편했는데/Adjective',
#   '이/Determiner',
#   '거/Noun',
#   '좋은데/Adjective',
#   '요/Noun',
#   './Punctuation',
#   '유/Noun',
#   '백색/Noun',
#   '의/Josa',
#   '점성/Noun',
#   '있는/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '인데/Josa',
#   '흡수/Noun',
#   '력/Suffix',
#   '이/Josa',
#   '정말/Noun',
#   '좋았어요/Adjective',
#   './Punctuation',
#   '끈/Noun',
#   '적임/Noun',
#   '없이/Adverb',
#   '보습/Noun',
#   '감/Noun',
#   '이/Josa',
#   '바로/Noun',
#   '채워지고/Verb',
#   '은은한/Adjective',
#   '향/Noun',
#   '도/Josa',
#   '맘/Noun',
#   '에/Josa',
#   '들었어요/Verb',
#   './Punctuation',
#   '자극/Noun',
#   '은/Josa',
#   '없고/Adjective',
#   '끈/Noun',
#   '적임/Noun',
#   '없이/Adverb',
#   '속/Modifier',
#   '수/Modifier',
#   '분과/Noun',
#   '영양/Noun',
#   '을/Josa',
#   '챙겨주는/Verb',
#   '느낌/Noun',
#   '이/Josa',
#   '더나구요/Adjective',
#   './Punctuation',
#   '레이어/Noun',
#   '링/Noun',
#   '하/Suffix',
#   '니/Josa',
#   '더/Noun',
#   '보습/Noun',
#   '지속/Noun',
#   '력/Suffix',
#   '도/Josa',
#   '업/Noun',
#   '되었어요/Verb',
#   './Punctuation',
#   '미백/Noun',
#   ',/Punctuation',
#   '주름/Noun',
#   '개선/Noun',
#   '기능/Noun',
#   '성/Suffix',
#   '제품/Noun',
#   '이고/Josa',
#   '피부/Noun',
#   '저/Determiner',
#   '자극/Noun',
#   '테스트/Noun',
#   ',/Punctuation',
#   '독일/Noun',
#   '더마/Adjective',
#   '테스트/Noun',
#   '엑설런트/Noun',
#   '인증/Noun',
#   '까지/Josa',
#   '마친/Verb',
#   '제품/Noun',
#   '이라/Josa',
#   '건조/Noun',
#   '가/Josa',
#   '심한/Adjective',
#   '피부/Noun',
#   ',/Punctuation',
#   '민감/Noun',
#   '피부/Noun',
#   ',/Punctuation',
#   '안티/Noun',
#   '에/Josa',
#   '이징/Noun',
#   '이/Josa',
#   '필요한/Adjective',
#   '모든/Noun',
#   '분/Noun',
#   '들/Suffix',
#   '이/Josa',
#   '쓰셔도/Verb',
#   '너무/Adverb',
#   '좋겠어요/Adjective',
#   './Punctuation',
#   '제품/Noun',
#   '제공/Noun',
#   '리뷰/Noun',
#   '입니다/Adjective',
#   './Punctuation'],
#  ['촉촉한데/Adjective',
#   '기름기/Noun',
#   '없이/Adverb',
#   '수분/Noun',
#   '감/Noun',
#   '이/Josa',
#   '느껴져서/Verb',
#   '엄청/Adverb',
#   '만족하면서/Adjective',
#   '쓰고있어요/Verb',
#   '!/Punctuation',
#   '화장/Noun',
#   '하기/Verb',
#   '전/Noun',
#   '에/Josa',
#   '쓰기/Noun',
#   '딱입니당/Adjective'],
#  ['물/Noun',
#   '타입/Noun',
#   '이/Josa',
#   '아니길래/Adjective',
#   '여름/Noun',
#   '엔/Josa',
#   '별로/Noun',
#   '일것/Verb',
#   '같았는데/Adjective',
#   '왠/Modifier',
#   '걸/Noun',
#   '촉촉하고/Adjective',
#   '기름/Noun',
#   '지지/Noun',
#   '않고/Verb',
#   '수분/Noun',
#   '충전/Noun',
#   '에/Josa',
#   '좋은/Adjective',
#   '느낌/Noun',
#   '!/Punctuation',
#   '끈/Noun',
#   '적임/Noun',
#   '도/Josa',
#   '없었습니다/Adjective',
#   './Punctuation',
#   '이/Noun',
#   '브랜드/Noun',
#   '는/Josa',
#   '처음/Noun',
#   '써/Verb',
#   '보는데/Verb',
#   '넘/Verb',
#   '만족스럽네요/Adjective',
#   '!!/Punctuation'],
#  ['어느/Modifier',
#   '정도/Noun',
#   '가격/Noun',
#   '대가/Noun',
#   '있는/Adjective',
#   '제품/Noun',
#   '이니/Josa',
#   '만큼/Noun',
#   '기대하고/Adjective',
#   '사용/Noun',
#   '해봤는데요/Verb',
#   '!!/Punctuation',
#   '확실히/Adjective',
#   '사용/Noun',
#   '하고/Josa',
#   '나니/Noun',
#   '피부/Noun',
#   '가/Josa',
#   '촉촉해진/Adjective',
#   '느낌/Noun',
#   '이/Josa',
#   '들어요/Verb',
#   '!!/Punctuation',
#   '흡수/Noun',
#   '력/Suffix',
#   '도/Josa',
#   '나쁘지/Adjective',
#   '않고/Verb',
#   '잘/Verb',
#   '사용/Noun',
#   '할/Verb',
#   '것/Noun',
#   '같습니다/Adjective',
#   '~/Punctuation',
#   '향/Noun',
#   '도/Josa',
#   '나쁘지/Adjective',
#   '않아요/Verb',
#   './Punctuation'],
#  ['글/Noun',
#   '로우/Noun',
#   '픽/Noun',
#   '이벤트/Noun',
#   '로/Josa',
#   '받아서/Verb',
#   '샘플/Noun',
#   '을/Josa',
#   '써/Verb',
#   '봤는데/Verb',
#   '이/Determiner',
#   '거/Noun',
#   '너무/Adverb',
#   '좋은데/Adjective',
#   '요/Noun',
#   './Punctuation',
#   '😃/Foreign',
#   '!?/Punctuation',
#   '이/Noun',
#   '세상/Noun',
#   '에/Josa',
#   '있는/Adjective',
#   '토너/Noun',
#   '진짜/Noun',
#   '많이/Adverb',
#   '써/Verb',
#   '봤는데/Verb',
#   './Punctuation',
#   '🌸/Foreign',
#   '저/Noun',
#   '는/Josa',
#   '수분/Noun',
#   '이/Josa',
#   '부족한/Adjective',
#   '지/Modifier',
#   '성/Modifier',
#   '피부/Noun',
#   '인데/Josa',
#   '도/Noun',
#   '깔끔하고/Adjective',
#   '수분/Noun',
#   '을/Josa',
#   '채워/Verb',
#   '주는/Verb',
#   '느낌/Noun',
#   '을/Josa',
#   '많이/Adverb',
#   '받았어요/Verb',
#   './Punctuation',
#   '제품/Noun',
#   '자체/Noun',
#   '가/Josa',
#   '일단/Noun',
#   '약간/Noun',
#   '흐르는/Verb',
#   '제/Modifier',
#   '형/Noun',
#   '인데/Josa',
#   '향기도/Noun',
#   '약간/Noun',
#   '상큼/Noun',
#   '한/Josa',
#   '과일/Noun',
#   '이/Josa',
#   '생각나서/Verb',
#   '되게/Adverb',
#   '향/Noun',
#   '이/Josa',
#   '좋았다고/Adjective',
#   '생각/Noun',
#   '을/Josa',
#   '했네요/Verb',
#   '!/Punctuation',
#   '그리고/Conjunction',
#   '발림/Noun',
#   '성도/Noun',
#   '굉장히/Adjective',
#   '부드럽고/Adjective',
#   '좋은데/Adjective',
#   '흡수/Noun',
#   '력/Suffix',
#   '이/Josa',
#   '진짜/Noun',
#   '좋아요/Adjective',
#   './Punctuation',
#   '시중/Noun',
#   '에/Josa',
#   '판매/Noun',
#   '하는/Verb',
#   '토너/Noun',
#   '를/Josa',
#   '진짜/Noun',
#   '많이/Adverb',
#   '써/Verb',
#   '봤는데/Verb',
#   '다음/Noun',
#   '에/Josa',
#   '진짜/Noun',
#   '구매/Noun',
#   '할/Verb',
#   '거/Noun',
#   '같은/Adjective',
#   '토너/Noun',
#   '예요/Josa',
#   '../Punctuation',
#   '👍🏻👍🏻/Foreign',
#   '그리고/Conjunction',
#   '좋은/Adjective',
#   '점/Noun',
#   '은/Josa',
#   '바르고/Verb',
#   '나면/Verb',
#   '피부/Noun',
#   '결/Noun',
#   '이/Josa',
#   '굉장히/Adjective',
#   '좋/Adjective',
#   '아보/Noun',
#   '이고/Josa',
#   '반짝반짝/Adverb',
#   '광/Noun',
#   '이/Josa',
#   '나요/Eomi',
#   './Punctuation',
#   '저/Noun',
#   '같은/Adjective',
#   '지/Modifier',
#   '성/Modifier',
#   '피부/Noun',
#   '들/Suffix',
#   '은/Josa',
#   '이/Determiner',
#   '거/Noun',
#   '하나/Noun',
#   '바르고/Verb',
#   '에센스/Noun',
#   '만/Josa',
#   '발라/Noun',
#   '도/Josa',
#   '스킨/Noun',
#   '케어/Noun',
#   '끝낼/Verb',
#   '수/Noun',
#   '있을/Adjective',
#   '것/Noun',
#   '같아요/Adjective',
#   './Punctuation',
#   '사실/Noun',
#   '들어/Verb',
#   '보지/Noun',
#   '못/VerbPrefix',
#   '했던/Verb',
#   '브랜드/Noun',
#   '라/Josa',
#   '기대/Noun',
#   '를/Josa',
#   '하지/Verb',
#   '않고/Verb',
#   '썼는데/Verb',
#   '정말/Noun',
#   '제/Noun',
#   '가/Josa',
#   '써/Verb',
#   '본/Verb',
#   '토너/Noun',
#   '중/Noun',
#   '에/Josa',
#   '베스트/Noun',
#   '5/Number',
#   '안/Noun',
#   '에/Josa',
#   '드는것/Verb',
#   '같아요/Adjective',
#   './Punctuation',
#   '😊/Foreign',
#   '그리고/Conjunction',
#   '판매/Noun',
#   '업자/Noun',
#   '가/Josa',
#   '현대/Noun',
#   '약품/Noun',
#   '이라는/Josa',
#   '약품/Noun',
#   '회사/Noun',
#   '더라구요/Adjective',
#   './Punctuation',
#   '그래서/Adverb',
#   '뭔가/Noun',
#   '더/Noun',
#   '잘/Verb',
#   '만든/Verb',
#   '거/Noun',
#   '같기도/Adjective',
#   '하고/Verb',
#   '정말/Noun',
#   '느낌/Noun',
#   '좋네요/Adjective',
#   './Punctuation',
#   '다음/Noun',
#   '엔/Josa',
#   '본/Modifier',
#   '품/Noun',
#   '으로/Josa',
#   '구매/Noun',
#   '할게요/Verb',
#   './Punctuation',
#   '!/Punctuation'],
#  ['크림/Noun',
#   '스킨/Noun',
#   '같은/Adjective',
#   '타입/Noun',
#   '이고/Josa',
#   '촉촉하고/Adjective',
#   '발림/Noun',
#   '성/Suffix',
#   '이/Josa',
#   '좋아요/Adjective',
#   '흡수/Noun',
#   '가/Josa',
#   '잘/VerbPrefix',
#   '되고/Verb',
#   '가볍지/Adjective',
#   '않게/Verb',
#   '사용/Noun',
#   '하기/Verb',
#   '좋았어요/Adjective'],
#  ['크림/Noun',
#   '처럼/Josa',
#   '촉촉한/Adjective',
#   '토너/Noun',
#   '네/Suffix',
#   '요/Josa',
#   '~/Punctuation',
#   '밀크/Noun',
#   '색/Noun',
#   '이라/Josa',
#   '향/Noun',
#   '은/Josa',
#   '어떨까/Adjective',
#   '궁금했는데/Adjective',
#   '복숭아/Noun',
#   '처럼/Josa',
#   '달콤한/Adjective',
#   '향/Noun',
#   '이나/Noun',
#   '네/Suffix',
#   '요/Josa',
#   'ㅎㅎ/KoreanParticle'],
#  ['지렸어요/Verb',
#   'ㅋㅋㅋ/KoreanParticle',
#   '부들부들/Noun',
#   '그냥/Noun',
#   '로션/Noun',
#   '바르는/Verb',
#   '느낌/Noun',
#   '이에요/Josa',
#   'ㅋ/KoreanParticle',
#   '그런데/Conjunction',
#   '뭔가/Noun',
#   '효과/Noun',
#   '있/Adjective',
#   '누/Noun',
#   '하는데/Verb',
#   '있어요/Adjective',
#   'ㅌㅌ/KoreanParticle',
#   '흠/Noun',
#   '…/Punctuation',
#   '추천/Noun',
#   '은/Josa',
#   '반/Modifier',
#   '반입/Noun',
#   '니/Josa',
#   '다용/Noun'],
#  ['펩타이드/Noun',
#   '단어/Noun',
#   '만/Josa',
#   '들어도/Verb',
#   '피부/Noun',
#   '가/Josa',
#   '건강할것/Adjective',
#   '같아요/Adjective',
#   '노화/Noun',
#   '방지/Noun',
#   '로/Josa',
#   '추천/Noun',
#   '드려요/Verb',
#   '화장품/Noun',
#   '도/Josa',
#   '똑똑하게/Adjective',
#   '사용/Noun',
#   '하자구요/Verb'],
#  ['너무/Adverb',
#   '흘러내리지/Verb',
#   '않고/Verb',
#   '제/Modifier',
#   '형/Noun',
#   '이/Josa',
#   '너무/Adverb',
#   '만족스러웠고/Adjective',
#   '보습/Noun',
#   '력/Suffix',
#   '이/Josa',
#   '굉장히/Adjective',
#   '좋더라구요/Adjective',
#   '!!!/Punctuation'],
#  ['지금/Noun',
#   '쓰고있는/Verb',
#   '요/Noun',
#   '제품/Noun',
#   '!!!/Punctuation',
#   '기초/Noun',
#   '첫/Modifier',
#   '단계/Noun',
#   '로/Josa',
#   '쓰는데/Verb',
#   '에센스/Noun',
#   '에/Josa',
#   '가까운/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '이에요/Josa',
#   '완전/Noun',
#   '촉촉/Noun',
#   '그/Noun',
#   '자체/Noun',
#   '입니다/Adjective',
#   '!!/Punctuation',
#   '완전/Noun',
#   '애정/Noun',
#   '템/Noun',
#   '이에요/Josa',
#   '♡/Foreign'],
#  ['모든/Noun',
#   '때/Noun',
#   '에/Josa',
#   '사용/Noun',
#   '하는/Verb',
#   '제품/Noun',
#   '입니다/Adjective',
#   './Punctuation',
#   '스킨/Noun',
#   '이지만/Josa',
#   '물/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '아니고/Adjective',
#   '약간/Noun',
#   '점성/Noun',
#   '이/Josa',
#   '있어요/Adjective',
#   './Punctuation',
#   '건조한/Adjective',
#   '계절/Noun',
#   '이/Josa',
#   '되면/Verb',
#   '손바닥/Noun',
#   '에/Josa',
#   '덜어/Verb',
#   '두/Determiner',
#   '세번/Noun',
#   '레이어/Noun',
#   '링/Noun',
#   '하/Exclamation',
#   '듯이/Noun',
#   '발라/Noun',
#   '줍니다/Verb',
#   './Punctuation',
#   '그러면/Adverb',
#   '촉촉한/Adjective',
#   '느낌/Noun',
#   '이/Josa',
#   '들어요/Verb',
#   './Punctuation',
#   '물/Noun',
#   '처럼/Josa',
#   '흐르지는/Verb',
#   '않아서/Verb',
#   '뚜껑/Noun',
#   '을/Josa',
#   '열고/Verb',
#   '탈탈/Adverb',
#   '털듯이/Verb',
#   '토너/Noun',
#   '를/Josa',
#   '손바닥/Noun',
#   '데/Noun',
#   '덜어/Verb',
#   '사용/Noun',
#   '하는데/Verb',
#   '향기/Noun',
#   '는/Josa',
#   '거의/Noun',
#   '없다시피/Adjective',
#   '합니다/Verb',
#   './Punctuation'],
#  ['랩/Noun',
#   '클/Verb',
#   '펩타이드/Noun',
#   '크림/Noun',
#   '스킨/Noun',
#   '모/Modifier',
#   '이스/Noun',
#   '처/Noun',
#   '라/Josa',
#   '이징/Noun',
#   '토너/Noun',
#   '랩/Noun',
#   '클을/Verb',
#   '잘/Verb',
#   '몰랐었는데/Verb',
#   '예전/Noun',
#   '에/Josa',
#   '운/Noun',
#   '좋게/Adjective',
#   '당첨/Noun',
#   '이/Josa',
#   '되서/Verb',
#   '쓰기/Noun',
#   '시작/Noun',
#   '했는데/Verb',
#   '그/Noun',
#   '후/Noun',
#   '로/Josa',
#   '랩/Noun',
#   '클에서/Verb',
#   '신상/Noun',
#   '나오면/Verb',
#   '관심/Noun',
#   '이/Josa',
#   '가더라구요/Verb',
#   '쓰고/Verb',
#   '만족하지/Adjective',
#   '않았다면/Verb',
#   '관심/Noun',
#   '이/Josa',
#   '없겠죠/Adjective',
#   '?/Punctuation',
#   '하지만/Conjunction',
#   '저/Noun',
#   '는/Josa',
#   '만족했었기에/Adjective',
#   '계속/Noun',
#   '관심/Noun',
#   '가지/Noun',
#   '고/Josa',
#   '있구요/Adjective',
#   '토너/Noun',
#   '는/Josa',
#   '수분/Noun',
#   '을/Josa',
#   '채우기/Verb',
#   '위해/Noun',
#   '서/Josa',
#   '쓰는거/Verb',
#   '자나요/Verb',
#   '항상/Noun',
#   '아쉬웠던게/Adjective',
#   '토너/Noun',
#   '는/Josa',
#   '왜/Noun',
#   '수분/Noun',
#   '만/Josa',
#   '가능할까/Adjective',
#   '유수/Noun',
#   '분/Suffix',
#   '밸런스/Noun',
#   '를/Josa',
#   '이/Noun',
#   '한가지/Noun',
#   '로만/Noun',
#   '가능하면/Adjective',
#   '좋지/Adjective',
#   '않을까/Verb',
#   '하는/Verb',
#   '생각/Noun',
#   '을/Josa',
#   '갖고/Verb',
#   '있었는데/Adjective',
#   '오/Noun',
#   '이/Determiner',
#   '녀석/Noun',
#   '거의/Noun',
#   '왔어요/Verb',
#   '수분/Noun',
#   '만/Josa',
#   '채워주는게/Verb',
#   '아니고/Adjective',
#   '유/Noun',
#   '분/Suffix',
#   '도/Josa',
#   '살짝/Noun',
#   '느껴져요/Verb',
#   '정착/Noun',
#   '해볼/Verb',
#   '의향/Noun',
#   '있어요/Adjective'],
#  ['건성/Noun',
#   '이/Josa',
#   '쓰기/Noun',
#   '좋은/Adjective',
#   '토너/Noun',
#   '에요/Josa',
#   '토너/Noun',
#   '지만/Josa',
#   '무거운/Adjective',
#   '느낌/Noun',
#   '이고/Josa',
#   '바르면/Verb',
#   '수분/Noun',
#   '감/Noun',
#   '과/Josa',
#   '유/Noun',
#   '분/Suffix',
#   '감/Noun',
#   '을/Josa',
#   '채워주는/Verb',
#   '느낌이였어요/Verb',
#   '여름/Noun',
#   '이라서/Josa',
#   '여러/Modifier',
#   '개/Noun',
#   '바르지/Verb',
#   '않고/Verb',
#   '이/Determiner',
#   '거/Noun',
#   '하나로/Noun',
#   '토너/Noun',
#   '와/Josa',
#   '앰플/Noun',
#   '단계/Noun',
#   '를/Josa',
#   '한/Verb',
#   '번/Noun',
#   '에/Josa',
#   '할/Verb',
#   '수/Noun',
#   '있는/Adjective',
#   '제품/Noun',
#   '이에요/Josa'],
#  ['예전/Noun',
#   '에/Josa',
#   '샘플/Noun',
#   '을/Josa',
#   '써/Verb',
#   '봐서/Verb',
#   '너무/Adverb',
#   '좋아서/Adjective',
#   '본/Modifier',
#   '품/Noun',
#   '을/Josa',
#   '샀어요/Verb',
#   '~/Punctuation',
#   '촉/Noun',
#   '촉감/Noun',
#   '은/Josa',
#   '좋아요/Adjective'],
#  ['제/Modifier',
#   '형/Noun',
#   '은/Josa',
#   '토니모리/Noun',
#   '모찌/Noun',
#   '토너/Noun',
#   ',/Punctuation',
#   '일리/Noun',
#   '윤/Noun',
#   '프로바이오틱스/Noun',
#   '에센스/Noun',
#   '드롭/Noun',
#   '이랑/Josa',
#   '비슷합니당/Adjective',
#   '모찌/Noun',
#   '토너/Noun',
#   '가/Josa',
#   '좀더/Noun',
#   '콧물제형/Noun',
#   '이고/Josa',
#   '조금/Noun',
#   '흡수/Noun',
#   '가/Josa',
#   '느려요/Adjective',
#   '일리/Noun',
#   '윤/Noun',
#   '꺼/Suffix',
#   '랑은/Josa',
#   '제/Modifier',
#   '형도/Noun',
#   '그렇고/Adjective',
#   '마무리/Noun',
#   '감/Noun',
#   '이/Josa',
#   '끈/Noun',
#   '적/Suffix',
#   '이지/Josa',
#   '않는다는/Verb',
#   '점/Noun',
#   '에서/Josa',
#   '비슷해요/Adjective',
#   '크림/Noun',
#   '스킨/Noun',
#   '이라고/Josa',
#   '해서/Verb',
#   '라네즈/Noun',
#   '크림/Noun',
#   '스킨/Noun',
#   '떠올리면/Verb',
#   '제/Modifier',
#   '형/Noun',
#   '부터/Josa',
#   '완전히/Adjective',
#   '달라용/Adjective',
#   '사/Modifier',
#   '용감/Noun',
#   '에/Josa',
#   '있어서는/Adjective',
#   '확실히/Adjective',
#   '흡수/Noun',
#   '가/Josa',
#   '빠르다/Adjective',
#   '보니/Verb',
#   '랩/Noun',
#   '클/Verb',
#   '토너/Noun',
#   '가/Josa',
#   '쓰기/Noun',
#   '편하고/Adjective',
#   '흡수/Noun',
#   '되었을/Verb',
#   '때/Noun',
#   '끈/Noun',
#   '적임/Noun',
#   '없이/Adverb',
#   '약간/Noun',
#   '매끈한/Adjective',
#   '느낌/Noun',
#   '으로/Josa',
#   '마무리/Noun',
#   '됩니당/Verb',
#   '요약/Noun',
#   '1/Number',
#   './Punctuation',
#   '모찌/Noun',
#   '토너/Noun',
#   '//Punctuation',
#   '일리/Noun',
#   '윤/Noun',
#   '에센스/Noun',
#   '와/Josa',
#   '제/Modifier',
#   '형/Noun',
#   '90/Number',
#   '프로/Noun',
#   '정도/Noun',
#   '유사/Noun',
#   '(/Punctuation',
#   '체감/Noun',
#   ')/Punctuation',
#   '2/Number',
#   './Punctuation',
#   '흡수/Noun',
#   ':/Punctuation',
#   '모찌/Noun',
#   '토너/Noun',
#   '</Punctuation',
#   '일리/Noun',
#   '윤/Noun',
#   '<=/Punctuation',
#   '랩/Noun',
#   '클/Verb',
#   '3/Number',
#   './Punctuation',
#   '보습/Noun',
#   '감/Noun',
#   ':/Punctuation',
#   '모찌/Noun',
#   '토너/Noun',
#   '=/Punctuation',
#   '랩/Noun',
#   '클/Verb',
#   '</Punctuation',
#   '일리/Noun',
#   '윤/Noun'],
#  ['️☑️/Foreign',
#   '겨쿨/Noun',
#   '딥/Noun',
#   '-/Punctuation',
#   '다크/Noun',
#   '//Punctuation',
#   '차선/Noun',
#   '겨쿨/Noun',
#   '비비드/Noun',
#   '☑️/Foreign',
#   '피부/Noun',
#   '타입/Noun',
#   ':/Punctuation',
#   '21-22/Number',
#   '호/Noun',
#   '걸친/Verb',
#   '약/Modifier',
#   '건성/Noun',
#   '-/Punctuation',
#   '중성/Noun',
#   '☑️/Foreign',
#   '명도/Noun',
#   '많이/Adverb',
#   '타는/Verb',
#   '편/Noun',
#   '☑️/Foreign',
#   '구매/Noun',
#   '색상/Noun',
#   '//Punctuation',
#   '호수/Noun',
#   ':/Punctuation',
#   'N/Alpha',
#   '💫/Foreign',
#   '장점/Noun',
#   '-/Punctuation',
#   '우유/Noun',
#   '같은/Adjective',
#   '백색/Noun',
#   '색상/Noun',
#   '의/Josa',
#   '묽은/Adjective',
#   '토너/Noun',
#   '에요/Josa',
#   './Punctuation',
#   '가벼운/Adjective',
#   '사/Modifier',
#   '용감/Noun',
#   '입니다/Adjective',
#   './Punctuation',
#   '-/Punctuation',
#   '흡수/Noun',
#   '가/Josa',
#   '빨라/Adjective',
#   '챱토/Noun',
#   '등/Noun',
#   '기초/Noun',
#   '루틴/Noun',
#   '으로/Josa',
#   '사용/Noun',
#   '해도/Verb',
#   '될/Verb',
#   '것/Noun',
#   '같아요/Adjective',
#   './Punctuation',
#   '보습/Noun',
#   '감은/Verb',
#   '무난/Noun',
#   '합니다/Verb',
#   './Punctuation',
#   '💫/Foreign',
#   '단점/Noun',
#   '-/Punctuation',
#   '펩타이드/Noun',
#   '는/Josa',
#   '안티/Noun',
#   '에/Josa',
#   '이징/Noun',
#   '성분/Noun',
#   '인데/Josa',
#   '효과/Noun',
#   '는/Josa',
#   '잘/Verb',
#   '모르겠어요/Verb',
#   './Punctuation',
#   '아무래도/Adverb',
#   '단기간/Noun',
#   '에/Josa',
#   '효과/Noun',
#   '를/Josa',
#   '보기/Noun',
#   '어려운/Adjective',
#   '영역/Noun',
#   '이긴/Verb',
#   '해/Noun',
#   '요/Josa',
#   './Punctuation'],
#  ['랩/Noun',
#   '클/Verb',
#   '순면/Noun',
#   '패드/Noun',
#   '때문/Noun',
#   '에/Josa',
#   '이/Noun',
#   '브랜드/Noun',
#   '에/Josa',
#   '호감/Noun',
#   'max/Alpha',
#   '됐는데/Verb',
#   '토너/Noun',
#   '도/Josa',
#   '괜찮네요/Adjective',
#   '!!!/Punctuation',
#   '너무/Adverb',
#   '무겁지/Adjective',
#   '않지만/Verb',
#   '보습/Noun',
#   '은/Josa',
#   '잘/VerbPrefix',
#   '되는/Verb',
#   '고런/Modifier',
#   '제품/Noun',
#   '입니다/Adjective',
#   'ㅎㅎ/KoreanParticle',
#   '로션/Noun',
#   '같은/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '?!/Punctuation',
#   '이라/Verb',
#   '건성/Noun',
#   '이/Josa',
#   '데/Noun',
#   '일리/Noun',
#   '로/Josa',
#   '가볍게/Adjective',
#   '바르기/Verb',
#   '좋았어요/Adjective',
#   'ㅎㅎ/KoreanParticle',
#   '무난/Noun',
#   '하고/Josa',
#   '괜찮았음/Adjective',
#   'ㅎㅎ/KoreanParticle',
#   '가벼워진/Verb',
#   '크림/Noun',
#   '스킨/Noun',
#   '느낌/Noun',
#   '!!/Punctuation',
#   '민감/Noun',
#   '+/Punctuation',
#   '아토피/Noun',
#   '피부/Noun',
#   '인데/Josa',
#   '따가/Adjective',
#   '움/Noun',
#   '도/Josa',
#   '없고/Adjective',
#   '홍조/Noun',
#   ',/Punctuation',
#   '두드러기/Noun',
#   '도/Josa',
#   '올라오지/Verb',
#   '않았어요/Verb',
#   'ㅎㅎ/KoreanParticle'],
#  ['그냥/Noun',
#   '딱/Adverb',
#   '생각나는/Verb',
#   '무난/Noun',
#   '한/Josa',
#   '토너/Noun',
#   '에요/Josa',
#   '그럼에도/Adjective',
#   '수분/Noun',
#   '감/Noun',
#   '이나/Josa',
#   '민감/Noun',
#   '성은/Noun',
#   '없고/Adjective',
#   '무난/Noun',
#   '해서/Verb',
#   '딱/Adverb',
#   '쓰기/Noun',
#   '좋습니다/Adjective'],
#  ['토너/Noun',
#   '지만/Josa',
#   '크림/Noun',
#   '스킨/Noun',
#   '이라/Josa',
#   '약간/Noun',
#   '점성/Noun',
#   '이/Josa',
#   '있어서/Adjective',
#   '흘러내리지/Verb',
#   '않아서/Verb',
#   '바를/Verb',
#   '때/Noun',
#   '느긋하게/Adjective',
#   '바를/Verb',
#   '수/Noun',
#   '있어서/Adjective',
#   '편해요/Adjective',
#   '~/Punctuation',
#   '가벼운/Adjective',
#   '느낌/Noun',
#   '은/Josa',
#   '아닙니다/Adjective',
#   '!/Punctuation',
#   '말/Noun',
#   '그대로/Noun',
#   '크림/Noun',
#   '스킨/Noun',
#   '이라/Josa',
#   '토너/Noun',
#   '처럼/Josa',
#   '묽지/Adjective',
#   '않고/Verb',
#   '좀/Noun',
#   '리치/Noun',
#   '한/Josa',
#   '느낌/Noun',
#   '이/Suffix',
#   '예요/Josa',
#   '~/Punctuation',
#   '흡수/Noun',
#   '가/Josa',
#   '막/Noun',
# ...
#   '조금/Noun',
#   '있고/Adjective',
#   '너무/Adverb',
#   '가볍지도/Adjective',
#   '너무/Adverb',
#   '무거운것도/Adjective',
#   '아닌/Adjective',
#   '가장/Noun',
#   '기본/Noun',
#   '적/Suffix',
#   '인/Josa',
#   '에센스/Noun',
#   '토너/Noun',
#   '에/Josa',
#   '용/Noun',
#   '에요/Josa',
#   '가볍게/Adjective',
#   '쓰기/Noun',
#   '좋/Adjective',
#   '네/Determiner',
#   '용/Noun'],
#  ['순하고/Adjective',
#   '물/Noun',
#   '같아요/Adjective',
#   './Punctuation',
#   '화장/Noun',
#   '솜/Noun',
#   '에/Josa',
#   '넓고/Adjective',
#   '충분히/Adjective',
#   '적셔서/Verb',
#   '닥토/Noun',
#   '로/Josa',
#   '써도/Verb',
#   '좋구/Adjective',
#   '그대로/Noun',
#   '흡수/Noun',
#   '시켜도/Verb',
#   '좋아요/Adjective',
#   './Punctuation'],
#  ['딱/Adverb',
#   '전형/Noun',
#   '적/Suffix',
#   '인/Josa',
#   '기본/Noun',
#   '의/Josa',
#   '액체/Noun',
#   '형/Suffix',
#   '토너/Noun',
#   '에요/Josa',
#   '매일/Noun',
#   '아침/Noun',
#   '저녁/Noun',
#   '에/Josa',
#   '화장/Noun',
#   '솜/Noun',
#   '에/Josa',
#   '덜어/Verb',
#   '닦/Verb',
#   '토로/Noun',
#   '사용/Noun',
#   '했고/Verb',
#   '결/Noun',
#   '정리/Noun',
#   '되면서/Verb',
#   '한/Determiner',
#   '겹/Noun',
#   '의/Josa',
#   '수분/Noun',
#   '막/Noun',
#   '을/Josa',
#   '형성/Noun',
#   '해주기/Verb',
#   '좋았어요/Adjective',
#   '트러블/Noun',
#   '없이/Adverb',
#   '순한/Adjective',
#   '느낌이었고/Verb',
#   '데/Noun',
#   '일리/Noun',
#   '로/Josa',
#   '사용/Noun',
#   '하기/Verb',
#   '좋아요/Adjective'],
#  ['샘플/Noun',
#   '로/Josa',
#   '한번/Noun',
#   '써보다/Verb',
#   '괜찮은/Adjective',
#   '제품/Noun',
#   '같아서/Adjective',
#   '구매/Noun',
#   '하게/Verb',
#   '된/Verb',
#   '제품/Noun',
#   '이에요/Josa',
#   '제/Modifier',
#   '형/Noun',
#   '은/Josa',
#   '묽은/Adjective',
#   '콧물제형/Noun',
#   '?/Punctuation',
#   '그렇다고/Conjunction',
#   '피부/Noun',
#   '에/Josa',
#   '마무리/Noun',
#   '감/Noun',
#   '이/Josa',
#   '끈/Noun',
#   '적/Suffix',
#   '이지/Josa',
#   '않고/Verb',
#   '피부/Noun',
#   '에/Josa',
#   '촉촉하게/Adjective',
#   '흡수/Noun',
#   '도/Josa',
#   '잘/VerbPrefix',
#   '되에/Verb',
#   '마무리/Noun',
#   '감/Noun',
#   '이/Josa',
#   '좋았어요/Adjective',
#   '맨/Modifier',
#   '처음/Noun',
#   '에/Josa',
#   '사용/Noun',
#   '할/Verb',
#   '때/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '이/Josa',
#   '엄청/Adverb',
#   '가벼운/Adjective',
#   '느낌/Noun',
#   '이/Josa',
#   '아니라/Adjective',
#   '걱정/Noun',
#   '했었는데/Verb',
#   '피부/Noun',
#   '에/Josa',
#   '발랐을/Verb',
#   '때/Noun',
#   '엄청/Adverb',
#   '무겁게/Adjective',
#   '흡수/Noun',
#   '되지도/Verb',
#   '않고/Verb',
#   '그렇다고/Conjunction',
#   '엄청/Adverb',
#   '가볍지도/Adjective',
#   '않고/Verb',
#   '딱/Adverb',
#   '알맞았어요/Adjective',
#   '굿굿/Noun',
#   '피부/Noun',
#   '가/Josa',
#   '예민/Noun',
#   '한편/Noun',
#   '인데/Josa',
#   '전혀/Noun',
#   '자극/Noun',
#   '이/Josa',
#   '안/VerbPrefix',
#   '느껴졌어요/Verb',
#   '딱/Adverb',
#   '기초/Noun',
#   '가/Josa',
#   '잡히는/Verb',
#   '느낌/Noun',
#   '?/Punctuation',
#   '이/Determiner',
#   '랄/Noun',
#   '까/Verb',
#   '사용/Noun',
#   '후/Noun',
#   '그/Noun',
#   '느낌/Noun',
#   '이/Josa',
#   '너무/Adverb',
#   '좋았어요/Adjective'],
#  ['약간/Noun',
#   '묽은콧물/Noun',
#   '재형/Noun',
#   '이고/Josa',
#   '향/Noun',
#   '은/Josa',
#   '무향/Noun',
#   '에/Josa',
#   '가깝고/Adjective',
#   '산뜻한/Adjective',
#   '느낌/Noun',
#   '인데/Josa',
#   '딱히/Adjective',
#   '기대한/Adjective',
#   '제품/Noun',
#   '은/Josa',
#   '아니었는데/Adjective',
#   '이제/Noun',
#   '는/Josa',
#   '애/Noun',
#   '없이는/Adjective',
#   '못/VerbPrefix',
#   '사는/Verb',
#   '느낌/Noun',
#   '쓰/Verb',
#   '특히/Adverb',
#   '환절기/Noun',
#   '에/Josa',
#   '정말/Noun',
#   '매일/Noun',
#   '손/Noun',
#   '이/Josa',
#   '갔어요/Verb',
#   './Punctuation',
#   '자기전이든/Verb',
#   '화장/Noun',
#   '전이/Noun',
#   '든/Josa',
#   '발라주고/Verb',
#   '흡수/Noun',
#   '한/Josa',
#   '뒤/Noun',
#   '크림/Noun',
#   '이나/Josa',
#   '에센스/Noun',
#   '발라/Noun',
#   '도/Josa',
#   '촉촉함이/Adjective',
#   '달랐어요/Adjective',
#   './Punctuation',
#   '정말/Noun',
#   '제품/Noun',
#   '내용/Noun',
#   '그대로/Noun',
#   '비워주고/Verb',
#   '채워주기/Verb',
#   '위함/Noun',
#   '인/Josa',
#   '제품/Noun',
#   '인거/Josa',
#   '같아요/Adjective',
#   './Punctuation',
#   '모공/Noun',
#   '이/Josa',
#   '수축/Noun',
#   '하고/Josa',
#   '하는건/Verb',
#   '당연히/Adjective',
#   '아니지만/Adjective',
#   '더/Noun',
#   '늘어지지/Verb',
#   '않게/Verb',
#   '수분/Noun',
#   '보충/Noun',
#   '은/Josa',
#   '의/Noun',
#   '역할/Noun',
#   '은/Josa',
#   '확실히/Adjective',
#   '한다고/Verb',
#   '느꼈고/Verb',
#   '특히/Adverb',
#   '패키지/Noun',
#   '가/Josa',
#   '맘/Noun',
#   '에/Josa',
#   '드는/Verb',
#   '부분/Noun',
#   '이/Josa',
#   '말랑한/Adjective',
#   '실리콘/Noun',
#   '형태/Noun',
#   '로/Josa',
#   '누르기/Noun',
#   '도/Josa',
#   '편하고/Adjective',
#   '입구/Noun',
#   '가/Josa',
#   '뾰족/Adverb',
#   '한/Determiner',
#   '형태/Noun',
#   '라/Josa',
#   '얼굴/Noun',
#   '에/Josa',
#   '바로/Noun',
#   '죽/Noun',
#   '바르기에/Verb',
#   '너무/Adverb',
#   '좋았어요/Adjective',
#   './Punctuation',
#   '은근/Noun',
#   '이런/Adjective',
#   '작은/Adjective',
#   '부분/Noun',
#   '이/Josa',
#   '삶/Noun',
#   '의/Josa',
#   '질/Noun',
#   '을/Josa',
#   '좋아지게/Verb',
#   '하는거/Verb',
#   '같아요/Adjective',
#   './Punctuation',
#   '굿/Noun',
#   '솔직히/Adjective',
#   '비슷한/Adjective',
#   '재형/Noun',
#   '의/Josa',
#   '제품/Noun',
#   '들/Suffix',
#   '많이/Adverb',
#   '써/Verb',
#   '봤지만/Verb',
#   '패키지/Noun',
#   '며/Josa',
#   '끈/Noun',
#   '적함/Noun',
#   '이/Josa',
#   '없는/Adjective',
#   '산뜻한/Adjective',
#   '마무/Noun',
#   '감/Noun',
#   '이/Josa',
#   '다음/Noun',
#   '재형/Noun',
#   '을/Josa',
#   '받아들이기에/Verb',
#   '수분/Noun',
#   '감/Noun',
#   '이/Josa',
#   '탄탄하게/Adjective',
#   '다져주는/Verb',
#   '느낌/Noun',
#   '이라/Josa',
#   '추천/Noun',
#   '땅/Noun',
#   '!/Punctuation'],
#  ['보습/Noun',
#   '도/Josa',
#   '우수하고/Adjective',
#   '발림/Noun',
#   '성도/Noun',
#   '좋슴니/Noun',
#   '다/Josa',
#   '!!/Punctuation',
#   '향/Noun',
#   '도/Josa',
#   '이/Determiner',
#   '정도/Noun',
#   '면/Josa',
#   '만족/Noun',
#   '이용/Noun'],
#  ['점성/Noun',
#   '이/Josa',
#   '살짝/Noun',
#   '있는/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   './Punctuation',
#   '발릴/Verb',
#   '때/Noun',
#   '조금/Noun',
#   '미/Adjective',
#   '끄/Verb',
#   '덩/Noun',
#   '거리/Noun',
#   '는/Josa',
#   '느낌/Noun',
#   '이나/Josa',
#   '흡수/Noun',
#   '후/Noun',
#   '미/Adjective',
#   '끄/Verb',
#   '덩/Noun',
#   '거리/Noun',
#   '거나/Noun',
#   '끈/Noun',
#   '적/Suffix',
#   '이는/Verb',
#   '느낌/Noun',
#   '없음/Adjective',
#   './Punctuation',
#   '흡수/Noun',
#   '잘/Verb',
#   '되고/Verb',
#   '여러/Modifier',
#   '번/Noun',
#   '덧/Noun',
#   '발라/Noun',
#   '도/Josa',
#   '가벼운/Adjective',
#   '사/Modifier',
#   '용감/Noun',
#   '에/Josa',
#   '어느/Adverb',
#   '정도/Noun',
#   '수분/Noun',
#   '감/Noun',
#   '을/Josa',
#   '붙들어/Verb',
#   '줘서/Verb',
#   '좋음/Adjective',
#   './Punctuation',
#   '기존/Noun',
#   '에/Josa',
#   '익숙하게/Adjective',
#   '쓰던/Verb',
#   '스킨/Noun',
#   '케어/Noun',
#   '용기/Noun',
#   '와/Josa',
#   '달리/Noun',
#   '뾰족/Adverb',
#   '캡/Noun',
#   '을/Josa',
#   '사용/Noun',
#   '하는데/Verb',
#   '그/Noun',
#   '점도/Noun',
#   '좋았음/Adjective',
#   './Punctuation'],
#  ['에센스/Noun',
#   '토너/Noun',
#   '답/Noun',
#   '게/Josa',
#   '앰플/Noun',
#   '처럼/Josa',
#   '약간/Noun',
#   '콧물/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '이/Josa',
#   '아니라/Adjective',
#   '물/Noun',
#   '처럼/Josa',
#   '주르륵/Noun',
#   '흐르는/Verb',
#   '?/Punctuation',
#   '제/Modifier',
#   '형/Noun',
#   '이/Josa',
#   '더라구요/Adjective',
#   '!/Punctuation',
#   '근데/Adverb',
#   '흡수/Noun',
#   '는/Josa',
#   '더/Noun',
#   '잘/VerbPrefix',
#   '돼서/Verb',
#   '좋았어요/Adjective',
#   'ㅎㅎ/KoreanParticle',
#   '꾸준히/Adjective',
#   '사용/Noun',
#   '하면/Verb',
#   '속/Modifier',
#   '건조/Noun',
#   '도/Josa',
#   '잡힐거/Verb',
#   '같아요/Adjective',
#   '만족합니다/Adjective',
#   '!/Punctuation'],
#  ['지/Modifier',
#   '복합/Noun',
#   '성/Suffix',
#   '에/Josa',
#   '각질/Noun',
#   '많이/Adverb',
#   '올라오는/Verb',
#   '피부/Noun',
#   '타입/Noun',
#   '이에요/Josa',
#   './Punctuation',
#   '처음/Noun',
#   '에는/Josa',
#   '다/Adverb',
#   '자연/Noun',
#   '이라는/Josa',
#   '브랜드/Noun',
#   '도/Josa',
#   '잘/Verb',
#   '모르고/Verb',
#   '사용/Noun',
#   '했는데/Verb',
#   '기초/Noun',
#   '제품/Noun',
#   '이/Josa',
#   '유명한/Adjective',
#   '브랜드/Noun',
#   '더라구요/Adjective',
#   '..!!/Punctuation',
#   '화장/Noun',
#   '하기/Verb',
#   '전/Noun',
#   '에/Josa',
#   '기/Modifier',
#   '초로/Noun',
#   '도/Josa',
#   '너무/Adverb',
#   '좋고/Adjective',
#   '매트/Noun',
#   '한/Josa',
#   '파데랑/Verb',
#   '합/Noun',
#   '이/Josa',
#   '좋다/Adjective',
#   '보/Noun',
#   '니까/Josa',
#   '모공/Noun',
#   '도/Josa',
#   '더/Noun',
#   '촘촘하/Noun',
#   '게/Josa',
#   '매워져서/Adjective',
#   '화장/Noun',
#   '전/Noun',
#   '에/Josa',
#   '필수/Noun',
#   '로/Josa',
#   '사용/Noun',
#   '중/Suffix',
#   '이에요/Josa',
#   '❤️/Foreign',
#   '그리고/Conjunction',
#   '에센스/Noun',
#   '토너/Noun',
#   '다/Josa',
#   '보니/Verb',
#   '살짝/Noun',
#   '걸쭉한/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '인데/Josa',
#   '흡수/Noun',
#   '후/Noun',
#   '에는/Josa',
#   '끈/Noun',
#   '적/Suffix',
#   '이는/Verb',
#   '느낌/Noun',
#   '없이/Adverb',
#   '촉촉하게/Adjective',
#   '마무리/Noun',
#   '되어서/Verb',
#   '끈/Noun',
#   '적임/Noun',
#   '걱정/Noun',
#   '되시는/Verb',
#   '분/Noun',
#   '들/Suffix',
#   '도/Josa',
#   '걱정/Noun',
#   '없이/Adverb',
#   '잘/Verb',
#   '사용/Noun',
#   '하실/Verb',
#   '수/Noun',
#   '있을/Adjective',
#   '것/Noun',
#   '같아요/Adjective',
#   'ㅎㅎ/KoreanParticle',
#   '겨울/Noun',
#   '에도/Josa',
#   '다른/Noun',
#   '크림/Noun',
#   '안/VerbPrefix',
#   '바르고/Verb',
#   '단독/Noun',
#   '사용/Noun',
#   '했을/Verb',
#   '때/Noun',
#   '충분히/Adjective',
#   '괜찮았던/Adjective',
#   '기억/Noun',
#   '이/Josa',
#   '있어서/Adjective',
#   '여름/Noun',
#   '에/Josa',
#   '요/Modifier',
#   '거/Noun',
#   '하나/Noun',
#   '만으로도/Josa',
#   '충분히/Adjective',
#   '수분/Noun',
#   '유/Noun',
#   '분/Suffix',
#   '관리/Noun',
#   '잘/Verb',
#   '할/Verb',
#   '수/Noun',
#   '있을/Adjective',
#   '것/Noun',
#   '같아요/Adjective',
#   '❤️/Foreign',
#   '재구매/Verb',
#   '의사/Noun',
#   '충분히/Adjective',
#   '있습니다/Adjective',
#   '!/Punctuation'],
#  ['매일/Noun',
#   '사용/Noun',
#   '하기/Verb',
#   '좋은/Adjective',
#   '토너/Noun',
#   '토너/Noun',
#   '의/Josa',
#   '농도/Noun',
#   '는/Josa',
#   '에센스/Noun',
#   '와/Josa',
#   '비슷하게/Adjective',
#   '걸쭉한/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '이에요/Josa',
#   './Punctuation',
#   '이/Noun',
#   '질감/Noun',
#   '덕분/Noun',
#   '에/Josa',
#   '토너/Noun',
#   '가/Josa',
#   '피부/Noun',
#   '에/Josa',
#   '서서히/Noun',
#   '흡수/Noun',
#   '되어/Verb',
#   '촉촉해져요/Adjective',
#   '사용/Noun',
#   '후/Noun',
#   '피부/Noun',
#   '가/Josa',
#   '부드럽고/Adjective',
#   '촉촉해진/Adjective',
#   '느낌/Noun',
#   '이/Josa',
#   '들어요/Verb',
#   '피부/Noun',
#   '염증/Noun',
#   '을/Josa',
#   '퇴치/Noun',
#   '하는/Verb',
#   '데/Noun',
#   '도움/Noun',
#   '이/Josa',
#   '되는/Verb',
#   '나이아신/Noun',
#   '아마이드/Noun',
#   '가/Josa',
#   '함유/Noun',
#   '되어/Verb',
#   '있어요/Adjective',
#   '~/Punctuation'],
#  ['약간/Noun',
#   '무거운/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '같은데/Adjective',
#   '막상/Noun',
#   '쓰면/Verb',
#   '가볍고/Adjective',
#   '쓱/Noun',
#   '스며들어서/Verb',
#   '너무/Adverb',
#   '좋아요/Adjective',
#   '재구매/Verb',
#   '예정/Noun',
#   '입니다/Adjective'],
#  ['점성/Noun',
#   '있는/Adjective',
#   '토너/Noun',
#   '지만/Josa',
#   '물/Noun',
#   '토너/Noun',
#   '처럼/Josa',
#   '수분/Noun',
#   '감/Noun',
#   '이/Josa',
#   '엄청/Adverb',
#   '느껴집니다/Verb',
#   '엄청/Adverb',
#   '촉촉해요/Adjective',
#   '토너/Noun',
#   '가/Josa',
#   '스포이드/Noun',
#   '처럼/Josa',
#   '쭉/Noun',
#   '짜야/Verb',
#   '나오는/Verb',
#   '타입/Noun',
#   '이라/Josa',
#   '위생/Noun',
#   '적/Suffix',
#   '이라고/Josa',
#   '느껴지고/Verb',
#   '수분/Noun',
#   '백프로/Noun',
#   '스킨/Noun',
#   '으로/Josa',
#   '딱/Adverb',
#   '좋고/Adjective',
#   '트러블/Noun',
#   ',/Punctuation',
#   '자극/Noun',
#   '못/Noun',
#   '느꼈습니다/Verb',
#   '여름/Noun',
#   '에/Josa',
#   '더/Noun',
#   '잘/Verb',
#   '쓸/Verb',
#   '거/Noun',
#   '같아요/Adjective',
#   '무난/Noun',
#   '무난/Noun',
#   '해/Noun',
#   '요/Josa',
#   '!!/Punctuation'],
#  ['보습/Noun',
#   '감/Noun',
#   ',/Punctuation',
#   '수분/Noun',
#   '감/Noun',
#   '둘다/Verb',
#   '짱/VerbPrefix',
#   '짱/VerbPrefix',
#   '쓰/Adjective',
#   '!/Punctuation',
#   '양도/Noun',
#   '꽤/Noun',
#   '많고/Adjective',
#   '향/Noun',
#   '도/Josa',
#   '괜찮은/Adjective',
#   '편이/Noun',
#   '에요/Josa',
#   './Punctuation',
#   '딱/Modifier',
#   '하나/Noun',
#   '저/Noun',
#   '에게/Josa',
#   '불호/Noun',
#   '라면/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '..!?/Punctuation',
#   '점성/Noun',
#   '이/Josa',
#   '좀/Noun',
#   '있는/Adjective',
#   '편이/Noun',
#   '라서/Josa',
#   '약간/Noun',
#   '느낌/Noun',
#   '이/Josa',
#   '이상한/Adjective',
#   '정도/Noun',
#   '..?/Punctuation',
#   '에요/Josa',
#   'ㅋㅋㅋ/KoreanParticle',
#   '구거/Noun',
#   '말구/Verb',
#   '나머지/Noun',
#   '는/Josa',
#   '괜찮앗어요/Adjective',
#   '!/Punctuation'],
#  ['모공/Noun',
#   '에/Josa',
#   '효과/Noun',
#   '가/Josa',
#   '있을까/Adjective',
#   '해서/Verb',
#   '사/Noun',
#   '봤는데/Verb',
#   ',,/Punctuation',
#   '모공/Noun',
#   '조임이나/Verb',
#   '이런건/Adjective',
#   '못/Noun',
#   '느끼겠지만/Verb',
#   ',,/Punctuation',
#   '점성/Noun',
#   '있는/Adjective',
#   '토너/Noun',
#   '로/Josa',
#   '말끔/Adverb',
#   '하게/Verb',
#   '쓸수/Verb',
#   '있는/Adjective',
#   '토너/Noun',
#   '로/Josa',
#   '토너/Noun',
#   '로써/Noun',
#   '의/Josa',
#   '역할/Noun',
#   '을/Josa',
#   '잘/Verb',
#   '하는/Verb',
#   '느낌/Noun',
#   '이/Josa',
#   '듭니/Noun',
#   '다/Josa',
#   '!!~~/Punctuation',
#   '바르면/Verb',
#   '촉촉해서/Adjective',
#   '쓸/Verb',
#   '만해/Noun',
#   '요/Josa',
#   '!!/Punctuation'],
#  ['속/Modifier',
#   '건조/Noun',
#   '잡기/Noun',
#   '좋은/Adjective',
#   '묽은/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '이/Suffix',
#   '에/Josa',
#   '용/Noun',
#   '저/Noun',
#   '는/Josa',
#   '개인/Noun',
#   '적/Suffix',
#   '으로/Josa',
#   '닦/Verb',
#   '토/Noun',
#   '를/Josa',
#   '좋아하기/Adjective',
#   '때문/Noun',
#   '에/Josa',
#   '재구/Verb',
#   '매는/Verb',
#   '없지만/Adjective',
#   '건조하신/Adjective',
#   '분/Noun',
#   '들께는/Verb',
#   '딱/Adverb',
#   '좋/Adjective',
#   '습/Noun',
#   '니당/Verb',
#   '!/Punctuation'],
#  ['엄청/Adverb',
#   '촉촉하고/Adjective',
#   '끈/Noun',
#   '적임/Noun',
#   '없어서/Adjective',
#   '좋네요/Adjective',
#   '다만/Noun',
#   '용량/Noun',
#   '이/Josa',
#   '좀/Noun',
#   '더/Noun',
#   '컸으면/Verb',
#   '좋겠어요/Adjective',
#   '건성/Noun',
#   '추천/Noun',
#   '!/Punctuation'],
#  ['정말/Noun',
#   '딱/Adverb',
#   '수분/Noun',
#   '만/Josa',
#   '잘/Verb',
#   '채워주고/Verb',
#   '모공/Noun',
#   '을/Josa',
#   '조여/Noun',
#   '준다던지/Verb',
#   ',/Punctuation',
#   '쿨링감/Noun',
#   '이/Josa',
#   '있다던지/Adjective',
#   '하는/Verb',
#   '효과/Noun',
#   '는/Josa',
#   '못/VerbPrefix',
#   '봤/Verb',
#   '숩/Noun',
#   '니/Josa',
#   '더/Noun',
#   '../Punctuation'],
#  ['토너/Noun',
#   '라지/Noun',
#   '만/Josa',
#   '에센스/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '에/Josa',
#   '더/Noun',
#   '가까운거/Adjective',
#   '같습니다/Adjective',
#   './Punctuation',
#   '저/Noun',
#   '는/Josa',
#   '복합/Noun',
#   '성/Suffix',
#   '인데/Josa',
#   '이/Noun',
#   '제품/Noun',
#   '을/Josa',
#   '바르고/Verb',
#   '덜/Noun',
#   '땡겼어요/Verb',
#   './Punctuation',
#   '대신/Noun',
#   '기분/Noun',
#   '탓/Noun',
#   '인지/Josa',
#   '토너/Noun',
#   '인데/Josa',
#   '흡수/Noun',
#   '가/Josa',
#   '그렇게/Adverb',
#   '빠르지/Adjective',
#   '않아/Verb',
#   '두드려줘야/Verb',
#   '해서/Verb',
#   '조금/Noun',
#   '은/Josa',
#   '번거롭습니다/Adjective',
#   '../Punctuation'],
#  ['건성/Noun',
#   '입니다/Adjective',
#   '!/Punctuation',
#   '닦도/Verb',
#   '후/Noun',
#   '소량/Noun',
#   '흡수/Noun',
#   '해주고/Verb',
#   '있는데도/Adjective',
#   '촉촉한게/Adjective',
#   '느껴집니다/Verb',
#   './Punctuation',
#   '에센스/Noun',
#   '바르고/Verb',
#   '베이스/Noun',
#   '하고있어요/Verb',
#   '!/Punctuation',
#   '그런데도/Adjective',
#   '괜찮아서/Adjective',
#   '추천/Noun',
#   '드려요/Verb',
#   '~/Punctuation'],
#  ['의외로/Adverb',
#   '보기/Noun',
#   '보다는/Josa',
#   '수분/Noun',
#   '감/Noun',
#   '있고/Adjective',
#   '좋아요/Adjective',
#   '~/Punctuation',
#   '샘플/Noun',
#   '도/Josa',
#   '양도/Noun',
#   '많구/Adjective',
#   '!/Punctuation',
#   '여름/Noun',
#   '보다는/Josa',
#   '가을/Noun',
#   '겨울/Noun',
#   '에/Josa',
#   '쓰기/Noun',
#   '좋을/Adjective',
#   '것/Noun',
#   '같은/Adjective',
#   '보습/Noun',
#   '력/Suffix',
#   '이네/Josa',
#   '요/Noun',
#   '!!!/Punctuation',
#   '점도/Noun',
#   '있고/Adjective',
#   '엄청/Adverb',
#   '물/Noun',
#   '타입/Noun',
#   '이라기/Josa',
#   '보디/Noun',
#   '는/Josa',
#   '에센스/Noun',
#   '형태/Noun',
#   '에/Josa',
#   '가까워요/Adjective',
#   '!/Punctuation'],
#  ['샘플/Noun',
#   '사용/Noun',
#   '했어요/Verb',
#   './Punctuation',
#   '토너/Noun',
#   '라기/Josa',
#   '보다는/Josa',
#   '에센스/Noun',
#   '같이/Adverb',
#   '촉촉합니다/Adjective',
#   './Punctuation',
#   '끈/Noun',
#   '적임/Noun',
#   '은/Josa',
#   '없는/Adjective',
#   '수분/Noun',
#   '에센스/Noun',
#   '같아요/Adjective',
#   './Punctuation',
#   '모공/Noun',
#   '은/Josa',
#   '잘/Verb',
#   '모르겠어요/Verb',
#   './Punctuation'],
#  ['건성/Noun',
#   '이/Josa',
#   '여름/Noun',
#   '에/Josa',
#   '쓰기/Noun',
#   '좋은/Adjective',
#   '토너/Noun',
#   '인/Josa',
#   '것/Noun',
#   '같아요/Adjective',
#   '모공/Noun',
#   '이/Josa',
#   '좁아진다거나/Adjective',
#   '하는건/Verb',
#   '별로/Noun',
#   '못/VerbPrefix',
#   '느꼈고/Verb',
#   '물/Noun',
#   '처럼/Josa',
#   '흐르는/Verb',
#   '토너/Noun',
#   '라서/Josa',
#   '막/Noun',
#   '쓰기/Noun',
#   '좋아요/Adjective',
#   '토너/Noun',
#   '팩/Noun',
#   '으로도/Josa',
#   '좋을/Adjective',
#   '것/Noun',
#   '같아요/Adjective'],
#  ['모공/Noun',
#   '을/Josa',
#   '줄여주는/Verb',
#   '라인/Noun',
#   '이라고/Josa',
#   '해서/Verb',
#   '라인/Noun',
#   '싹/Noun',
#   '다/Adverb',
#   '구매/Noun',
#   '해봤는데/Verb',
#   '모공/Noun',
#   '축소/Noun',
#   '효과/Noun',
#   '는/Josa',
#   '딱히/Adjective',
#   '못/VerbPrefix',
#   '봤어요/Verb',
#   '.../Punctuation',
#   'ㅎ/KoreanParticle',
#   '발랐을/Verb',
#   '때/Noun',
#   '시원하면서/Adjective',
#   '알로에겔/Noun',
#   '처럼/Josa',
#   '미끌미끌하게/Adjective',
#   '발리는데/Verb',
#   '취향/Noun',
#   '탈꺼/Verb',
#   '같긴한데/Adjective',
#   '전/Noun',
#   '좋더라구요/Adjective',
#   ':)/Punctuation',
#   '이/Determiner',
#   '거/Noun',
#   '랑/Josa',
#   '크림/Noun',
#   '만/Josa',
#   '발라/Noun',
#   '도/Josa',
#   '충분할/Adjective',
#   '정도/Noun',
#   '로/Josa',
#   '수분/Noun',
#   '공급/Noun',
#   '이/Josa',
#   '잘/VerbPrefix',
#   '돼요/Verb'],
#  ['다른/Noun',
#   '토너/Noun',
#   '들/Suffix',
#   '은/Josa',
#   '물/Noun',
#   '제/Modifier',
#   '형/Noun',
#   '인데/Josa',
#   '얘/Noun',
#   '는/Josa',
#   '콧물/Noun',
#   '같이/Josa',
#   '점성/Noun',
#   '있는/Adjective',
#   '제/Modifier',
#   '형/Noun',
#   '이에요/Josa',
#   '수분/Noun',
#   '감도/Verb',
#   '더/Noun',
#   '있는/Adjective',
#   '것/Noun',
#   '같고/Adjective',
#   '순한/Adjective',
#   '느낌/Noun',
#   '이라/Josa',
#   '좋았습니다/Adjective',
#   '~/Punctuation'],
#  ...]

# %%
# tagging = []
# morph = []
# tag = []

# for j in range(len(list_)):
#   for i in list_[j] :
#     morph.append(i.split('/')[0])
#     tag.append(i.split('/')[1])
#   tagging.append([morph, tag])

# pd.DataFrame(tagging, columns =['morph', 'tag'])

# %%
def myTokenizer(text):
    d = pd.DataFrame(okt.pos(text), columns=['morph','tag'])
    d.set_index('tag', inplace=True)
    if ('Verb' in d.index) | ('Noun' in d.index) | ('Adjective' in d.index):
        return d.loc[d.index.intersection(['Verb','Noun','Adjective']),'morph'].values
    else :
        return []

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#TF-IDF Vectorizer에 연결해주기
tfidf_pos = TfidfVectorizer(tokenizer=myTokenizer)
tfidf_pos.fit(X)
tfidf_pos.vocabulary_
# Out:
# C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# {'샘플링': 79004,
#  '이벤트': 109257,
#  '사용': 76620,
#  '크림': 134964,
#  '토너': 137167,
#  '보습': 64869,
#  '라네즈': 43868,
#  '스킨': 84004,
#  '미스트': 56566,
#  '형': 149726,
#  '달라': 29969,
#  '달달': 29961,
#  '향': 148838,
#  '기분': 14061,
#  '받아서': 59864,
#  '했습니다': 148549,
#  '않아요': 94983,
#  '쓰고있는데': 89618,
#  '촉촉하고': 131240,
#  '좋아서': 120223,
#  '건조하지': 6721,
#  '은은하게': 108194,
#  '좋아요': 120262,
#  '로션': 44650,
#  '질감': 125166,
#  '여름': 101239,
#  '가을': 1737,
#  '겨울': 7861,
#  '수': 82138,
#  '것': 7505,
#  '같은': 4985,
#  '촉촉하게': 131225,
#  '있을': 112790,
#  '같아요': 4872,
#  '바르기': 58478,
#  '잘': 114166,
#  '쓸': 90574,
#  '당첨': 31239,
#  '결과': 8137,
#  '한번': 145814,
#  '발라': 60198,
#  '일단': 110650,
#  '제': 118585,
#  '기준': 14245,
#  '합격': 146308,
#  '되어': 35563,
#  '해본': 147097,
#  '해야하나': 147430,
#  '감도': 3339,
#  '않아서': 94965,
#  '같다고': 4766,
#  '있어서': 112480,
#  '좋더라구요': 120145,
#  '입니다': 111419,
#  '밀크': 57591,
#  '느낌': 26999,
#  '건성': 6555,
#  '피부': 143374,
#  '제품': 118699,
#  '흡수': 152123,
#  '편이': 140876,
#  '손': 81760,
#  '촵촵': 131842,
#  '랍니': 44045,
#  '좋은': 121109,
#  '묵직한': 54137,
#  '편하게': 140994,
#  '있는': 112115,
#  '적당히': 117102,
#  '바를수': 58906,
#  '덜어서': 32689,
#  '해주기': 147685,
#  '거': 5778,
#  '하라': 144873,
#  '기초': 14255,
#  '정도': 118287,
#  '하나': 144525,
#  '추가': 131957,
#  '콧물제형': 134350,
#  '지속': 123674,
#  '끈': 17311,
#  '거나': 5797,
#  '겉': 7552,
#  '화장': 150340,
#  '전': 117795,
#  '부담': 66299,
#  '끝내도': 17892,
#  '될': 36106,
#  '해도': 146648,
#  '가써요': 1686,
#  '는거': 27383,
#  '촉촉해요': 131505,
#  '촉촉한게': 131391,
#  '좋은데': 121117,
#  '없어서': 100275,
#  '없어요': 100294,
#  '빠르게': 72015,
#  '같아서': 4863,
#  '복숭아': 65524,
#  '몇번': 52118,
#  '보송보송': 64634,
#  '약간': 96892,
#  '더': 31895,
#  '나고': 18684,
#  '두드리니까': 36686,
#  '되서': 35507,
#  '바르고': 58371,
#  '당김': 31118,
#  '느껴지는거': 26491,
#  '생각': 79028,
#  '이상': 109584,
#  '요': 105368,
#  '에센스': 100906,
#  '대용': 31707,
#  '부족함': 67625,
#  '민감': 56917,
#  '자극': 113065,
#  '솜': 81998,
#  '뭍': 55828,
#  '비싸다고': 70760,
#  '가능할': 464,
#  '없네요': 99854,
#  '좋게': 119796,
#  '했는데': 148389,
#  '스며들어요': 83672,
#  '닦아내고': 29161,
#  '줬어요': 122805,
#  '하네요': 144548,
#  '쫀쫀': 126828,
#  '세안': 81001,
#  '후': 150998,
#  '바르니': 58584,
#  '없고': 99795,
#  '산뜻해서': 77127,
#  '좋았어요': 120950,
#  '대신': 31665,
#  '번': 62675,
#  '바로': 58316,
#  '쓸만큼': 90725,
#  '될만큼': 36147,
#  '촉촉해용': 131506,
#  '진짜': 124920,
#  '최고': 131858,
#  '대박': 31609,
#  '랩': 44110,
#  '케어': 133912,
#  '라인': 43958,
#  '다음': 28891,
#  '날': 20525,
#  '광남': 9572,
#  '바르면': 58653,
#  '해져요': 147596,
#  '클': 135159,
#  '컨디션': 133687,
#  '덧': 33022,
#  '정말': 118313,
#  '무향': 54071,
#  '푸석푸석하고': 142020,
#  '안좋은': 94387,
#  '잤더니': 115967,
#  '좋아졌어요': 120339,
#  '미끌거리지': 56217,
#  '기': 13435,
#  '지난번': 123349,
#  '한적': 145880,
#  '묻혀': 54773,
#  '닦': 29074,
#  '했었거든요': 148579,
#  '가볍게': 1440,
#  '없는': 99861,
#  '있었는데': 112586,
#  '좋았다': 120890,
#  '중': 122485,
#  '적임': 117570,
#  '건조': 6588,
#  '햇': 148305,
#  '부들부들': 66707,
#  '거려': 5880,
#  '남아': 21260,
#  '저': 116602,
#  '용': 105496,
#  '쓰것': 89405,
#  '않고': 94724,
#  '는데': 27418,
#  '쓰고나서': 89499,
#  '믿고': 57118,
#  '쓸만': 90722,
#  '하네용': 144550,
#  '잇어서': 111844,
#  '간편하고': 2526,
#  '진하지': 125024,
#  '덜함': 32890,
#  '덜하고': 32785,
#  '촉촉함이': 131457,
#  '딱이에': 40829,
#  '유': 107353,
#  '분기': 67833,
#  '소량': 81471,
#  '감': 3220,
#  '사람': 75860,
#  '계절': 8418,
#  '쓰기': 89697,
#  '개인': 5490,
#  '유지': 107902,
#  '편입': 140976,
#  '니': 27847,
#  '김': 14615,
#  '느껴지는데': 26511,
#  '써도': 88109,
#  '보입니다': 65402,
#  '덜어': 32649,
#  '쓰는': 89754,
#  '않으면서': 95187,
#  '잡아줘서': 115734,
#  '빠르고': 72018,
#  '건조한': 6732,
#  '상관없이': 78350,
#  '좋아': 120205,
#  '좋았고요': 120870,
#  '괜찮은': 9989,
#  '답답하지': 30925,
#  '괜찮을': 10000,
#  '흰색': 152292,
#  '덕분': 32485,
#  '일반': 110730,
#  '물': 54893,
#  '그': 11687,
#  '속성': 81738,
#  '묽은': 55496,
#  '좋음': 121219,
#  '가는': 265,
#  '글': 12947,
#  '로우': 44674,
#  '픽': 143545,
#  '샘플': 79002,
#  '온': 103532,
#  '다른': 28563,
#  '가장': 1773,
#  '맘': 48687,
#  '사제품': 76697,
#  '기대': 13607,
#  '이하': 110125,
#  '과': 9403,
#  '우윳빛': 106150,
#  '받아': 59834,
#  '해봤는데': 147231,
#  '들었던': 39350,
#  '였었는데': 102075,
#  '하지': 145539,
#  '않아': 94957,
#  '나서': 19278,
#  '스며들고': 83640,
#  '많아': 47570,
#  '미세하고': 56524,
#  '하얀색': 145303,
#  '우유': 106145,
#  '때': 41162,
#  '템': 137121,
#  '강추': 4231,
#  '흐르고': 151525,
#  '올렸을': 104415,
#  '잡아주는': 115643,
#  '가벼운': 1330,
#  '같고': 4699,
#  '남다르더라구요': 21204,
#  '무겁지': 53419,
#  '건조함만': 6816,
#  '펩타이드': 140443,
#  '글픽': 13034,
#  '평가': 141381,
#  '단': 29523,
#  '처음': 130402,
#  '보고': 63946,
#  '팹': 139681,
#  '이드': 108849,
#  '역시': 101436,
#  '촥촥': 131825,
#  '써': 88048,
#  '봤는데': 66087,
#  '잡아주는데': 115659,
#  '하게': 144151,
#  '두드려주면': 36620,
#  '돼요': 34941,
#  '순하고': 82521,
#  '촉촉해서': 131495,
#  '만족스러워서': 47047,
#  '좋네요': 119966,
#  '무겁거나': 53371,
#  '여드름': 101216,
#  '클렌징': 135253,
#  '좀': 119582,
#  '장벽': 116057,
#  '강화': 4478,
#  '선호': 80461,
#  '브랜드': 69925,
#  '접': 118106,
#  '이': 108539,
#  '풀향': 142579,
#  '나': 18433,
#  '점성': 118060,
#  '하나로': 144530,
#  '세번': 80970,
#  '레이어': 44428,
#  '링': 45444,
#  '럼': 44270,
#  '트러블': 137974,
#  '반응': 59468,
#  '기한': 14275,
#  '미백': 56470,
#  '주름': 121577,
#  '기능': 13499,
#  '전체': 117925,
#  '타입': 135863,
#  '경험': 8284,
#  '가졌으며': 1950,
#  '세게': 80841,
#  '하는': 144565,
#  '되는': 35290,
#  '가': 0,
#  '타사': 135803,
#  '해봐서': 147181,
#  '바르지': 58759,
#  '않았는데도': 95063,
#  '느껴지지': 26565,
#  '않았습니다': 95109,
#  '참': 128980,
#  '길어지면': 14534,
#  '맞아서': 49401,
#  '였습니다': 102061,
#  '있습니다': 112446,
#  '유명하지만': 107506,
#  '좋아해서': 120748,
#  '궁금했습니다': 11252,
#  '남다릅니다': 21209,
#  '건조함이': 6828,
#  '편안한': 140784,
#  '좋았습니다': 120935,
#  '있을지': 112852,
#  '얼굴': 99236,
#  '악': 93311,
#  '수분': 82233,
#  '저녁': 116614,
#  '아침': 93025,
#  '머': 50519,
#  '금고': 13246,
#  '보니': 64254,
#  '자면': 113351,
#  '많고': 47475,
#  '상태': 78602,
#  '에어컨': 100943,
#  '땐': 41287,
#  '유액': 107734,
#  '성분': 80697,
#  '뭔가': 55904,
#  '드네': 37498,
#  '선크림': 80437,
#  '필수': 143728,
#  '꽤': 16884,
#  '환절기': 150697,
#  '분': 67825,
#  '듯': 39735,
#  '봤어요': 66144,
#  '많아져서': 47592,
#  '지내는': 123402,
#  '틀었을': 138628,
#  '하는데': 144669,
#  '닦는': 29115,
#  '맞지': 49589,
#  '않는데': 94856,
#  '합쳐졌다는': 146376,
#  '찹': 129111,
#  '시키면서': 85497,
#  '들어있어': 39168,
#  '찾는': 129301,
#  '들께도': 38354,
#  '해요': 147551,
#  '건조해져서': 6879,
#  '괜찮아요': 9808,
#  '같아': 4853,
#  '촉촉했어요': 131632,
#  '좋을': 121146,
#  '굉장히': 10233,
#  '부드러워지는게': 66567,
#  '에멀젼': 100878,
#  '원래': 106655,
#  '토파': 137256,
#  '그냥': 11703,
#  '결': 8134,
#  '의사': 108474,
#  '바르기만': 58481,
#  '느껴집니다': 26631,
#  '재구매': 116223,
#  '크리미': 134952,
#  '충전': 132494,
#  '완전': 104966,
#  '적당': 116992,
#  '아주': 93002,
#  '금방': 13262,
#  '토': 137156,
#  '토로': 137208,
#  '무난': 53451,
#  '중이': 122666,
#  '건조하거나': 6593,
#  '필요할': 143961,
#  '아니라서': 92066,
#  '촉촉함과': 131433,
#  '건조해지지는': 6959,
#  '만족합니다': 47295,
#  '심하거나': 86830,
#  '같네요': 4748,
#  '채워주는': 129904,
#  '쓰면': 90102,
#  '되고': 35200,
#  '나서도': 19286,
#  '용은': 105599,
#  '했을': 148651,
#  '워터': 106622,
#  '리': 45003,
#  '부지': 67669,
#  '아니고': 91985,
#  '좋고': 119911,
#  '펴': 140451,
#  '바르는게': 58559,
#  '맞는거': 49260,
#  '평소': 141449,
#  '발림': 61044,
#  '속': 81680,
#  '점점': 118089,
#  '요즘': 105451,
#  '잡기': 115483,
#  '건너': 6497,
#  '대충': 31765,
#  '경우': 8264,
#  '반수': 59458,
#  '완화': 105006,
#  '도움': 33682,
#  '글로우픽': 12982,
#  '화장품': 150344,
#  '회사': 150924,
#  '약품': 96927,
#  '제조': 118681,
#  '종이': 119759,
#  '글함': 13051,
#  '맞춤': 49668,
#  '가득하고': 617,
#  '깔끔해서': 15430,
#  '촉촉한': 131365,
#  '아닌': 92251,
#  '힘든': 152454,
#  '있다고': 112262,
#  '아니라': 92054,
#  '두꺼우면': 36379,
#  '어떠세요': 97770,
#  '스며드는': 83610,
#  '하는데요': 144687,
#  '뛰거나': 42959,
#  '해서': 147300,
#  '않아도': 94962,
#  '뜨는': 43290,
#  '였는데요': 102015,
#  '채워': 129856,
#  '넣어': 23754,
#  '해봤어요': 147263,
#  '했어서': 148565,
#  '들': 38205,
#  '아실거라고': 92880,
#  '들어가있어': 38755,
#  '이었습니다': 109906,
#  '밀리는': 57378,
#  '보면': 64543,
#  '덜': 32555,
#  '줄': 122098,
#  '친구': 132958,
#  '정돈': 118291,
#  '양': 97378,
#  '이참': 110072,
#  '사': 75293,
#  '아닙니다': 92363,
#  '좋아하는데': 120578,
#  '가볍습니다': 1494,
#  '알았는데': 95969,
#  '하기': 144447,
#  '받은거라': 60059,
#  '적어서': 117248,
#  '넘': 23261,
#  '버렸어요': 62223,
#  '상큼': 78599,
#  '과일': 9457,
#  '호': 149782,
#  '지성인': 123671,
#  '후다닥': 151038,
#  '단계': 29538,
#  '지성은': 123669,
#  '하면서': 144943,
#  '먹어서': 51039,
#  '써요': 88313,
#  '오묘해요': 103261,
#  '바쁠': 59037,
#  '건조하고': 6606,
#  '유용하게': 107775,
#  '촉촉할것': 131420,
#  '같아용': 4876,
#  '괜찮습니다': 9794,
#  '독일': 33858,
#  '테스트': 137058,
#  '이름': 109198,
#  '이자': 110024,
#  '필요': 143775,
#  '완벽': 104880,
#  '가능': 338,
#  '용기': 105504,
#  '영양가': 102192,
#  '듬뿍': 39697,
#  '점': 118040,
#  '더마': 32131,
#  '없을': 100632,
#  '믿음직함': 57201,
#  '아쉬운': 92646,
#  '아쉽습니다': 92812,
#  '인정받은': 110501,
#  '잡는': 115495,
#  '넣으면': 23955,
#  '들어가': 38621,
#  '첫': 130608,
#  '특유': 138276,
#  '텁텁': 136974,
#  '마무리': 45703,
#  '템팅': 137145,
#  '상승': 78433,
#  '만렙': 46879,
#  '때문': 41236,
#  '젤': 118734,
#  '걸': 7114,
#  '충분': 132345,
#  '은은하고': 108209,
#  '묽고': 55431,
#  '산뜻한': 77088,
#  '같은거': 4987,
#  '할수록': 146074,
#  '느껴지고': 26474,
#  '않기': 94755,
#  '하고': 144231,
#  '하면': 144939,
#  '액체': 96530,
#  '지성': 123665,
#  '추천': 132089,
#  '톤': 137319,
#  '정리': 118308,
#  '있지만': 112898,
#  '확실히': 150614,
#  '괜찮네요': 9737,
#  '바릅니다': 58971,
#  '하기에는': 144479,
#  '반신반의': 59462,
#  '향기도': 148846,
#  '촉촉하면서': 131342,
#  '가벼워서': 1372,
#  '씁니다': 90938,
#  '초단': 131030,
#  '더욱더': 32230,
#  '안': 93360,
#  '좋더라고요': 120144,
#  '채워줄수': 129962,
#  '맞을것': 49555,
#  '올라오고': 103823,
#  '수분크림': 82238,
#  '적': 116888,
#  '알': 95349,
#  '인증': 110513,
#  '단백질': 29691,
#  '단위체': 29726,
#  '아미노산': 92569,
#  '개': 5143,
#  '구성': 10499,
#  '물질': 55383,
#  '콜라겐': 134285,
#  '엘라스': 101025,
#  '틴': 138739,
#  '생': 79026,
#  '위해': 107292,
#  '확인': 150635,
#  '현대': 149664,
#  '독자': 33859,
#  '조성': 119074,
#  '헥사': 149441,
#  '틸헥': 138765,
#  '등': 39750,
#  '함유': 146284,
#  '개선': 5280,
#  '탄력': 136079,
#  '레몬': 44364,
#  '오렌지': 103118,
#  '껍질': 16375,
#  '추출': 132107,
#  '발효': 61162,
#  '업': 99646,
#  '사이클링': 76672,
#  '원료': 106658,
#  '뿐': 75096,
#  '종': 119733,
#  '걱정': 6384,
#  '무': 53285,
#  '첨가': 130597,
#  '신경': 85764,
#  '밀키': 57596,
#  '눈': 25922,
#  '톡톡': 137287,
#  '톡': 137272,
#  '광': 9559,
#  '광채': 9622,
#  '한': 145633,
#  '된': 35964,
#  '합니다': 146315,
#  '아세': 92599,
#  '해주네요': 147714,
#  '써주네요': 88414,
#  '느껴지는': 26490,
#  '않지만': 95336,
#  '않는': 94800,
#  '두드리면서': 36698,
#  '채워지는': 129982,
#  '그리': 12555,
#  '않은': 95220,
#  '당김이나': 31131,
#  '있어': 112464,
#  '탄탄하게': 136097,
#  '꼼꼼하게': 16673,
#  '투명하지': 137574,
#  '묽지': 55523,
#  '투명하게': 137554,
#  '세상': 80976,
#  '일이': 111013,
#  '사랑': 75867,
#  '오': 102874,
#  '쫌': 126917,
#  '호불호': 149838,
#  '갈릴': 2900,
#  '내': 22086,
#  '착해': 128745,
#  '있으나': 112702,
#  '좋아하면': 120611,
#  '상관없다': 78314,
#  '아껴': 91826,
#  '뒀다가': 37154,
#  '쓸게': 90613,
#  '흔들어서': 151759,
#  '하시구': 145095,
#  '잡으세요': 115788,
#  '자체': 113772,
#  '만큼': 47443,
#  '촉촉': 131172,
#  '데': 33249,
#  '게': 7596,
#  '워낙': 106585,
#  '커버': 133538,
#  '앰플': 96585,
#  '해': 146490,
#  '통': 137381,
#  '사면': 76030,
#  '한참': 145889,
#  '만족': 47006,
#  '쓰면서': 90104,
#  '해주고': 147647,
#  '할': 145915,
#  '밀리거나': 57353,
#  '뭉침이': 55785,
#  '되어서': 35593,
#  '바른': 58781,
#  '좋아했는데': 120774,
#  '놀랬어요': 24938,
#  '심한': 86921,
#  '부드럽': 66630,
#  '있어용': 112511,
#  '심할': 86953,
#  '촉촉하기까지': 131250,
#  '예민한': 102414,
#  '딱인': 40848,
#  '작년': 113829,
#  '현재': 149688,
#  '먼저': 51470,
#  '인공': 110378,
#  '품': 142582,
#  '가격': 28,
#  '단점': 29741,
#  '발려서': 60725,
#  '해보고': 146777,
#  '싶은데': 87431,
#  '괜찮아서': 9801,
#  '좋았고': 120869,
#  '순해서': 82662,
#  '비싼게': 70890,
#  '콧물': 134340,
#  '주로': 121565,
#  '백색': 61886,
#  '분과': 67830,
#  '영양': 102191,
#  '엑설런트': 100993,
#  '안티': 94527,
#  '이징': 110067,
#  '모든': 52164,
#  '제공': 118592,
#  '리뷰': 45097,
#  '답답한': 30932,
#  '불편했는데': 68808,
#  '은은한': 108253,
#  '더나구요': 31915,
#  '필요한': 143927,
#  '좋겠어요': 119883,
#  '채워지고': 129976,
#  '들었어요': 39371,
#  '챙겨주는': 130167,
#  '되었어요': 35832,
#  '마친': 46009,
#  '쓰셔도': 90127,
#  '촉촉한데': 131394,
#  '만족하면서': 47182,
#  '딱입니당': 40869,
#  '기름기': 13879,
#  '느껴져서': 26404,
#  '쓰고있어요': 89654,
#  '별로': 63820,
#  '기름': 13878,
#  '지지': 124448,
#  '아니길래': 92005,
#  '같았는데': 4915,
#  '없었습니다': 100529,
#  '만족스럽네요': 47105,
#  '일것': 110623,
#  '보는데': 64244,
#  '대가': 31439,
#  '나니': 18982,
#  '기대하고': 13649,
#  '촉촉해진': 131596,
#  '나쁘지': 19236,
#  '같습니다': 4846,
#  '해봤는데요': 147234,
#  '들어요': 39080,
#  '도': 33430,
#  '성도': 80684,
#  '시중': 85190,
#  '판매': 139264,
#  '구매': 10447,
#  '아보': 92585,
#  '사실': 76356,
#  '보지': 65444,
#  '베스트': 63512,
#  '업자': 99726,
#  '주는': 121483,
#  '받았어요': 59976,
#  '흐르는': 151536,
#  '생각나서': 79059,
#  '했네요': 148382,
#  '나면': 19107,
#  '끝낼': 17950,
#  '들어': 38620,
#  '했던': 148480,
#  '썼는데': 88725,
#  '본': 65562,
#  '드는것': 37514,
#  '만든': 46485,
#  '할게요': 145967,
#  '부족한': 67587,
#  '깔끔하고': 15363,
#  '좋았다고': 120892,
#  '부드럽고': 66640,
#  '좋': 119784,
#  '더라구요': 32008,
#  '같기도': 4715,
#  '가볍지': 1499,
#  '않게': 94692,
#  '색': 78840,
#  '이나': 108769,
#  '어떨까': 97820,
#  '궁금했는데': 11243,
#  '달콤한': 30475,
#  '지렸어요': 123546,
#  '바르는': 58502,
#  '효과': 150972,
#  '누': 25662,
#  '흠': 152069,
#  '반입': 59471,
#  '다용': 28882,
#  '있': 111917,
#  '있어요': 112508,
#  '단어': 29719,
#  '노화': 24381,
#  '방지': 61651,
#  '들어도': 38928,
#  '드려요': 37733,
#  '하자구요': 145507,
#  '건강할것': 6433,
#  '똑똑하게': 42677,
#  '흘러내리지': 151920,
#  '만족스러웠고': 47066,
#  '지금': 123178,
#  '애정': 96489,
#  '쓰고있는': 89606,
#  '쓰는데': 89837,
#  '가까운': 96,
#  '손바닥': 81833,
#  '듯이': 39741,
#  '뚜껑': 42770,
#  '향기': 148845,
#  '거의': 6132,
#  '되면': 35484,
#  '줍니다': 122472,
#  '흐르지는': 151563,
#  '열고': 101716,
#  '털듯이': 136833,
#  '없다시피': 100023,
#  '이스': 109746,
#  '처': 130348,
#  '예전': 102832,
#  '운': 106193,
#  '시작': 85181,
#  '신상': 85986,
#  '관심': 9514,
#  '계속': 8346,
#  '가지': 1963,
#  '항상': 146468,
#  '왜': 105188,
#  '유수': 107721,
#  '밸런스': 61940,
#  '한가지': 145637,
#  '로만': 44626,
#  '녀석': 24084,
#  '살짝': 77826,
#  '정착': 118412,
#  '의향': 108533,
#  '클을': 135475,
#  '몰랐었는데': 52925,
#  '클에서': 135451,
#  '나오면': 19673,
#  '가더라구요': 567,
#  '쓰고': 89485,
#  '않았다면': 95079,
#  '채우기': 129774,
#  '쓰는거': 89756,
#  '자나요': 113137,
#  '않을까': 95279,
#  '갖고': 4507,
#  '왔어요': 105101,
#  '채워주는게': 129914,
#  '느껴져요': 26409,
#  '해볼': 147126,
#  '만족하지': 47240,
#  '없겠죠': 99789,
#  '만족했었기에': 47362,
#  '있구요': 112016,
#  '아쉬웠던게': 92733,
#  '가능할까': 471,
#  '가능하면': 413,
#  '좋지': 121258,
#  '무거운': 53298,
#  '느낌이였어요': 27182,
#  '촉': 131145,
#  '촉감': 131147,
#  '봐서': 65951,
#  '샀어요': 78227,
#  '토니모리': 137174,
#  '모찌': 52739,
#  '일리': 110710,
#  '윤': 108032,
#  '프로바이오틱스': 142879,
#  '드롭': 37784,
#  '좀더': 119605,
#  '조금': 118980,
#  '형도': 149736,
#  '용감': 105498,
#  '요약': 105440,
#  '프로': 142872,
#  '유사': 107672,
#  '체감': 130767,
#  '비슷합니당': 70657,
#  '느려요': 27276,
#  '그렇고': 12224,
#  '비슷해요': 70670,
#  '완전히': 104976,
#  '달라용': 30050,
#  '있어서는': 112481,
#  '빠르다': 72034,
#  '편하고': 141016,
#  '매끈한': 50079,
#  '않는다는': 94833,
#  '떠올리면': 41621,
#  '되었을': 35845,
#  '됩니당': 36223,
#  '겨쿨': 7967,
#  '딥': 39963,
#  '다크': 29001,
#  '차선': 128352,
#  '비비드': 70465,
#  '중성': 122531,
#  '명도': 52050,
#  '편': 140584,
#  '색상': 78896,
#  '호수': 149850,
#  '장점': 116096,
#  '챱토': 130344,
#  '루틴': 44899,
#  '단기간': 29545,
#  '보기': 64048,
#  '영역': 102200,
#  '걸친': 7415,
#  '타는': 135755,
#  '감은': 3625,
#  '모르겠어요': 52318,
#  '이긴': 108724,
#  '빨라': 72703,
#  '어려운': 97894,
#  '순면': 82474,
#  '패드': 139552,
#  '호감': 149785,
#  '아토피': 93048,
#  '움': 106431,
#  '홍조': 150038,
#  '두드러기': 36554,
#  '됐는데': 35018,
#  '이라': 108863,
#  '가벼워진': 1405,
#  '올라오지': 103933,
#  '않았어요': 95118,
#  '괜찮았음': 9955,
#  '따가': 40026,
#  '성은': 80733,
#  '생각나는': 79042,
#  '그럼에도': 12188,
#  '좋습니다': 120193,
#  '말': 47906,
#  '그대로': 11722,
#  '리치': 45160,
#  '막': 46047,
#  '쫀쫀하': 126853,
#  '양감': 97382,
#  '샤샤': 79594,
#  '삭': 76920,
#  '나무늘보': 19118,
#  '느긋하게': 26359,
#  '편해요': 141203,
#  '빠르진': 72061,
#  '좋아하시는': 120649,
#  '부담스러운': 66314,
#  '야하는': 96767,
#  '힘들어서': 152563,
#  '바를': 58861,
#  '않다고': 94880,
#  '느꼈어요': 26686,
#  '비추': 71196,
#  '채워주고': 129894,
#  '싶은': 87413,
#  '답': 30869,
#  '빛': 71903,
#  '맑은': 48676,
#  '고민': 8741,
#  '끈덕끈덕': 17332,
#  '끈덕임': 17334,
#  '전혀': 117948,
#  '심지어': 86810,
#  '기부': 14060,
#  '보': 63908,
#  '봣': 66048,
#  '또': 42501,
#  '변화': 63800,
#  '한여름': 145858,
#  '사이': 76650,
#  '굳이': 10846,
#  '난': 20333,
#  '얘': 97466,
#  '일': 110600,
#  '선택': 80440,
#  '뽀얀': 73915,
#  '넉넉히': 23056,
#  '보들보들한': 64404,
#  '안될': 93873,
#  '조아요': 119200,
#  '드러워': 37663,
#  '드러운': 37659,
#  '보들보들해지는': 64440,
#  '많은': 47769,
#  '엄청난': 99607,
#  '충분히': 132435,
#  '있네요': 112103,
#  '엄청나게': 99569,
#  '편인데도': 140958,
#  '미끄러지는': 56103,
#  '지느': 123452,
#  '듦': 39683,
#  '잇지는': 111908,
#  '준다는': 122039,
#  '날아가서': 20832,
#  '해줘야': 148051,
#  '하기도': 144463,
#  '해야겠다': 147381,
#  '여러': 101222,
#  '비교': 70230,
#  '겹': 8201,
#  '드': 37485,
#  '무게': 53431,
#  '김이나': 14632,
#  '따라서': 40491,
#  ...}

# %%
len(tfidf_pos.vocabulary_)
# Out:
# 152789

# %%
# 실제 문장에 단어를 토큰값으로 변환해주는 작업 진행 : 8분정도 걸림
X_trains = tfidf_pos.transform(X)

# %%
X_trains
# Out:
# <183005x152789 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6215772 stored elements in Compressed Sparse Row format>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_trains, y, test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((146404, 152789), (36601, 152789), (146404,), (36601,))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier() # 하이퍼 파라미터 조절 X / 랜덤포레스트 기 모델

# %%
# 교차검증 - 예상 성능 확인해보기
from sklearn.model_selection import cross_val_score

rs = cross_val_score(rf_model, X_train, y_train, cv = 5)
print(rs)
print(rs.mean())
# Out:
# [0.74871077 0.74809603 0.74813019 0.74970117 0.74894126]
# 0.748715883619117

# %%
# 모델 학습 및 평가
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_model.score(X_train, y_train)
# Out:
# 0.9998838829540176

# %%
rf_model.score(X_test, y_test)
# Out:
# 0.7483128876260211

# %%
# 하이퍼 파라미터 조합찾기
from sklearn.model_selection import GridSearchCV

# %%
# 하이퍼 파라미터 조절
# 내가 하이퍼 파라미터 뭉텡이를 던져주면 조합식을 짜서 최적의 조합을 짜줌
# 이때 사용하는건 교차검증 점수
param = { 'n_estimators' : [500, 1000, 1500, 2000, 2500], # 트리의 갯수 갯수가 많을수록 시간이 오래걸림
          'max_depth': range(1,6), # 트리의 최대 깊이 최대 깊이는 5를 안넘는게 좋음...
          #'min_samples_split': range(1,6),
          #'min_samples_leaf' : range(1,6)

        }

# range(100, 5001, 100) - 100부터 5000까지 100씩 증가 시켜주세요
grid_model = GridSearchCV(rf_model, param, n_jobs=-1, cv = 10)

# %%
grid_model.fit(X_train, y_train) #시간 좀 걸림
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': range(1, 6),
#                          'n_estimators': [500, 1000, 1500, 2000, 2500]})

# %%
print(f" 최적 교차검증 점수 : {grid_model.best_score_}") # 최적 파라미터로 찾은 교차검증 점수
print(f" 최적 교차검증 파라미터 목록 : {grid_model.best_params_}") # 최적 파라미터 목록
# Out:
#  최적 교차검증 점수 : 0.7314622557620396
#  최적 교차검증 파라미터 목록 : {'max_depth': 1, 'n_estimators': 500}

# %%
best_model = grid_model.best_estimator_ # 최적 모델 만들기

# %%
best_model.fit(X_train, y_train) # 최적 모델 학습
# Out:
# RandomForestClassifier(max_depth=1, n_estimators=500)

# %%
best_model.score(X_train, y_train) # 최적 모델 훈련 점수
# Out:
# 0.7314622551296412

# %%
best_model.score(X_test, y_test) # 최적 모델 평가 점수
# Out:
# 0.7313734597415371

# %%
# rf 활용
# predict_proba : 각 클래스별 불확실성 확률 -> 예측확률을 정답별로 표시
# target_names = ['부정', '중립' ,'긍정']
target_names = np.array(["부정", "중립", "긍정"])
review = ['이 화장품은 촉촉해서 건성 피부를 가지신 분이라면 좋을것 같아요']
vect_review = tfidf_pos.transform(review) # 토큰화 변환 진행 코드
pre = rf_model.predict(vect_review)
print(f"{review[0]} 문장은 {rf_model.predict_proba(vect_review).max()*100:.2f}%로 {target_names[pre[0]]} 리뷰입니다!")
# Out:
# 이 화장품은 촉촉해서 건성 피부를 가지신 분이라면 좋을것 같아요 문장은 75.77%로 긍정 리뷰입니다!

# %%
pre1 = rf_model.predict(X_test)
pre1
# Out:
# array([2, 2, 2, ..., 2, 2, 2], dtype=int64)

# %%
translated_pre1 = target_names[pre1]
translated_pre1
# Out:
# array(['긍정', '긍정', '긍정', ..., '긍정', '긍정', '긍정'], dtype='<U2')
